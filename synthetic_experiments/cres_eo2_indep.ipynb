# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import argparse

plt.switch_backend('agg')
# In[3]:
font = {'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torchvision import transforms, utils, models, datasets
from torch.utils.data import Dataset, DataLoader

# %%
from synthetic_dataloader import *


from synthetic_utils import *


# In[5]:


from trainer_dataloader import *
from networks import *
from losses import *


# In[6]:

# %%
input_size = 96
batch_size = 64
num_workers = 4


cuda = False
pin_memory = False
if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    cuda = True
    cudnn.benchmark = True
    pin_memory = True
else:
    device = torch.device("cpu")

print('Device set: {}'.format(device))


# In[8]:


data_transforms = {
        'train': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ]),
        'val': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
}
# Out:
# Device set: cuda

# %%
# if independent:
DATA_PATH = '/home/s1791387/diss/gen_shapes/'
# else:
# DATA_PATH = '/home/s1791387/diss/dependent_gen/'
print(DATA_PATH)
TRAIN_PATH = os.path.join(DATA_PATH, 'train')
VAL_PATH = os.path.join(DATA_PATH, 'valid')
TEST_PATH = os.path.join(DATA_PATH, 'test')
# Out:
# /home/s1791387/diss/gen_shapes/

# %%
train_df = datasets.ImageFolder(root=TRAIN_PATH, transform=data_transforms['train'])
val_df = datasets.ImageFolder(root=VAL_PATH, transform=data_transforms['val'])
test_df = datasets.ImageFolder(root=TEST_PATH, transform=data_transforms['val'])

# %%
LOAD_PATH = './eo2_indep/1/weights/encoder_194_0.716.pth'

# %%
laftr_encoder = torch.load(LOAD_PATH)

# %%
gender_train = ShapeDataset(train_df)
gender_valid = ShapeDataset(val_df)
gender_test = ShapeDataset(test_df)

# %%
advtrain_loader = DataLoader(gender_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
advval_loader = DataLoader(gender_valid, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
advtest_loader = DataLoader(gender_test, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

# %%
classifier = ClassNet()

adv_criterion = nn.BCELoss()
opt_adv = optim.Adam(classifier.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler_adv = lr_scheduler.StepLR(optimizer=opt_adv, gamma=0.99, step_size=1)

# %%
num_epochs = 20
train_losses = []
train_accs = []
val_losses = []
val_accs = []
epoch_time = AverageMeter()
ep_end = time.time()
for epoch in range(0, num_epochs):
        print('Epoch: {}/{}'.format(epoch, num_epochs))
        scheduler_adv.step()
        # train
        train_loss, train_acc = train_classifier_epoch(advtrain_loader, laftr_encoder,
                                classifier, opt_adv, adv_criterion, device)
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        # validate
        print('-'*10)
        val_loss, val_acc = validate_classifier_epoch(advval_loader, laftr_encoder, classifier,
                                 adv_criterion, device)

        print('Avg validation loss: {} \t Accuracy: {}'.format(val_loss, val_acc))
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        
        print('-' * 20)
        epoch_time.update(time.time() - ep_end)
        ep_end = time.time()
        print('Epoch {}/{}\t'
              'Time {epoch_time.val:.3f} sec ({epoch_time.avg:.3f} sec)'.format(epoch, num_epochs, epoch_time=epoch_time))
        print('-'*20)
# Out:
# Epoch: 0/20
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/79]	Time 2.138 (2.138)	Loss 0.6267 (0.6267)	Accuracy 0.6406 (0.6406)
# Batch: [10/79]	Time 0.031 (0.453)	Loss 0.6107 (0.6450)	Accuracy 0.7031 (0.6222)
# Batch: [20/79]	Time 1.331 (0.443)	Loss 0.6375 (0.6379)	Accuracy 0.6406 (0.6376)
# Batch: [30/79]	Time 0.040 (0.401)	Loss 0.5762 (0.6204)	Accuracy 0.6875 (0.6638)
# Batch: [40/79]	Time 1.340 (0.409)	Loss 0.6678 (0.6178)	Accuracy 0.6250 (0.6601)
# Batch: [50/79]	Time 0.030 (0.389)	Loss 0.5684 (0.6108)	Accuracy 0.6562 (0.6639)
# Batch: [60/79]	Time 1.367 (0.397)	Loss 0.5745 (0.6056)	Accuracy 0.7344 (0.6696)
# Batch: [70/79]	Time 0.052 (0.383)	Loss 0.5578 (0.6005)	Accuracy 0.7188 (0.6741)
# ----------
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Avg validation loss: 0.6236076514720916 	 Accuracy: 0.638
# --------------------
# Epoch 0/20	Time 38.653 sec (38.653 sec)
# --------------------
# Epoch: 1/20
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([52])) that is different to the input size (torch.Size([52, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/79]	Time 5.106 (5.106)	Loss 0.6451 (0.6451)	Accuracy 0.5781 (0.5781)
# Batch: [10/79]	Time 0.035 (0.603)	Loss 0.6083 (0.5970)	Accuracy 0.6406 (0.6662)
# Batch: [20/79]	Time 0.063 (0.467)	Loss 0.5553 (0.5830)	Accuracy 0.7031 (0.6778)
# Batch: [30/79]	Time 0.039 (0.456)	Loss 0.5826 (0.5817)	Accuracy 0.6875 (0.6789)
# Batch: [40/79]	Time 0.083 (0.419)	Loss 0.4533 (0.5789)	Accuracy 0.8125 (0.6825)
# Batch: [50/79]	Time 0.028 (0.424)	Loss 0.5608 (0.5753)	Accuracy 0.7188 (0.6875)
# Batch: [60/79]	Time 0.053 (0.403)	Loss 0.6653 (0.5783)	Accuracy 0.6094 (0.6839)
# Batch: [70/79]	Time 0.033 (0.405)	Loss 0.6035 (0.5793)	Accuracy 0.6875 (0.6835)
# ----------
# Avg validation loss: 0.5779397554397583 	 Accuracy: 0.694
# --------------------
# Epoch 1/20	Time 34.268 sec (36.461 sec)
# --------------------
# Epoch: 2/20
# Batch: [0/79]	Time 2.043 (2.043)	Loss 0.6160 (0.6160)	Accuracy 0.5469 (0.5469)
# Batch: [10/79]	Time 0.031 (0.455)	Loss 0.6226 (0.5589)	Accuracy 0.6094 (0.6818)
# Batch: [20/79]	Time 1.280 (0.444)	Loss 0.4849 (0.5523)	Accuracy 0.7812 (0.7009)
# Batch: [30/79]	Time 0.030 (0.399)	Loss 0.5785 (0.5561)	Accuracy 0.7188 (0.7001)
# Batch: [40/79]	Time 1.242 (0.405)	Loss 0.5211 (0.5595)	Accuracy 0.7188 (0.6989)
# Batch: [50/79]	Time 0.016 (0.391)	Loss 0.5707 (0.5620)	Accuracy 0.7031 (0.6918)
# Batch: [60/79]	Time 1.196 (0.395)	Loss 0.6423 (0.5626)	Accuracy 0.6406 (0.6924)
# Batch: [70/79]	Time 0.037 (0.383)	Loss 0.6188 (0.5637)	Accuracy 0.6094 (0.6910)
# ----------
# Avg validation loss: 0.5929315748214722 	 Accuracy: 0.654
# --------------------
# Epoch 2/20	Time 33.040 sec (35.320 sec)
# --------------------
# Epoch: 3/20
# Batch: [0/79]	Time 2.114 (2.114)	Loss 0.5863 (0.5863)	Accuracy 0.6562 (0.6562)
# Batch: [10/79]	Time 0.035 (0.460)	Loss 0.5405 (0.5681)	Accuracy 0.7344 (0.6946)
# Batch: [20/79]	Time 1.241 (0.444)	Loss 0.5393 (0.5732)	Accuracy 0.7344 (0.6868)
# Batch: [30/79]	Time 0.033 (0.400)	Loss 0.6553 (0.5750)	Accuracy 0.6562 (0.6870)
# Batch: [40/79]	Time 1.262 (0.407)	Loss 0.5301 (0.5629)	Accuracy 0.7031 (0.6947)
# Batch: [50/79]	Time 0.034 (0.388)	Loss 0.5535 (0.5629)	Accuracy 0.6875 (0.6955)
# Batch: [60/79]	Time 1.209 (0.393)	Loss 0.6603 (0.5617)	Accuracy 0.5312 (0.6939)
# Batch: [70/79]	Time 0.031 (0.381)	Loss 0.4332 (0.5579)	Accuracy 0.7812 (0.6952)
# ----------
# Avg validation loss: 0.566143768787384 	 Accuracy: 0.694
# --------------------
# Epoch 3/20	Time 32.847 sec (34.702 sec)
# --------------------
# Epoch: 4/20
# Batch: [0/79]	Time 2.006 (2.006)	Loss 0.5811 (0.5811)	Accuracy 0.7031 (0.7031)
# Batch: [10/79]	Time 0.023 (0.458)	Loss 0.5560 (0.5631)	Accuracy 0.6562 (0.7031)
# Batch: [20/79]	Time 1.247 (0.444)	Loss 0.5352 (0.5586)	Accuracy 0.6875 (0.7009)
# Batch: [30/79]	Time 0.014 (0.399)	Loss 0.4689 (0.5534)	Accuracy 0.8281 (0.7122)
# Batch: [40/79]	Time 1.238 (0.406)	Loss 0.6099 (0.5504)	Accuracy 0.6719 (0.7119)
# Batch: [50/79]	Time 0.028 (0.388)	Loss 0.5815 (0.5558)	Accuracy 0.6562 (0.7065)
# Batch: [60/79]	Time 1.247 (0.393)	Loss 0.5500 (0.5562)	Accuracy 0.7500 (0.7062)
# Batch: [70/79]	Time 0.033 (0.381)	Loss 0.5621 (0.5560)	Accuracy 0.6875 (0.7027)
# ----------
# Avg validation loss: 0.7061448632478714 	 Accuracy: 0.616
# --------------------
# Epoch 4/20	Time 32.864 sec (34.334 sec)
# --------------------
# Epoch: 5/20
# Batch: [0/79]	Time 2.029 (2.029)	Loss 0.5503 (0.5503)	Accuracy 0.7031 (0.7031)
# Batch: [10/79]	Time 0.074 (0.458)	Loss 0.5349 (0.5622)	Accuracy 0.7188 (0.6861)
# Batch: [20/79]	Time 1.353 (0.447)	Loss 0.6453 (0.5656)	Accuracy 0.5938 (0.6845)
# Batch: [30/79]	Time 0.080 (0.400)	Loss 0.7114 (0.5620)	Accuracy 0.5938 (0.6890)
# Batch: [40/79]	Time 1.334 (0.407)	Loss 0.6066 (0.5572)	Accuracy 0.6562 (0.6909)
# Batch: [50/79]	Time 0.053 (0.388)	Loss 0.5669 (0.5546)	Accuracy 0.7344 (0.6949)
# Batch: [60/79]	Time 1.300 (0.394)	Loss 0.6455 (0.5555)	Accuracy 0.5938 (0.6944)
# Batch: [70/79]	Time 0.020 (0.380)	Loss 0.4935 (0.5524)	Accuracy 0.7812 (0.6987)
# ----------
# Avg validation loss: 0.5778374314308167 	 Accuracy: 0.684
# --------------------
# Epoch 5/20	Time 32.793 sec (34.077 sec)
# --------------------
# Epoch: 6/20
# Batch: [0/79]	Time 2.107 (2.107)	Loss 0.5646 (0.5646)	Accuracy 0.6719 (0.6719)
# Batch: [10/79]	Time 0.036 (0.462)	Loss 0.4809 (0.5439)	Accuracy 0.7031 (0.7017)
# Batch: [20/79]	Time 1.301 (0.454)	Loss 0.6187 (0.5674)	Accuracy 0.6562 (0.6905)
# Batch: [30/79]	Time 0.044 (0.403)	Loss 0.6538 (0.5628)	Accuracy 0.6719 (0.6956)
# Batch: [40/79]	Time 1.322 (0.410)	Loss 0.6274 (0.5621)	Accuracy 0.6406 (0.6959)
# Batch: [50/79]	Time 0.055 (0.391)	Loss 0.4793 (0.5590)	Accuracy 0.7812 (0.7007)
# Batch: [60/79]	Time 1.334 (0.396)	Loss 0.3980 (0.5559)	Accuracy 0.8438 (0.7021)
# Batch: [70/79]	Time 0.030 (0.382)	Loss 0.6684 (0.5518)	Accuracy 0.5781 (0.7038)
# ----------
# Avg validation loss: 0.5663743579387664 	 Accuracy: 0.686
# --------------------
# Epoch 6/20	Time 32.884 sec (33.907 sec)
# --------------------
# Epoch: 7/20
# Batch: [0/79]	Time 2.120 (2.120)	Loss 0.4060 (0.4060)	Accuracy 0.7969 (0.7969)
# Batch: [10/79]	Time 0.052 (0.462)	Loss 0.5448 (0.5432)	Accuracy 0.7500 (0.7074)
# Batch: [20/79]	Time 1.305 (0.443)	Loss 0.5959 (0.5528)	Accuracy 0.6094 (0.7016)
# Batch: [30/79]	Time 0.051 (0.397)	Loss 0.5288 (0.5715)	Accuracy 0.7500 (0.6880)
# Batch: [40/79]	Time 1.332 (0.405)	Loss 0.4820 (0.5672)	Accuracy 0.7188 (0.6947)
# Batch: [50/79]	Time 0.061 (0.385)	Loss 0.4467 (0.5638)	Accuracy 0.7656 (0.6982)
# Batch: [60/79]	Time 1.297 (0.391)	Loss 0.5234 (0.5630)	Accuracy 0.7031 (0.6975)
# Batch: [70/79]	Time 0.051 (0.378)	Loss 0.6259 (0.5593)	Accuracy 0.6719 (0.7016)
# ----------
# Avg validation loss: 0.5983122038841248 	 Accuracy: 0.648
# --------------------
# Epoch 7/20	Time 32.562 sec (33.739 sec)
# --------------------
# Epoch: 8/20
# Batch: [0/79]	Time 2.117 (2.117)	Loss 0.4532 (0.4532)	Accuracy 0.7500 (0.7500)
# Batch: [10/79]	Time 0.072 (0.454)	Loss 0.4343 (0.5308)	Accuracy 0.7812 (0.7159)
# Batch: [20/79]	Time 1.270 (0.440)	Loss 0.6268 (0.5587)	Accuracy 0.5938 (0.6942)
# Batch: [30/79]	Time 0.059 (0.395)	Loss 0.5329 (0.5520)	Accuracy 0.7344 (0.6971)
# Batch: [40/79]	Time 1.279 (0.403)	Loss 0.6100 (0.5485)	Accuracy 0.7188 (0.7039)
# Batch: [50/79]	Time 0.062 (0.384)	Loss 0.4772 (0.5478)	Accuracy 0.8281 (0.7053)
# Batch: [60/79]	Time 1.295 (0.390)	Loss 0.5500 (0.5462)	Accuracy 0.7031 (0.7065)
# Batch: [70/79]	Time 0.052 (0.378)	Loss 0.6247 (0.5487)	Accuracy 0.6406 (0.7060)
# ----------
# Avg validation loss: 0.5571697463989258 	 Accuracy: 0.69
# --------------------
# Epoch 8/20	Time 32.611 sec (33.614 sec)
# --------------------
# Epoch: 9/20
# Batch: [0/79]	Time 2.050 (2.050)	Loss 0.5124 (0.5124)	Accuracy 0.6562 (0.6562)
# Batch: [10/79]	Time 0.072 (0.457)	Loss 0.5662 (0.5574)	Accuracy 0.7188 (0.6847)
# Batch: [20/79]	Time 1.281 (0.442)	Loss 0.6715 (0.5552)	Accuracy 0.5625 (0.6853)
# Batch: [30/79]	Time 0.057 (0.396)	Loss 0.5161 (0.5491)	Accuracy 0.6875 (0.6900)
# Batch: [40/79]	Time 1.282 (0.403)	Loss 0.5281 (0.5458)	Accuracy 0.7812 (0.6959)
# Batch: [50/79]	Time 0.045 (0.384)	Loss 0.5697 (0.5476)	Accuracy 0.6406 (0.6952)
# Batch: [60/79]	Time 1.309 (0.391)	Loss 0.4948 (0.5450)	Accuracy 0.7969 (0.7011)
# Batch: [70/79]	Time 0.049 (0.377)	Loss 0.5282 (0.5446)	Accuracy 0.7656 (0.7047)
# ----------
# Avg validation loss: 0.5561363706588746 	 Accuracy: 0.694
# --------------------
# Epoch 9/20	Time 32.649 sec (33.517 sec)
# --------------------
# Epoch: 10/20
# Batch: [0/79]	Time 2.064 (2.064)	Loss 0.4305 (0.4305)	Accuracy 0.7969 (0.7969)
# Batch: [10/79]	Time 0.031 (0.464)	Loss 0.5293 (0.5645)	Accuracy 0.7344 (0.6960)
# Batch: [20/79]	Time 1.244 (0.442)	Loss 0.4904 (0.5618)	Accuracy 0.7500 (0.7009)
# Batch: [30/79]	Time 0.049 (0.399)	Loss 0.5053 (0.5512)	Accuracy 0.7188 (0.7046)
# Batch: [40/79]	Time 1.327 (0.405)	Loss 0.7195 (0.5507)	Accuracy 0.5625 (0.7020)
# Batch: [50/79]	Time 0.051 (0.386)	Loss 0.5838 (0.5466)	Accuracy 0.6719 (0.7037)
# Batch: [60/79]	Time 1.227 (0.391)	Loss 0.6128 (0.5440)	Accuracy 0.6719 (0.7065)
# Batch: [70/79]	Time 0.026 (0.380)	Loss 0.5669 (0.5445)	Accuracy 0.6562 (0.7064)
# ----------
# Avg validation loss: 0.5744804394245148 	 Accuracy: 0.674
# --------------------
# Epoch 10/20	Time 32.747 sec (33.447 sec)
# --------------------
# Epoch: 11/20
# Batch: [0/79]	Time 2.058 (2.058)	Loss 0.6026 (0.6026)	Accuracy 0.5938 (0.5938)
# Batch: [10/79]	Time 0.039 (0.458)	Loss 0.5779 (0.5583)	Accuracy 0.7344 (0.6875)
# Batch: [20/79]	Time 1.352 (0.443)	Loss 0.5967 (0.5553)	Accuracy 0.6875 (0.7009)
# Batch: [30/79]	Time 0.067 (0.395)	Loss 0.5558 (0.5500)	Accuracy 0.7031 (0.6991)
# Batch: [40/79]	Time 1.248 (0.403)	Loss 0.4877 (0.5452)	Accuracy 0.7500 (0.7043)
# Batch: [50/79]	Time 0.076 (0.383)	Loss 0.5523 (0.5456)	Accuracy 0.6875 (0.7031)
# Batch: [60/79]	Time 1.308 (0.390)	Loss 0.4821 (0.5465)	Accuracy 0.7500 (0.7001)
# Batch: [70/79]	Time 0.081 (0.377)	Loss 0.6183 (0.5452)	Accuracy 0.6094 (0.7022)
# ----------
# Avg validation loss: 0.5552363872528077 	 Accuracy: 0.708
# --------------------
# Epoch 11/20	Time 32.533 sec (33.371 sec)
# --------------------
# Epoch: 12/20
# Batch: [0/79]	Time 2.038 (2.038)	Loss 0.5967 (0.5967)	Accuracy 0.6562 (0.6562)
# Batch: [10/79]	Time 0.061 (0.458)	Loss 0.5650 (0.5308)	Accuracy 0.7344 (0.7074)
# Batch: [20/79]	Time 1.317 (0.445)	Loss 0.5188 (0.5353)	Accuracy 0.7500 (0.7091)
# Batch: [30/79]	Time 0.040 (0.396)	Loss 0.6397 (0.5428)	Accuracy 0.5938 (0.7051)
# Batch: [40/79]	Time 1.291 (0.403)	Loss 0.4954 (0.5486)	Accuracy 0.7344 (0.7043)
# Batch: [50/79]	Time 0.056 (0.383)	Loss 0.5223 (0.5473)	Accuracy 0.6875 (0.7001)
# Batch: [60/79]	Time 1.270 (0.391)	Loss 0.5471 (0.5464)	Accuracy 0.7344 (0.6995)
# Batch: [70/79]	Time 0.021 (0.378)	Loss 0.5700 (0.5441)	Accuracy 0.7031 (0.7025)
# ----------
# Avg validation loss: 0.580942521572113 	 Accuracy: 0.668
# --------------------
# Epoch 12/20	Time 32.613 sec (33.313 sec)
# --------------------
# Epoch: 13/20
# Batch: [0/79]	Time 2.148 (2.148)	Loss 0.5934 (0.5934)	Accuracy 0.6406 (0.6406)
# Batch: [10/79]	Time 0.049 (0.456)	Loss 0.5431 (0.5359)	Accuracy 0.6719 (0.7074)
# Batch: [20/79]	Time 1.313 (0.443)	Loss 0.5196 (0.5421)	Accuracy 0.7656 (0.7046)
# Batch: [30/79]	Time 0.055 (0.396)	Loss 0.6830 (0.5650)	Accuracy 0.6250 (0.6905)
# Batch: [40/79]	Time 1.309 (0.403)	Loss 0.4578 (0.5536)	Accuracy 0.8125 (0.7031)
# Batch: [50/79]	Time 0.024 (0.383)	Loss 0.5081 (0.5550)	Accuracy 0.7344 (0.7034)
# Batch: [60/79]	Time 1.312 (0.392)	Loss 0.5939 (0.5532)	Accuracy 0.7031 (0.7031)
# Batch: [70/79]	Time 0.039 (0.379)	Loss 0.5025 (0.5507)	Accuracy 0.7656 (0.7062)
# ----------
# Avg validation loss: 0.5895365576744079 	 Accuracy: 0.658
# --------------------
# Epoch 13/20	Time 32.686 sec (33.268 sec)
# --------------------
# Epoch: 14/20
# Batch: [0/79]	Time 2.004 (2.004)	Loss 0.6536 (0.6536)	Accuracy 0.6094 (0.6094)
# Batch: [10/79]	Time 0.057 (0.456)	Loss 0.5146 (0.5532)	Accuracy 0.7344 (0.7131)
# Batch: [20/79]	Time 1.321 (0.440)	Loss 0.6753 (0.5535)	Accuracy 0.6406 (0.7001)
# Batch: [30/79]	Time 0.055 (0.396)	Loss 0.5362 (0.5518)	Accuracy 0.7656 (0.7067)
# Batch: [40/79]	Time 1.383 (0.404)	Loss 0.4658 (0.5485)	Accuracy 0.7656 (0.7016)
# Batch: [50/79]	Time 0.033 (0.383)	Loss 0.5485 (0.5389)	Accuracy 0.7031 (0.7117)
# Batch: [60/79]	Time 1.262 (0.389)	Loss 0.5309 (0.5376)	Accuracy 0.7031 (0.7121)
# Batch: [70/79]	Time 0.054 (0.376)	Loss 0.4975 (0.5361)	Accuracy 0.7344 (0.7141)
# ----------
# Avg validation loss: 0.5715102882385253 	 Accuracy: 0.694
# --------------------
# Epoch 14/20	Time 32.471 sec (33.215 sec)
# --------------------
# Epoch: 15/20
# Batch: [0/79]	Time 2.041 (2.041)	Loss 0.6138 (0.6138)	Accuracy 0.6719 (0.6719)
# Batch: [10/79]	Time 0.057 (0.455)	Loss 0.5293 (0.5508)	Accuracy 0.6875 (0.7003)
# Batch: [20/79]	Time 1.297 (0.443)	Loss 0.5384 (0.5564)	Accuracy 0.7656 (0.6942)
# Batch: [30/79]	Time 0.036 (0.397)	Loss 0.4980 (0.5677)	Accuracy 0.7656 (0.6910)
# Batch: [40/79]	Time 1.360 (0.406)	Loss 0.4513 (0.5555)	Accuracy 0.7500 (0.6982)
# Batch: [50/79]	Time 0.047 (0.384)	Loss 0.4786 (0.5524)	Accuracy 0.7500 (0.7022)
# Batch: [60/79]	Time 1.336 (0.392)	Loss 0.4800 (0.5482)	Accuracy 0.7812 (0.7054)
# Batch: [70/79]	Time 0.047 (0.378)	Loss 0.5508 (0.5479)	Accuracy 0.7188 (0.7055)
# ----------
# Avg validation loss: 0.5534768590927124 	 Accuracy: 0.706
# --------------------
# Epoch 15/20	Time 32.567 sec (33.174 sec)
# --------------------
# Epoch: 16/20
# Batch: [0/79]	Time 2.036 (2.036)	Loss 0.4774 (0.4774)	Accuracy 0.8125 (0.8125)
# Batch: [10/79]	Time 0.048 (0.454)	Loss 0.5505 (0.5246)	Accuracy 0.6719 (0.7386)
# Batch: [20/79]	Time 1.296 (0.442)	Loss 0.4584 (0.5523)	Accuracy 0.8281 (0.7061)
# Batch: [30/79]	Time 0.036 (0.397)	Loss 0.6527 (0.5439)	Accuracy 0.5625 (0.7097)
# Batch: [40/79]	Time 1.364 (0.407)	Loss 0.5636 (0.5390)	Accuracy 0.7031 (0.7111)
# Batch: [50/79]	Time 0.035 (0.386)	Loss 0.5039 (0.5410)	Accuracy 0.7500 (0.7105)
# Batch: [60/79]	Time 1.297 (0.393)	Loss 0.6523 (0.5440)	Accuracy 0.6250 (0.7088)
# Batch: [70/79]	Time 0.033 (0.381)	Loss 0.5009 (0.5424)	Accuracy 0.7188 (0.7088)
# ----------
# Avg validation loss: 0.5545569732189178 	 Accuracy: 0.698
# --------------------
# Epoch 16/20	Time 32.684 sec (33.145 sec)
# --------------------
# Epoch: 17/20
# Batch: [0/79]	Time 2.147 (2.147)	Loss 0.5205 (0.5205)	Accuracy 0.6875 (0.6875)
# Batch: [10/79]	Time 0.030 (0.468)	Loss 0.4829 (0.5397)	Accuracy 0.7656 (0.7173)
# Batch: [20/79]	Time 1.249 (0.444)	Loss 0.6545 (0.5486)	Accuracy 0.5469 (0.7016)
# Batch: [30/79]	Time 0.045 (0.404)	Loss 0.6029 (0.5445)	Accuracy 0.7188 (0.7082)
# Batch: [40/79]	Time 1.337 (0.409)	Loss 0.5337 (0.5431)	Accuracy 0.7500 (0.7134)
# Batch: [50/79]	Time 0.056 (0.388)	Loss 0.6083 (0.5448)	Accuracy 0.6875 (0.7117)
# Batch: [60/79]	Time 1.290 (0.395)	Loss 0.5002 (0.5443)	Accuracy 0.7031 (0.7080)
# Batch: [70/79]	Time 0.045 (0.382)	Loss 0.5587 (0.5410)	Accuracy 0.7188 (0.7117)
# ----------
# Avg validation loss: 0.5575753803253174 	 Accuracy: 0.704
# --------------------
# Epoch 17/20	Time 32.970 sec (33.136 sec)
# --------------------
# Epoch: 18/20
# Batch: [0/79]	Time 2.087 (2.087)	Loss 0.4900 (0.4900)	Accuracy 0.7656 (0.7656)
# Batch: [10/79]	Time 0.017 (0.460)	Loss 0.5751 (0.5450)	Accuracy 0.6875 (0.6989)
# Batch: [20/79]	Time 1.401 (0.448)	Loss 0.6079 (0.5450)	Accuracy 0.6719 (0.6979)
# Batch: [30/79]	Time 0.040 (0.398)	Loss 0.6607 (0.5574)	Accuracy 0.6719 (0.6941)
# Batch: [40/79]	Time 1.336 (0.407)	Loss 0.5842 (0.5536)	Accuracy 0.7188 (0.7035)
# Batch: [50/79]	Time 0.031 (0.386)	Loss 0.4975 (0.5494)	Accuracy 0.7500 (0.7034)
# Batch: [60/79]	Time 1.228 (0.392)	Loss 0.5009 (0.5494)	Accuracy 0.7344 (0.7072)
# Batch: [70/79]	Time 0.034 (0.379)	Loss 0.6017 (0.5464)	Accuracy 0.6406 (0.7093)
# ----------
# Avg validation loss: 0.564834819316864 	 Accuracy: 0.696
# --------------------
# Epoch 18/20	Time 32.655 sec (33.110 sec)
# --------------------
# Epoch: 19/20
# Batch: [0/79]	Time 2.264 (2.264)	Loss 0.5963 (0.5963)	Accuracy 0.7500 (0.7500)
# Batch: [10/79]	Time 0.027 (0.472)	Loss 0.5690 (0.5668)	Accuracy 0.6406 (0.6918)
# Batch: [20/79]	Time 1.338 (0.455)	Loss 0.4818 (0.5587)	Accuracy 0.7188 (0.6979)
# Batch: [30/79]	Time 0.090 (0.403)	Loss 0.5617 (0.5617)	Accuracy 0.6250 (0.6935)
# Batch: [40/79]	Time 1.147 (0.410)	Loss 0.5365 (0.5527)	Accuracy 0.6875 (0.7035)
# Batch: [50/79]	Time 0.245 (0.392)	Loss 0.6114 (0.5497)	Accuracy 0.6562 (0.7047)
# Batch: [60/79]	Time 1.065 (0.393)	Loss 0.5222 (0.5487)	Accuracy 0.7031 (0.7052)
# Batch: [70/79]	Time 0.267 (0.383)	Loss 0.5547 (0.5455)	Accuracy 0.6562 (0.7099)
# ----------
# Avg validation loss: 0.5520205311775207 	 Accuracy: 0.698
# --------------------
# Epoch 19/20	Time 32.731 sec (33.091 sec)
# --------------------

# %%
plt.figure(figsize=(20,20))
plt.subplot(221)
plt.title('training classification loss')
plt.plot(train_losses)
plt.subplot(222)
plt.title('training accuracy')
plt.plot(train_accs)
plt.subplot(223)
plt.title('validation loss')
plt.plot(val_losses)
plt.subplot(224)
plt.title('validation accuracy')
plt.plot(val_accs)
plt.legend()
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
test_loss, test_acc = validate_classifier_epoch(advtest_loader, laftr_encoder, classifier,
                                 adv_criterion, device)
# Out:
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([52])) that is different to the input size (torch.Size([52, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))

# %%
test_loss, test_acc
# Out:
# (0.5383307013511658, 0.708)
