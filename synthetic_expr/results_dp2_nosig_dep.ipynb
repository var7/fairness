# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import argparse

plt.switch_backend('agg')
# In[3]:
font = {'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torchvision import transforms, utils, models, datasets
from torch.utils.data import Dataset, DataLoader

# %%
from synthetic_dataloader import *


from synthetic_utils import *


# In[5]:


from trainer_dataloader import *
from networks import *
from losses import *


# In[6]:

# %%
input_size = 96
batch_size = 64
num_workers = 4


cuda = False
pin_memory = False
if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    cuda = True
    cudnn.benchmark = True
    pin_memory = True
else:
    device = torch.device("cpu")

print('Device set: {}'.format(device))


# In[8]:


data_transforms = {
        'train': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ]),
        'val': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
}
# Out:
# Device set: cuda

# %%
# if independent:
# DATA_PATH = '/home/s1791387/diss/gen_shapes/'
# else:
DATA_PATH = '/home/s1791387/diss/dependent_gen/'
print(DATA_PATH)
TRAIN_PATH = os.path.join(DATA_PATH, 'train')
VAL_PATH = os.path.join(DATA_PATH, 'valid')
TEST_PATH = os.path.join(DATA_PATH, 'test')
# Out:
# /home/s1791387/diss/dependent_gen/

# %%
train_df = datasets.ImageFolder(root=TRAIN_PATH, transform=data_transforms['train'])
val_df = datasets.ImageFolder(root=VAL_PATH, transform=data_transforms['val'])
test_df = datasets.ImageFolder(root=TEST_PATH, transform=data_transforms['val'])

# %%
LOAD_PATH = './dp2_nosig_dep/2/weights/encoder_493_0.79.pth'

# %%
laftr_encoder = torch.load(LOAD_PATH)

# %%
gender_train = GenderDataset(train_df)
gender_valid = GenderDataset(val_df)

# %%
advtrain_loader = DataLoader(gender_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
advval_loader = DataLoader(gender_valid, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)

# %%
adversary = ClassNet()

adv_criterion = nn.BCELoss()
opt_adv = optim.Adam(adversary.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler_adv = lr_scheduler.StepLR(optimizer=opt_adv, gamma=0.99, step_size=1)

# %%
num_epochs = 20
train_losses = []
train_accs = []
val_losses = []
val_accs = []
epoch_time = AverageMeter()
ep_end = time.time()
for epoch in range(0, num_epochs):
        print('Epoch: {}/{}'.format(epoch, num_epochs))
        scheduler_adv.step()
        # train
        train_loss, train_acc = train_classifier_epoch(advtrain_loader, laftr_encoder,
                                adversary, opt_adv, adv_criterion, device)
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        # validate
        print('-'*10)
        val_loss, val_acc = validate_classifier_epoch(advval_loader, laftr_encoder, adversary,
                                 adv_criterion, device)

        print('Avg validation loss: {} \t Accuracy: {}'.format(val_loss, val_acc))
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        
        print('-' * 20)
        epoch_time.update(time.time() - ep_end)
        ep_end = time.time()
        print('Epoch {}/{}\t'
              'Time {epoch_time.val:.3f} sec ({epoch_time.avg:.3f} sec)'.format(epoch, num_epochs, epoch_time=epoch_time))
        print('-'*20)
# Out:
# Epoch: 0/20
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/79]	Time 11.248 (11.248)	Loss 2.9858 (2.9858)	Accuracy 0.4844 (0.4844)
# Batch: [10/79]	Time 0.275 (2.016)	Loss 0.9927 (1.6657)	Accuracy 0.5781 (0.5341)
# Batch: [20/79]	Time 5.837 (1.894)	Loss 0.8010 (1.2388)	Accuracy 0.5000 (0.5342)
# Batch: [30/79]	Time 0.362 (1.685)	Loss 0.6180 (1.0431)	Accuracy 0.6094 (0.5600)
# Batch: [40/79]	Time 5.876 (1.734)	Loss 0.5545 (0.9217)	Accuracy 0.7969 (0.6033)
# Batch: [50/79]	Time 0.089 (1.662)	Loss 0.5305 (0.8449)	Accuracy 0.8125 (0.6419)
# Batch: [60/79]	Time 5.294 (1.686)	Loss 0.4474 (0.7880)	Accuracy 0.8438 (0.6678)
# Batch: [70/79]	Time 0.104 (1.634)	Loss 0.5352 (0.7432)	Accuracy 0.6562 (0.6873)
# ----------
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Avg validation loss: 0.4227296385765076 	 Accuracy: 0.88
# --------------------
# Epoch 0/20	Time 145.683 sec (145.683 sec)
# --------------------
# Epoch: 1/20
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([52])) that is different to the input size (torch.Size([52, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/79]	Time 11.900 (11.900)	Loss 0.4567 (0.4567)	Accuracy 0.8281 (0.8281)
# Batch: [10/79]	Time 0.079 (2.089)	Loss 0.4169 (0.4234)	Accuracy 0.8906 (0.8523)
# Batch: [20/79]	Time 5.098 (1.929)	Loss 0.4368 (0.4251)	Accuracy 0.8281 (0.8452)
# Batch: [30/79]	Time 0.162 (1.727)	Loss 0.3883 (0.4200)	Accuracy 0.8594 (0.8468)
# Batch: [40/79]	Time 5.807 (1.771)	Loss 0.3395 (0.4091)	Accuracy 0.8906 (0.8495)
# Batch: [50/79]	Time 0.182 (1.688)	Loss 0.3688 (0.4067)	Accuracy 0.8750 (0.8496)
# Batch: [60/79]	Time 5.348 (1.699)	Loss 0.3423 (0.4027)	Accuracy 0.8594 (0.8522)
# Batch: [70/79]	Time 0.172 (1.642)	Loss 0.3184 (0.3977)	Accuracy 0.9219 (0.8530)
# ----------
# Avg validation loss: 0.3433031725883484 	 Accuracy: 0.88
# --------------------
# Epoch 1/20	Time 146.220 sec (145.951 sec)
# --------------------
# Epoch: 2/20
# Batch: [0/79]	Time 11.752 (11.752)	Loss 0.3564 (0.3564)	Accuracy 0.8594 (0.8594)
# Batch: [10/79]	Time 0.124 (2.036)	Loss 0.3139 (0.3281)	Accuracy 0.8906 (0.8849)
# Batch: [20/79]	Time 4.925 (1.917)	Loss 0.3448 (0.3357)	Accuracy 0.8281 (0.8728)
# Batch: [30/79]	Time 0.116 (1.769)	Loss 0.3123 (0.3413)	Accuracy 0.9062 (0.8614)
# Batch: [40/79]	Time 5.665 (1.802)	Loss 0.3918 (0.3442)	Accuracy 0.8281 (0.8609)
# Batch: [50/79]	Time 0.118 (1.717)	Loss 0.3581 (0.3418)	Accuracy 0.8281 (0.8627)
# Batch: [60/79]	Time 4.814 (1.710)	Loss 0.3242 (0.3378)	Accuracy 0.8438 (0.8653)
# Batch: [70/79]	Time 0.160 (1.651)	Loss 0.3079 (0.3337)	Accuracy 0.8906 (0.8680)
# ----------
# Avg validation loss: 0.3030423572063446 	 Accuracy: 0.886
# --------------------
# Epoch 2/20	Time 146.806 sec (146.236 sec)
# --------------------
# Epoch: 3/20
# Batch: [0/79]	Time 11.424 (11.424)	Loss 0.3413 (0.3413)	Accuracy 0.8750 (0.8750)
# Batch: [10/79]	Time 0.102 (1.998)	Loss 0.2985 (0.3145)	Accuracy 0.8906 (0.8835)
# Batch: [20/79]	Time 5.333 (1.894)	Loss 0.2765 (0.3124)	Accuracy 0.9062 (0.8824)
# Batch: [30/79]	Time 0.106 (1.717)	Loss 0.3225 (0.3080)	Accuracy 0.9062 (0.8816)
# Batch: [40/79]	Time 6.352 (1.777)	Loss 0.2947 (0.3043)	Accuracy 0.8594 (0.8849)
# Batch: [50/79]	Time 0.171 (1.694)	Loss 0.2934 (0.3032)	Accuracy 0.8594 (0.8845)
# Batch: [60/79]	Time 5.564 (1.710)	Loss 0.2732 (0.3018)	Accuracy 0.8906 (0.8852)
# Batch: [70/79]	Time 0.058 (1.654)	Loss 0.2892 (0.3021)	Accuracy 0.8750 (0.8834)
# ----------
# Avg validation loss: 0.33582886481285096 	 Accuracy: 0.844
# --------------------
# Epoch 3/20	Time 147.049 sec (146.440 sec)
# --------------------
# Epoch: 4/20
# Batch: [0/79]	Time 10.542 (10.542)	Loss 0.3398 (0.3398)	Accuracy 0.8438 (0.8438)
# Batch: [10/79]	Time 0.195 (1.963)	Loss 0.4471 (0.3261)	Accuracy 0.8125 (0.8452)
# Batch: [20/79]	Time 5.406 (1.854)	Loss 0.3054 (0.3135)	Accuracy 0.8750 (0.8534)
# Batch: [30/79]	Time 0.282 (1.674)	Loss 0.2006 (0.3058)	Accuracy 0.9219 (0.8609)
# Batch: [40/79]	Time 5.301 (1.724)	Loss 0.2955 (0.2992)	Accuracy 0.8906 (0.8678)
# Batch: [50/79]	Time 1.068 (1.658)	Loss 0.2262 (0.2935)	Accuracy 0.9375 (0.8707)
# Batch: [60/79]	Time 3.310 (1.652)	Loss 0.3173 (0.2928)	Accuracy 0.8438 (0.8709)
# Batch: [70/79]	Time 0.960 (1.617)	Loss 0.3230 (0.2952)	Accuracy 0.9062 (0.8724)
# ----------
# Avg validation loss: 0.2664918838739395 	 Accuracy: 0.882
# --------------------
# Epoch 4/20	Time 143.796 sec (145.911 sec)
# --------------------
# Epoch: 5/20
# Batch: [0/79]	Time 10.355 (10.355)	Loss 0.2965 (0.2965)	Accuracy 0.9062 (0.9062)
# Batch: [10/79]	Time 0.131 (1.972)	Loss 0.2540 (0.2836)	Accuracy 0.8594 (0.8963)
# Batch: [20/79]	Time 5.478 (1.871)	Loss 0.2487 (0.2713)	Accuracy 0.8750 (0.8943)
# Batch: [30/79]	Time 0.094 (1.686)	Loss 0.3177 (0.2648)	Accuracy 0.8594 (0.8962)
# Batch: [40/79]	Time 5.797 (1.749)	Loss 0.3249 (0.2670)	Accuracy 0.8594 (0.8910)
# Batch: [50/79]	Time 0.148 (1.660)	Loss 0.1994 (0.2695)	Accuracy 0.9375 (0.8885)
# Batch: [60/79]	Time 4.240 (1.685)	Loss 0.3037 (0.2691)	Accuracy 0.8906 (0.8901)
# Batch: [70/79]	Time 0.161 (1.628)	Loss 0.3292 (0.2660)	Accuracy 0.8594 (0.8922)
# ----------
# Avg validation loss: 0.2563171682357788 	 Accuracy: 0.892
# --------------------
# Epoch 5/20	Time 144.992 sec (145.758 sec)
# --------------------
# Epoch: 6/20
# Batch: [0/79]	Time 10.334 (10.334)	Loss 0.2201 (0.2201)	Accuracy 0.9688 (0.9688)
# Batch: [10/79]	Time 0.099 (1.976)	Loss 0.2545 (0.2723)	Accuracy 0.9219 (0.8949)
# Batch: [20/79]	Time 5.764 (1.882)	Loss 0.2514 (0.2712)	Accuracy 0.9062 (0.8936)
# Batch: [30/79]	Time 0.146 (1.691)	Loss 0.2499 (0.2701)	Accuracy 0.9062 (0.8911)
# Batch: [40/79]	Time 6.409 (1.754)	Loss 0.2712 (0.2627)	Accuracy 0.8594 (0.8941)
# Batch: [50/79]	Time 0.152 (1.666)	Loss 0.1568 (0.2639)	Accuracy 0.9531 (0.8919)
# Batch: [60/79]	Time 5.179 (1.686)	Loss 0.2962 (0.2635)	Accuracy 0.8750 (0.8919)
# Batch: [70/79]	Time 0.100 (1.623)	Loss 0.3026 (0.2648)	Accuracy 0.8125 (0.8922)
# ----------
# Avg validation loss: 0.24758060383796693 	 Accuracy: 0.898
# --------------------
# Epoch 6/20	Time 144.438 sec (145.569 sec)
# --------------------
# Epoch: 7/20
# Batch: [0/79]	Time 10.076 (10.076)	Loss 0.2502 (0.2502)	Accuracy 0.9062 (0.9062)
# Batch: [10/79]	Time 0.261 (1.923)	Loss 0.1957 (0.2681)	Accuracy 0.9062 (0.8892)
# Batch: [20/79]	Time 5.086 (1.824)	Loss 0.3382 (0.2772)	Accuracy 0.8438 (0.8832)
# Batch: [30/79]	Time 0.495 (1.695)	Loss 0.2861 (0.2787)	Accuracy 0.8750 (0.8775)
# Batch: [40/79]	Time 3.514 (1.685)	Loss 0.2439 (0.2692)	Accuracy 0.9062 (0.8822)
# Batch: [50/79]	Time 0.739 (1.667)	Loss 0.2487 (0.2646)	Accuracy 0.9062 (0.8882)
# Batch: [60/79]	Time 1.295 (1.622)	Loss 0.2905 (0.2630)	Accuracy 0.9062 (0.8896)
# Batch: [70/79]	Time 0.792 (1.630)	Loss 0.2787 (0.2613)	Accuracy 0.8750 (0.8900)
# ----------
# Avg validation loss: 0.2361816394329071 	 Accuracy: 0.902
# --------------------
# Epoch 7/20	Time 143.895 sec (145.360 sec)
# --------------------
# Epoch: 8/20
# Batch: [0/79]	Time 10.113 (10.113)	Loss 0.2847 (0.2847)	Accuracy 0.8906 (0.8906)
# Batch: [10/79]	Time 0.129 (1.908)	Loss 0.2929 (0.2822)	Accuracy 0.9219 (0.8977)
# Batch: [20/79]	Time 5.133 (1.828)	Loss 0.2796 (0.2630)	Accuracy 0.8594 (0.9010)
# Batch: [30/79]	Time 0.200 (1.636)	Loss 0.2799 (0.2566)	Accuracy 0.8438 (0.8987)
# Batch: [40/79]	Time 4.563 (1.676)	Loss 0.2062 (0.2554)	Accuracy 0.9062 (0.8998)
# Batch: [50/79]	Time 0.129 (1.592)	Loss 0.3000 (0.2550)	Accuracy 0.8281 (0.8983)
# Batch: [60/79]	Time 3.319 (1.612)	Loss 0.2594 (0.2490)	Accuracy 0.8438 (0.9004)
# Batch: [70/79]	Time 0.094 (1.558)	Loss 0.2168 (0.2519)	Accuracy 0.9219 (0.8974)
# ----------
# Avg validation loss: 0.22535719633102416 	 Accuracy: 0.918
# --------------------
# Epoch 8/20	Time 139.600 sec (144.720 sec)
# --------------------
# Epoch: 9/20
# Batch: [0/79]	Time 10.700 (10.700)	Loss 0.2078 (0.2078)	Accuracy 0.8906 (0.8906)
# Batch: [10/79]	Time 0.164 (2.013)	Loss 0.2906 (0.2556)	Accuracy 0.8281 (0.8707)
# Batch: [20/79]	Time 5.616 (1.878)	Loss 0.2429 (0.2612)	Accuracy 0.8750 (0.8772)
# Batch: [30/79]	Time 0.091 (1.695)	Loss 0.3688 (0.2577)	Accuracy 0.8281 (0.8841)
# Batch: [40/79]	Time 5.718 (1.731)	Loss 0.2615 (0.2587)	Accuracy 0.8750 (0.8883)
# Batch: [50/79]	Time 0.130 (1.649)	Loss 0.2169 (0.2620)	Accuracy 0.8438 (0.8845)
# Batch: [60/79]	Time 5.149 (1.667)	Loss 0.2825 (0.2599)	Accuracy 0.8906 (0.8860)
# Batch: [70/79]	Time 0.099 (1.608)	Loss 0.2497 (0.2568)	Accuracy 0.9062 (0.8882)
# ----------
# Avg validation loss: 0.2287978547811508 	 Accuracy: 0.906
# --------------------
# Epoch 9/20	Time 143.528 sec (144.601 sec)
# --------------------
# Epoch: 10/20
# Batch: [0/79]	Time 9.932 (9.932)	Loss 0.1739 (0.1739)	Accuracy 0.9219 (0.9219)
# Batch: [10/79]	Time 0.104 (1.946)	Loss 0.2705 (0.2484)	Accuracy 0.8594 (0.8920)
# Batch: [20/79]	Time 5.592 (1.845)	Loss 0.1850 (0.2455)	Accuracy 0.9219 (0.8929)
# Batch: [30/79]	Time 0.116 (1.680)	Loss 0.1480 (0.2384)	Accuracy 0.9844 (0.9002)
# Batch: [40/79]	Time 5.697 (1.733)	Loss 0.4251 (0.2467)	Accuracy 0.8438 (0.8990)
# Batch: [50/79]	Time 0.171 (1.664)	Loss 0.2215 (0.2437)	Accuracy 0.9062 (0.9001)
# Batch: [60/79]	Time 4.810 (1.684)	Loss 0.2022 (0.2407)	Accuracy 0.9531 (0.9022)
# Batch: [70/79]	Time 0.213 (1.633)	Loss 0.2317 (0.2403)	Accuracy 0.9062 (0.9010)
# ----------
# Avg validation loss: 0.23005361461639404 	 Accuracy: 0.906
# --------------------
# Epoch 10/20	Time 140.185 sec (144.199 sec)
# --------------------
# Epoch: 11/20
# Batch: [0/79]	Time 6.734 (6.734)	Loss 0.2554 (0.2554)	Accuracy 0.8750 (0.8750)
# Batch: [10/79]	Time 0.032 (1.322)	Loss 0.4322 (0.2361)	Accuracy 0.8125 (0.9062)
# Batch: [20/79]	Time 4.191 (1.287)	Loss 0.1297 (0.2463)	Accuracy 0.9844 (0.8996)
# Batch: [30/79]	Time 0.057 (1.179)	Loss 0.2802 (0.2477)	Accuracy 0.8750 (0.8972)
# Batch: [40/79]	Time 4.199 (1.223)	Loss 0.2155 (0.2495)	Accuracy 0.9062 (0.8979)
# Batch: [50/79]	Time 0.066 (1.167)	Loss 0.2486 (0.2383)	Accuracy 0.9062 (0.9023)
# Batch: [60/79]	Time 4.126 (1.197)	Loss 0.3542 (0.2480)	Accuracy 0.7969 (0.8978)
# Batch: [70/79]	Time 0.059 (1.160)	Loss 0.2517 (0.2542)	Accuracy 0.8906 (0.8924)
# ----------
# Avg validation loss: 0.22756192088127136 	 Accuracy: 0.902
# --------------------
# Epoch 11/20	Time 104.258 sec (140.871 sec)
# --------------------
# Epoch: 12/20
# Batch: [0/79]	Time 7.049 (7.049)	Loss 0.2772 (0.2772)	Accuracy 0.8594 (0.8594)
# Batch: [10/79]	Time 0.186 (1.381)	Loss 0.2457 (0.2258)	Accuracy 0.8438 (0.9034)
# Batch: [20/79]	Time 3.728 (1.310)	Loss 0.1702 (0.2451)	Accuracy 0.9219 (0.8958)
# Batch: [30/79]	Time 0.530 (1.214)	Loss 0.2390 (0.2470)	Accuracy 0.9375 (0.8967)
# Batch: [40/79]	Time 4.038 (1.253)	Loss 0.2003 (0.2388)	Accuracy 0.9062 (0.9017)
# Batch: [50/79]	Time 0.907 (1.211)	Loss 0.2725 (0.2375)	Accuracy 0.8906 (0.9032)
# Batch: [60/79]	Time 3.202 (1.224)	Loss 0.2091 (0.2337)	Accuracy 0.9062 (0.9042)
# Batch: [70/79]	Time 1.544 (1.211)	Loss 0.3444 (0.2340)	Accuracy 0.8281 (0.9018)
# ----------
# Avg validation loss: 0.2264573390483856 	 Accuracy: 0.902
# --------------------
# Epoch 12/20	Time 106.826 sec (138.252 sec)
# --------------------
# Epoch: 13/20
# Batch: [0/79]	Time 7.014 (7.014)	Loss 0.2926 (0.2926)	Accuracy 0.8438 (0.8438)
# Batch: [10/79]	Time 0.114 (1.366)	Loss 0.1603 (0.2343)	Accuracy 0.9219 (0.8991)
# Batch: [20/79]	Time 4.094 (1.309)	Loss 0.2321 (0.2378)	Accuracy 0.8750 (0.8966)
# Batch: [30/79]	Time 0.149 (1.193)	Loss 0.1922 (0.2321)	Accuracy 0.9062 (0.8987)
# Batch: [40/79]	Time 4.251 (1.241)	Loss 0.1658 (0.2314)	Accuracy 0.9062 (0.9021)
# Batch: [50/79]	Time 0.112 (1.185)	Loss 0.1778 (0.2294)	Accuracy 0.9688 (0.9010)
# Batch: [60/79]	Time 3.901 (1.219)	Loss 0.1940 (0.2368)	Accuracy 0.9062 (0.8960)
# Batch: [70/79]	Time 0.130 (1.181)	Loss 0.2329 (0.2370)	Accuracy 0.8750 (0.8952)
# ----------
# Avg validation loss: 0.22325863778591157 	 Accuracy: 0.902
# --------------------
# Epoch 13/20	Time 105.970 sec (135.946 sec)
# --------------------
# Epoch: 14/20
# Batch: [0/79]	Time 7.227 (7.227)	Loss 0.2469 (0.2469)	Accuracy 0.9375 (0.9375)
# Batch: [10/79]	Time 0.143 (1.389)	Loss 0.2057 (0.2327)	Accuracy 0.9062 (0.9134)
# Batch: [20/79]	Time 3.729 (1.317)	Loss 0.2441 (0.2338)	Accuracy 0.8750 (0.9100)
# Batch: [30/79]	Time 0.502 (1.215)	Loss 0.2203 (0.2279)	Accuracy 0.8594 (0.9108)
# Batch: [40/79]	Time 3.907 (1.244)	Loss 0.2308 (0.2273)	Accuracy 0.9062 (0.9089)
# Batch: [50/79]	Time 0.811 (1.202)	Loss 0.1907 (0.2339)	Accuracy 0.9219 (0.9038)
# Batch: [60/79]	Time 3.413 (1.222)	Loss 0.2107 (0.2391)	Accuracy 0.8906 (0.9019)
# Batch: [70/79]	Time 1.222 (1.199)	Loss 0.2034 (0.2391)	Accuracy 0.9219 (0.9025)
# ----------
# Avg validation loss: 0.22793764686584472 	 Accuracy: 0.898
# --------------------
# Epoch 14/20	Time 106.188 sec (133.962 sec)
# --------------------
# Epoch: 15/20
# Batch: [0/79]	Time 7.243 (7.243)	Loss 0.3430 (0.3430)	Accuracy 0.8281 (0.8281)
# Batch: [10/79]	Time 0.084 (1.394)	Loss 0.2084 (0.2544)	Accuracy 0.8906 (0.8892)
# Batch: [20/79]	Time 4.105 (1.344)	Loss 0.2947 (0.2510)	Accuracy 0.9062 (0.8958)
# Batch: [30/79]	Time 0.085 (1.217)	Loss 0.2321 (0.2409)	Accuracy 0.9219 (0.9022)
# Batch: [40/79]	Time 4.529 (1.260)	Loss 0.2519 (0.2332)	Accuracy 0.9062 (0.9059)
# Batch: [50/79]	Time 0.115 (1.197)	Loss 0.2375 (0.2360)	Accuracy 0.8750 (0.9026)
# Batch: [60/79]	Time 4.326 (1.229)	Loss 0.2447 (0.2318)	Accuracy 0.8750 (0.9047)
# Batch: [70/79]	Time 0.125 (1.192)	Loss 0.1630 (0.2305)	Accuracy 0.9375 (0.9051)
# ----------
# Avg validation loss: 0.21203385317325593 	 Accuracy: 0.912
# --------------------
# Epoch 15/20	Time 106.323 sec (132.235 sec)
# --------------------
# Epoch: 16/20
# Batch: [0/79]	Time 6.950 (6.950)	Loss 0.3176 (0.3176)	Accuracy 0.8438 (0.8438)
# Batch: [10/79]	Time 0.221 (1.429)	Loss 0.2619 (0.2244)	Accuracy 0.8750 (0.9077)
# Batch: [20/79]	Time 4.169 (1.396)	Loss 0.2816 (0.2350)	Accuracy 0.8281 (0.8996)
# Batch: [30/79]	Time 0.481 (1.269)	Loss 0.2008 (0.2352)	Accuracy 0.8906 (0.9017)
# Batch: [40/79]	Time 4.084 (1.302)	Loss 0.3420 (0.2379)	Accuracy 0.8594 (0.9017)
# Batch: [50/79]	Time 0.554 (1.247)	Loss 0.2566 (0.2361)	Accuracy 0.8750 (0.9010)
# Batch: [60/79]	Time 3.963 (1.263)	Loss 0.1543 (0.2311)	Accuracy 0.9688 (0.9050)
# Batch: [70/79]	Time 0.606 (1.229)	Loss 0.2081 (0.2303)	Accuracy 0.9062 (0.9047)
# ----------
# Avg validation loss: 0.2092926459312439 	 Accuracy: 0.918
# --------------------
# Epoch 16/20	Time 108.769 sec (130.854 sec)
# --------------------
# Epoch: 17/20
# Batch: [0/79]	Time 6.888 (6.888)	Loss 0.1310 (0.1310)	Accuracy 0.9844 (0.9844)
# Batch: [10/79]	Time 0.065 (1.341)	Loss 0.2568 (0.1936)	Accuracy 0.9375 (0.9290)
# Batch: [20/79]	Time 4.057 (1.292)	Loss 0.2455 (0.2097)	Accuracy 0.9062 (0.9174)
# Batch: [30/79]	Time 0.054 (1.192)	Loss 0.1879 (0.2220)	Accuracy 0.9062 (0.9078)
# Batch: [40/79]	Time 4.179 (1.237)	Loss 0.2792 (0.2202)	Accuracy 0.8594 (0.9097)
# Batch: [50/79]	Time 0.060 (1.189)	Loss 0.2079 (0.2202)	Accuracy 0.9531 (0.9087)
# Batch: [60/79]	Time 4.278 (1.220)	Loss 0.3050 (0.2222)	Accuracy 0.8594 (0.9093)
# Batch: [70/79]	Time 0.072 (1.182)	Loss 0.4192 (0.2265)	Accuracy 0.7969 (0.9071)
# ----------
# Avg validation loss: 0.25578622460365297 	 Accuracy: 0.884
# --------------------
# Epoch 17/20	Time 105.641 sec (129.454 sec)
# --------------------
# Epoch: 18/20
# Batch: [0/79]	Time 6.854 (6.854)	Loss 0.2467 (0.2467)	Accuracy 0.8750 (0.8750)
# Batch: [10/79]	Time 0.218 (1.370)	Loss 0.2636 (0.2270)	Accuracy 0.9219 (0.9062)
# Batch: [20/79]	Time 4.211 (1.303)	Loss 0.3322 (0.2277)	Accuracy 0.8438 (0.9048)
# Batch: [30/79]	Time 0.094 (1.202)	Loss 0.1686 (0.2195)	Accuracy 0.9062 (0.9047)
# Batch: [40/79]	Time 4.227 (1.250)	Loss 0.1966 (0.2211)	Accuracy 0.9062 (0.9074)
# Batch: [50/79]	Time 0.082 (1.206)	Loss 0.2081 (0.2294)	Accuracy 0.8906 (0.9017)
# Batch: [60/79]	Time 4.054 (1.238)	Loss 0.2677 (0.2375)	Accuracy 0.8906 (0.8981)
# Batch: [70/79]	Time 0.078 (1.208)	Loss 0.2015 (0.2391)	Accuracy 0.9062 (0.8988)
# ----------
# Avg validation loss: 0.23034120321273804 	 Accuracy: 0.896
# --------------------
# Epoch 18/20	Time 107.607 sec (128.304 sec)
# --------------------
# Epoch: 19/20
# Batch: [0/79]	Time 6.621 (6.621)	Loss 0.3465 (0.3465)	Accuracy 0.8594 (0.8594)
# Batch: [10/79]	Time 0.108 (1.343)	Loss 0.2950 (0.2598)	Accuracy 0.8125 (0.8878)
# Batch: [20/79]	Time 1.978 (1.063)	Loss 0.3279 (0.2487)	Accuracy 0.8750 (0.8966)
# Batch: [30/79]	Time 0.063 (0.825)	Loss 0.3780 (0.2420)	Accuracy 0.8438 (0.8957)
# Batch: [40/79]	Time 1.242 (0.726)	Loss 0.1890 (0.2315)	Accuracy 0.9375 (0.9036)
# Batch: [50/79]	Time 0.068 (0.643)	Loss 0.1627 (0.2265)	Accuracy 0.9219 (0.9075)
# Batch: [60/79]	Time 1.204 (0.605)	Loss 0.2049 (0.2229)	Accuracy 0.9062 (0.9086)
# Batch: [70/79]	Time 0.056 (0.563)	Loss 0.3351 (0.2230)	Accuracy 0.8438 (0.9076)
# ----------
# Avg validation loss: 0.2129594614505768 	 Accuracy: 0.9
# --------------------
# Epoch 19/20	Time 45.715 sec (124.174 sec)
# --------------------

# %%
plt.figure(figsize=(20,20))
plt.subplot(221)
plt.title('training classification loss')
plt.plot(train_losses)
plt.subplot(222)
plt.title('training accuracy')
plt.plot(train_accs)
plt.subplot(223)
plt.title('validation loss')
plt.plot(val_losses)
plt.subplot(224)
plt.title('validation accuracy')
plt.plot(val_accs)
plt.legend()
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.
