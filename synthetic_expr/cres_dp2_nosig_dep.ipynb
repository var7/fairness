# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import argparse

plt.switch_backend('agg')
# In[3]:
font = {'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torchvision import transforms, utils, models, datasets
from torch.utils.data import Dataset, DataLoader

# %%
from synthetic_dataloader import *


from synthetic_utils import *


# In[5]:


from trainer_dataloader import *
from networks import *
from losses import *


# In[6]:

# %%
input_size = 96
batch_size = 64
num_workers = 4


cuda = False
pin_memory = False
if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    cuda = True
    cudnn.benchmark = True
    pin_memory = True
else:
    device = torch.device("cpu")

print('Device set: {}'.format(device))


# In[8]:


data_transforms = {
        'train': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ]),
        'val': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
}
# Out:
# Device set: cuda

# %%
# if independent:
# DATA_PATH = '/home/s1791387/diss/gen_shapes/'
# else:
DATA_PATH = '/home/s1791387/diss/dependent_gen/'
print(DATA_PATH)
TRAIN_PATH = os.path.join(DATA_PATH, 'train')
VAL_PATH = os.path.join(DATA_PATH, 'valid')
TEST_PATH = os.path.join(DATA_PATH, 'test')
# Out:
# /home/s1791387/diss/dependent_gen/

# %%
train_df = datasets.ImageFolder(root=TRAIN_PATH, transform=data_transforms['train'])
val_df = datasets.ImageFolder(root=VAL_PATH, transform=data_transforms['val'])
test_df = datasets.ImageFolder(root=TEST_PATH, transform=data_transforms['val'])

# %%
LOAD_PATH = './dp2_nosig_dep/2/weights/encoder_493_0.79.pth'

# %%
laftr_encoder = torch.load(LOAD_PATH)

# %%
gender_train = ShapeDataset(train_df)
gender_valid = ShapeDataset(val_df)
gender_test = ShapeDataset(test_df)

# %%
advtrain_loader = DataLoader(gender_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
advval_loader = DataLoader(gender_valid, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
advtest_loader = DataLoader(gender_test, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

# %%
classifier = ClassNet()

adv_criterion = nn.BCELoss()
opt_adv = optim.Adam(classifier.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler_adv = lr_scheduler.StepLR(optimizer=opt_adv, gamma=0.99, step_size=1)

# %%
num_epochs = 20
train_losses = []
train_accs = []
val_losses = []
val_accs = []
epoch_time = AverageMeter()
ep_end = time.time()
for epoch in range(0, num_epochs):
        print('Epoch: {}/{}'.format(epoch, num_epochs))
        scheduler_adv.step()
        # train
        train_loss, train_acc = train_classifier_epoch(advtrain_loader, laftr_encoder,
                                classifier, opt_adv, adv_criterion, device)
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        # validate
        print('-'*10)
        val_loss, val_acc = validate_classifier_epoch(advval_loader, laftr_encoder, classifier,
                                 adv_criterion, device)

        print('Avg validation loss: {} \t Accuracy: {}'.format(val_loss, val_acc))
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        
        print('-' * 20)
        epoch_time.update(time.time() - ep_end)
        ep_end = time.time()
        print('Epoch {}/{}\t'
              'Time {epoch_time.val:.3f} sec ({epoch_time.avg:.3f} sec)'.format(epoch, num_epochs, epoch_time=epoch_time))
        print('-'*20)
# Out:
# Epoch: 0/20
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/79]	Time 2.170 (2.170)	Loss 2.6788 (2.6788)	Accuracy 0.4062 (0.4062)
# Batch: [10/79]	Time 0.091 (0.455)	Loss 1.0932 (1.1775)	Accuracy 0.4375 (0.4901)
# Batch: [20/79]	Time 1.303 (0.444)	Loss 0.5198 (0.9656)	Accuracy 0.6250 (0.5402)
# Batch: [30/79]	Time 0.048 (0.401)	Loss 0.5753 (0.8360)	Accuracy 0.7656 (0.5978)
# Batch: [40/79]	Time 1.338 (0.412)	Loss 0.5208 (0.7540)	Accuracy 0.7656 (0.6361)
# Batch: [50/79]	Time 0.051 (0.391)	Loss 0.5061 (0.7066)	Accuracy 0.7188 (0.6538)
# Batch: [60/79]	Time 1.343 (0.397)	Loss 0.5297 (0.6797)	Accuracy 0.7656 (0.6660)
# Batch: [70/79]	Time 0.052 (0.384)	Loss 0.4718 (0.6510)	Accuracy 0.7500 (0.6805)
# ----------
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Avg validation loss: 0.5365532479286194 	 Accuracy: 0.72
# --------------------
# Epoch 0/20	Time 33.953 sec (33.953 sec)
# --------------------
# Epoch: 1/20
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([52])) that is different to the input size (torch.Size([52, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/79]	Time 2.075 (2.075)	Loss 0.6449 (0.6449)	Accuracy 0.6406 (0.6406)
# Batch: [10/79]	Time 0.055 (0.461)	Loss 0.4248 (0.4987)	Accuracy 0.8594 (0.7670)
# Batch: [20/79]	Time 1.309 (0.447)	Loss 0.4431 (0.4935)	Accuracy 0.7812 (0.7634)
# Batch: [30/79]	Time 0.027 (0.401)	Loss 0.5980 (0.5035)	Accuracy 0.6719 (0.7571)
# Batch: [40/79]	Time 1.296 (0.408)	Loss 0.5570 (0.5047)	Accuracy 0.7188 (0.7557)
# Batch: [50/79]	Time 0.053 (0.387)	Loss 0.5116 (0.5045)	Accuracy 0.7656 (0.7564)
# Batch: [60/79]	Time 1.322 (0.394)	Loss 0.5578 (0.4977)	Accuracy 0.7031 (0.7610)
# Batch: [70/79]	Time 0.049 (0.380)	Loss 0.4811 (0.4935)	Accuracy 0.7969 (0.7641)
# ----------
# Avg validation loss: 0.47876948046684265 	 Accuracy: 0.79
# --------------------
# Epoch 1/20	Time 33.425 sec (33.689 sec)
# --------------------
# Epoch: 2/20
# Batch: [0/79]	Time 1.995 (1.995)	Loss 0.4762 (0.4762)	Accuracy 0.7188 (0.7188)
# Batch: [10/79]	Time 0.055 (0.454)	Loss 0.4758 (0.4416)	Accuracy 0.7344 (0.7841)
# Batch: [20/79]	Time 1.291 (0.443)	Loss 0.4735 (0.4538)	Accuracy 0.7656 (0.7790)
# Batch: [30/79]	Time 0.036 (0.398)	Loss 0.5335 (0.4583)	Accuracy 0.8281 (0.7757)
# Batch: [40/79]	Time 1.323 (0.406)	Loss 0.4078 (0.4625)	Accuracy 0.8125 (0.7740)
# Batch: [50/79]	Time 0.052 (0.387)	Loss 0.4192 (0.4624)	Accuracy 0.8125 (0.7748)
# Batch: [60/79]	Time 1.282 (0.392)	Loss 0.5986 (0.4643)	Accuracy 0.6875 (0.7759)
# Batch: [70/79]	Time 0.069 (0.379)	Loss 0.4356 (0.4608)	Accuracy 0.8281 (0.7775)
# ----------
# Avg validation loss: 0.5297597713470459 	 Accuracy: 0.734
# --------------------
# Epoch 2/20	Time 32.730 sec (33.370 sec)
# --------------------
# Epoch: 3/20
# Batch: [0/79]	Time 1.994 (1.994)	Loss 0.5443 (0.5443)	Accuracy 0.6875 (0.6875)
# Batch: [10/79]	Time 0.054 (0.465)	Loss 0.5097 (0.5065)	Accuracy 0.7812 (0.7486)
# Batch: [20/79]	Time 1.368 (0.448)	Loss 0.5538 (0.5027)	Accuracy 0.7031 (0.7522)
# Batch: [30/79]	Time 0.052 (0.399)	Loss 0.4640 (0.4777)	Accuracy 0.7969 (0.7702)
# Batch: [40/79]	Time 1.313 (0.407)	Loss 0.5166 (0.4653)	Accuracy 0.7656 (0.7759)
# Batch: [50/79]	Time 0.049 (0.387)	Loss 0.3918 (0.4632)	Accuracy 0.7812 (0.7773)
# Batch: [60/79]	Time 1.300 (0.394)	Loss 0.4047 (0.4601)	Accuracy 0.8438 (0.7800)
# Batch: [70/79]	Time 0.054 (0.381)	Loss 0.4207 (0.4561)	Accuracy 0.7812 (0.7832)
# ----------
# Avg validation loss: 0.48501580905914304 	 Accuracy: 0.784
# --------------------
# Epoch 3/20	Time 32.733 sec (33.210 sec)
# --------------------
# Epoch: 4/20
# Batch: [0/79]	Time 2.086 (2.086)	Loss 0.4159 (0.4159)	Accuracy 0.7812 (0.7812)
# Batch: [10/79]	Time 0.036 (0.456)	Loss 0.4447 (0.4580)	Accuracy 0.7344 (0.7543)
# Batch: [20/79]	Time 1.345 (0.446)	Loss 0.4826 (0.4563)	Accuracy 0.8125 (0.7746)
# Batch: [30/79]	Time 0.036 (0.399)	Loss 0.3698 (0.4434)	Accuracy 0.8750 (0.7883)
# Batch: [40/79]	Time 1.290 (0.406)	Loss 0.5212 (0.4361)	Accuracy 0.7812 (0.8007)
# Batch: [50/79]	Time 0.032 (0.386)	Loss 0.5284 (0.4362)	Accuracy 0.7188 (0.8006)
# Batch: [60/79]	Time 1.317 (0.393)	Loss 0.4694 (0.4331)	Accuracy 0.7500 (0.8025)
# Batch: [70/79]	Time 0.045 (0.380)	Loss 0.3615 (0.4348)	Accuracy 0.8438 (0.7984)
# ----------
# Avg validation loss: 0.4829706456661224 	 Accuracy: 0.772
# --------------------
# Epoch 4/20	Time 32.726 sec (33.114 sec)
# --------------------
# Epoch: 5/20
# Batch: [0/79]	Time 2.156 (2.156)	Loss 0.4574 (0.4574)	Accuracy 0.7812 (0.7812)
# Batch: [10/79]	Time 0.031 (0.460)	Loss 0.4109 (0.4271)	Accuracy 0.8438 (0.7884)
# Batch: [20/79]	Time 1.443 (0.451)	Loss 0.4913 (0.4523)	Accuracy 0.7344 (0.7827)
# Batch: [30/79]	Time 0.034 (0.399)	Loss 0.3437 (0.4462)	Accuracy 0.8125 (0.7818)
# Batch: [40/79]	Time 1.212 (0.406)	Loss 0.5174 (0.4491)	Accuracy 0.7969 (0.7847)
# Batch: [50/79]	Time 0.034 (0.388)	Loss 0.3478 (0.4395)	Accuracy 0.8281 (0.7877)
# Batch: [60/79]	Time 1.261 (0.394)	Loss 0.4498 (0.4368)	Accuracy 0.7812 (0.7900)
# Batch: [70/79]	Time 0.061 (0.380)	Loss 0.4111 (0.4377)	Accuracy 0.8125 (0.7898)
# ----------
# Avg validation loss: 0.4865045630931854 	 Accuracy: 0.78
# --------------------
# Epoch 5/20	Time 32.780 sec (33.058 sec)
# --------------------
# Epoch: 6/20
# Batch: [0/79]	Time 2.000 (2.000)	Loss 0.4459 (0.4459)	Accuracy 0.7969 (0.7969)
# Batch: [10/79]	Time 0.074 (0.459)	Loss 0.4739 (0.4700)	Accuracy 0.7812 (0.7869)
# Batch: [20/79]	Time 1.285 (0.452)	Loss 0.4608 (0.4582)	Accuracy 0.7344 (0.7857)
# Batch: [30/79]	Time 0.051 (0.403)	Loss 0.3670 (0.4412)	Accuracy 0.8594 (0.7994)
# Batch: [40/79]	Time 1.321 (0.408)	Loss 0.4473 (0.4443)	Accuracy 0.7969 (0.7984)
# Batch: [50/79]	Time 0.044 (0.389)	Loss 0.4652 (0.4438)	Accuracy 0.7656 (0.7917)
# Batch: [60/79]	Time 1.254 (0.394)	Loss 0.4053 (0.4404)	Accuracy 0.7969 (0.7925)
# Batch: [70/79]	Time 0.039 (0.381)	Loss 0.3657 (0.4351)	Accuracy 0.7969 (0.7947)
# ----------
# Avg validation loss: 0.479588504076004 	 Accuracy: 0.772
# --------------------
# Epoch 6/20	Time 32.864 sec (33.030 sec)
# --------------------
# Epoch: 7/20
# Batch: [0/79]	Time 2.119 (2.119)	Loss 0.4027 (0.4027)	Accuracy 0.8281 (0.8281)
# Batch: [10/79]	Time 0.050 (0.467)	Loss 0.4291 (0.4271)	Accuracy 0.7812 (0.7898)
# Batch: [20/79]	Time 1.289 (0.445)	Loss 0.5715 (0.4617)	Accuracy 0.6875 (0.7805)
# Batch: [30/79]	Time 0.058 (0.397)	Loss 0.4609 (0.4463)	Accuracy 0.7969 (0.7888)
# Batch: [40/79]	Time 1.330 (0.407)	Loss 0.3986 (0.4476)	Accuracy 0.7969 (0.7851)
# Batch: [50/79]	Time 0.062 (0.386)	Loss 0.4467 (0.4451)	Accuracy 0.8281 (0.7874)
# Batch: [60/79]	Time 1.333 (0.392)	Loss 0.4377 (0.4427)	Accuracy 0.8594 (0.7902)
# Batch: [70/79]	Time 0.041 (0.379)	Loss 0.5011 (0.4404)	Accuracy 0.7656 (0.7901)
# ----------
# Avg validation loss: 0.5513318475484849 	 Accuracy: 0.74
# --------------------
# Epoch 7/20	Time 32.720 sec (32.992 sec)
# --------------------
# Epoch: 8/20
# Batch: [0/79]	Time 2.171 (2.171)	Loss 0.6632 (0.6632)	Accuracy 0.6562 (0.6562)
# Batch: [10/79]	Time 0.059 (0.458)	Loss 0.4423 (0.4666)	Accuracy 0.8125 (0.7841)
# Batch: [20/79]	Time 1.331 (0.446)	Loss 0.3751 (0.4477)	Accuracy 0.7969 (0.7887)
# Batch: [30/79]	Time 0.047 (0.399)	Loss 0.6390 (0.4514)	Accuracy 0.6875 (0.7863)
# Batch: [40/79]	Time 1.299 (0.406)	Loss 0.3704 (0.4396)	Accuracy 0.8438 (0.7946)
# Batch: [50/79]	Time 0.053 (0.386)	Loss 0.3926 (0.4344)	Accuracy 0.8281 (0.7975)
# Batch: [60/79]	Time 1.355 (0.394)	Loss 0.4164 (0.4367)	Accuracy 0.8281 (0.7946)
# Batch: [70/79]	Time 0.030 (0.380)	Loss 0.4212 (0.4353)	Accuracy 0.7969 (0.7951)
# ----------
# Avg validation loss: 0.49630040788650515 	 Accuracy: 0.774
# --------------------
# Epoch 8/20	Time 32.722 sec (32.962 sec)
# --------------------
# Epoch: 9/20
# Batch: [0/79]	Time 2.009 (2.009)	Loss 0.3542 (0.3542)	Accuracy 0.8906 (0.8906)
# Batch: [10/79]	Time 0.033 (0.461)	Loss 0.3313 (0.4115)	Accuracy 0.8438 (0.8139)
# Batch: [20/79]	Time 1.276 (0.443)	Loss 0.3222 (0.4087)	Accuracy 0.9219 (0.8185)
# Batch: [30/79]	Time 0.051 (0.399)	Loss 0.3447 (0.4138)	Accuracy 0.8438 (0.8135)
# Batch: [40/79]	Time 1.301 (0.405)	Loss 0.4520 (0.4177)	Accuracy 0.7812 (0.8117)
# Batch: [50/79]	Time 0.035 (0.386)	Loss 0.3162 (0.4172)	Accuracy 0.8438 (0.8058)
# Batch: [60/79]	Time 1.256 (0.392)	Loss 0.3572 (0.4161)	Accuracy 0.8125 (0.8081)
# Batch: [70/79]	Time 0.034 (0.379)	Loss 0.3366 (0.4164)	Accuracy 0.8281 (0.8077)
# ----------
# Avg validation loss: 0.5052193570137024 	 Accuracy: 0.772
# --------------------
# Epoch 9/20	Time 32.763 sec (32.942 sec)
# --------------------
# Epoch: 10/20
# Batch: [0/79]	Time 2.030 (2.030)	Loss 0.3939 (0.3939)	Accuracy 0.7656 (0.7656)
# Batch: [10/79]	Time 0.027 (0.461)	Loss 0.4820 (0.4437)	Accuracy 0.7656 (0.7855)
# Batch: [20/79]	Time 1.293 (0.448)	Loss 0.3190 (0.4323)	Accuracy 0.8594 (0.7865)
# Batch: [30/79]	Time 0.055 (0.399)	Loss 0.3953 (0.4270)	Accuracy 0.7969 (0.7913)
# Batch: [40/79]	Time 1.367 (0.406)	Loss 0.3615 (0.4163)	Accuracy 0.8438 (0.7969)
# Batch: [50/79]	Time 0.037 (0.386)	Loss 0.4410 (0.4176)	Accuracy 0.8125 (0.7987)
# Batch: [60/79]	Time 1.337 (0.393)	Loss 0.4575 (0.4220)	Accuracy 0.8125 (0.7974)
# Batch: [70/79]	Time 0.045 (0.380)	Loss 0.3045 (0.4175)	Accuracy 0.8438 (0.8002)
# ----------
# Avg validation loss: 0.47349988198280335 	 Accuracy: 0.794
# --------------------
# Epoch 10/20	Time 32.670 sec (32.917 sec)
# --------------------
# Epoch: 11/20
# Batch: [0/79]	Time 2.062 (2.062)	Loss 0.4481 (0.4481)	Accuracy 0.7969 (0.7969)
# Batch: [10/79]	Time 0.102 (0.467)	Loss 0.3376 (0.4138)	Accuracy 0.8594 (0.8097)
# Batch: [20/79]	Time 1.283 (0.444)	Loss 0.3579 (0.4092)	Accuracy 0.8594 (0.8132)
# Batch: [30/79]	Time 0.055 (0.398)	Loss 0.3630 (0.3960)	Accuracy 0.8125 (0.8180)
# Batch: [40/79]	Time 1.303 (0.406)	Loss 0.4007 (0.3996)	Accuracy 0.8125 (0.8190)
# Batch: [50/79]	Time 0.044 (0.385)	Loss 0.3837 (0.4118)	Accuracy 0.8125 (0.8110)
# Batch: [60/79]	Time 1.377 (0.394)	Loss 0.5035 (0.4182)	Accuracy 0.7188 (0.8053)
# Batch: [70/79]	Time 0.044 (0.384)	Loss 0.4786 (0.4227)	Accuracy 0.7500 (0.8039)
# ----------
# Avg validation loss: 0.5317441623210907 	 Accuracy: 0.746
# --------------------
# Epoch 11/20	Time 33.055 sec (32.928 sec)
# --------------------
# Epoch: 12/20
# Batch: [0/79]	Time 2.101 (2.101)	Loss 0.4510 (0.4510)	Accuracy 0.7969 (0.7969)
# Batch: [10/79]	Time 0.036 (0.468)	Loss 0.4102 (0.4512)	Accuracy 0.7969 (0.7926)
# Batch: [20/79]	Time 1.263 (0.442)	Loss 0.3109 (0.4246)	Accuracy 0.8594 (0.8036)
# Batch: [30/79]	Time 0.048 (0.401)	Loss 0.3354 (0.4231)	Accuracy 0.8750 (0.8004)
# Batch: [40/79]	Time 1.270 (0.405)	Loss 0.4089 (0.4199)	Accuracy 0.7969 (0.8060)
# Batch: [50/79]	Time 0.051 (0.383)	Loss 0.3770 (0.4121)	Accuracy 0.8125 (0.8088)
# Batch: [60/79]	Time 1.177 (0.390)	Loss 0.2952 (0.4096)	Accuracy 0.9062 (0.8097)
# Batch: [70/79]	Time 0.066 (0.377)	Loss 0.3376 (0.4136)	Accuracy 0.8438 (0.8079)
# ----------
# Avg validation loss: 0.5094494655132293 	 Accuracy: 0.762
# --------------------
# Epoch 12/20	Time 32.504 sec (32.896 sec)
# --------------------
# Epoch: 13/20
# Batch: [0/79]	Time 1.994 (1.994)	Loss 0.5581 (0.5581)	Accuracy 0.7656 (0.7656)
# Batch: [10/79]	Time 0.028 (0.449)	Loss 0.4177 (0.4627)	Accuracy 0.8125 (0.7841)
# Batch: [20/79]	Time 1.338 (0.440)	Loss 0.2557 (0.4454)	Accuracy 0.9219 (0.7909)
# Batch: [30/79]	Time 0.061 (0.396)	Loss 0.4426 (0.4291)	Accuracy 0.7500 (0.8014)
# Batch: [40/79]	Time 1.259 (0.403)	Loss 0.4704 (0.4284)	Accuracy 0.7188 (0.7954)
# Batch: [50/79]	Time 0.122 (0.387)	Loss 0.4672 (0.4238)	Accuracy 0.7656 (0.7996)
# Batch: [60/79]	Time 1.266 (0.392)	Loss 0.4052 (0.4247)	Accuracy 0.8594 (0.8030)
# Batch: [70/79]	Time 0.054 (0.380)	Loss 0.3369 (0.4231)	Accuracy 0.8281 (0.8033)
# ----------
# Avg validation loss: 0.4711745994091034 	 Accuracy: 0.78
# --------------------
# Epoch 13/20	Time 32.760 sec (32.886 sec)
# --------------------
# Epoch: 14/20
# Batch: [0/79]	Time 2.162 (2.162)	Loss 0.4144 (0.4144)	Accuracy 0.7969 (0.7969)
# Batch: [10/79]	Time 0.046 (0.466)	Loss 0.3023 (0.3853)	Accuracy 0.9062 (0.8381)
# Batch: [20/79]	Time 1.306 (0.447)	Loss 0.4240 (0.4019)	Accuracy 0.8438 (0.8281)
# Batch: [30/79]	Time 0.041 (0.399)	Loss 0.3665 (0.4055)	Accuracy 0.8281 (0.8256)
# Batch: [40/79]	Time 1.234 (0.407)	Loss 0.4116 (0.4038)	Accuracy 0.7656 (0.8232)
# Batch: [50/79]	Time 0.104 (0.387)	Loss 0.3506 (0.4069)	Accuracy 0.8906 (0.8226)
# Batch: [60/79]	Time 1.292 (0.394)	Loss 0.4982 (0.4055)	Accuracy 0.7344 (0.8202)
# Batch: [70/79]	Time 0.039 (0.386)	Loss 0.5507 (0.4107)	Accuracy 0.7344 (0.8151)
# ----------
# Avg validation loss: 0.47450351595878604 	 Accuracy: 0.796
# --------------------
# Epoch 14/20	Time 33.187 sec (32.906 sec)
# --------------------
# Epoch: 15/20
# Batch: [0/79]	Time 2.128 (2.128)	Loss 0.3299 (0.3299)	Accuracy 0.8438 (0.8438)
# Batch: [10/79]	Time 0.050 (0.465)	Loss 0.4428 (0.4429)	Accuracy 0.7969 (0.7869)
# Batch: [20/79]	Time 1.275 (0.444)	Loss 0.5523 (0.4418)	Accuracy 0.7656 (0.7917)
# Batch: [30/79]	Time 0.043 (0.401)	Loss 0.2638 (0.4272)	Accuracy 0.9375 (0.7964)
# Batch: [40/79]	Time 1.259 (0.407)	Loss 0.4828 (0.4267)	Accuracy 0.7344 (0.7969)
# Batch: [50/79]	Time 0.049 (0.387)	Loss 0.3082 (0.4250)	Accuracy 0.8750 (0.8015)
# Batch: [60/79]	Time 1.240 (0.395)	Loss 0.3484 (0.4233)	Accuracy 0.8281 (0.8023)
# Batch: [70/79]	Time 0.065 (0.382)	Loss 0.4036 (0.4166)	Accuracy 0.8281 (0.8052)
# ----------
# Avg validation loss: 0.46427042269706725 	 Accuracy: 0.784
# --------------------
# Epoch 15/20	Time 32.943 sec (32.908 sec)
# --------------------
# Epoch: 16/20
# Batch: [0/79]	Time 2.115 (2.115)	Loss 0.3781 (0.3781)	Accuracy 0.8125 (0.8125)
# Batch: [10/79]	Time 0.045 (0.457)	Loss 0.3792 (0.3922)	Accuracy 0.8281 (0.8111)
# Batch: [20/79]	Time 1.351 (0.445)	Loss 0.4236 (0.4183)	Accuracy 0.7812 (0.7969)
# Batch: [30/79]	Time 0.019 (0.399)	Loss 0.3911 (0.4217)	Accuracy 0.8438 (0.7989)
# Batch: [40/79]	Time 1.306 (0.407)	Loss 0.4277 (0.4280)	Accuracy 0.7656 (0.7954)
# Batch: [50/79]	Time 0.053 (0.387)	Loss 0.4377 (0.4245)	Accuracy 0.7812 (0.7972)
# Batch: [60/79]	Time 1.241 (0.393)	Loss 0.4355 (0.4197)	Accuracy 0.7344 (0.7994)
# Batch: [70/79]	Time 0.041 (0.381)	Loss 0.4251 (0.4155)	Accuracy 0.8281 (0.8013)
# ----------
# Avg validation loss: 0.4778404517173767 	 Accuracy: 0.788
# --------------------
# Epoch 16/20	Time 32.758 sec (32.900 sec)
# --------------------
# Epoch: 17/20
# Batch: [0/79]	Time 2.029 (2.029)	Loss 0.3597 (0.3597)	Accuracy 0.8438 (0.8438)
# Batch: [10/79]	Time 0.050 (0.453)	Loss 0.4344 (0.3920)	Accuracy 0.8594 (0.8338)
# Batch: [20/79]	Time 1.226 (0.446)	Loss 0.4860 (0.3984)	Accuracy 0.7344 (0.8251)
# Batch: [30/79]	Time 0.016 (0.402)	Loss 0.3192 (0.3925)	Accuracy 0.8750 (0.8301)
# Batch: [40/79]	Time 1.283 (0.406)	Loss 0.4010 (0.3925)	Accuracy 0.8281 (0.8308)
# Batch: [50/79]	Time 0.117 (0.388)	Loss 0.4484 (0.3994)	Accuracy 0.8125 (0.8251)
# Batch: [60/79]	Time 1.267 (0.394)	Loss 0.3966 (0.4011)	Accuracy 0.7812 (0.8215)
# Batch: [70/79]	Time 0.091 (0.382)	Loss 0.3341 (0.3986)	Accuracy 0.8594 (0.8228)
# ----------
# Avg validation loss: 0.47159838342666627 	 Accuracy: 0.778
# --------------------
# Epoch 17/20	Time 32.846 sec (32.897 sec)
# --------------------
# Epoch: 18/20
# Batch: [0/79]	Time 2.023 (2.023)	Loss 0.4685 (0.4685)	Accuracy 0.8125 (0.8125)
# Batch: [10/79]	Time 0.056 (0.463)	Loss 0.5033 (0.4095)	Accuracy 0.7188 (0.8210)
# Batch: [20/79]	Time 1.257 (0.444)	Loss 0.5365 (0.4240)	Accuracy 0.7500 (0.8080)
# Batch: [30/79]	Time 0.038 (0.398)	Loss 0.3059 (0.4164)	Accuracy 0.9375 (0.8150)
# Batch: [40/79]	Time 1.308 (0.406)	Loss 0.3237 (0.4150)	Accuracy 0.8281 (0.8110)
# Batch: [50/79]	Time 0.054 (0.387)	Loss 0.3890 (0.4206)	Accuracy 0.7969 (0.8061)
# Batch: [60/79]	Time 1.348 (0.393)	Loss 0.3691 (0.4155)	Accuracy 0.8594 (0.8074)
# Batch: [70/79]	Time 0.050 (0.381)	Loss 0.4381 (0.4169)	Accuracy 0.8438 (0.8072)
# ----------
# Avg validation loss: 0.5098961777687073 	 Accuracy: 0.77
# --------------------
# Epoch 18/20	Time 32.752 sec (32.889 sec)
# --------------------
# Epoch: 19/20
# Batch: [0/79]	Time 2.109 (2.109)	Loss 0.4166 (0.4166)	Accuracy 0.7656 (0.7656)
# Batch: [10/79]	Time 0.051 (0.464)	Loss 0.3759 (0.3942)	Accuracy 0.8438 (0.8210)
# Batch: [20/79]	Time 1.261 (0.445)	Loss 0.3100 (0.4133)	Accuracy 0.8438 (0.8088)
# Batch: [30/79]	Time 0.043 (0.400)	Loss 0.3486 (0.4079)	Accuracy 0.8438 (0.8100)
# Batch: [40/79]	Time 1.371 (0.409)	Loss 0.4003 (0.4010)	Accuracy 0.8125 (0.8129)
# Batch: [50/79]	Time 0.050 (0.387)	Loss 0.4156 (0.4074)	Accuracy 0.8125 (0.8107)
# Batch: [60/79]	Time 1.330 (0.395)	Loss 0.4844 (0.4070)	Accuracy 0.7812 (0.8102)
# Batch: [70/79]	Time 0.063 (0.382)	Loss 0.3748 (0.4075)	Accuracy 0.8594 (0.8096)
# ----------
# Avg validation loss: 0.47799082231521606 	 Accuracy: 0.774
# --------------------
# Epoch 19/20	Time 32.767 sec (32.883 sec)
# --------------------

# %%
plt.figure(figsize=(20,20))
plt.subplot(221)
plt.title('training classification loss')
plt.plot(train_losses)
plt.subplot(222)
plt.title('training accuracy')
plt.plot(train_accs)
plt.subplot(223)
plt.title('validation loss')
plt.plot(val_losses)
plt.subplot(224)
plt.title('validation accuracy')
plt.plot(val_accs)
plt.legend()
plt.tight_layout()
# Out:
# No handles with labels found to put in legend.

# %%
test_loss, test_acc = validate_classifier_epoch(advtest_loader, laftr_encoder, classifier,
                                 adv_criterion, device)
# Out:
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([52])) that is different to the input size (torch.Size([52, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))

# %%
test_loss, test_acc
# Out:
# (0.484138738155365, 0.76)
