# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torchvision import transforms, utils, models, datasets
from torch.utils.data import Dataset, DataLoader

# %%
from synthetic_utils import *

# %%
from trainer_dataloader import *
from networks import *
from losses import *
from synthetic_dataloader import *

# %%
input_size = 96
batch_size = 128
num_workers = 4
num_epochs = 20

# %%
cuda = False
pin_memory = False
if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    cuda = True
    cudnn.benchmark = True
    pin_memory = True
else:
    device = torch.device("cpu")

print('Device set: {}'.format(device))
# Out:
# Device set: cuda

# %%
data_transforms = {
        'train': transforms.Compose([
            transforms.Resize((input_size, input_size)),
#             transforms.RandomRotation(10),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ]),
        'val': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
}

# %%
# DATA_PATH = '/home/s1791387/diss/gen_shapes/'
# DATA_PATH = '/home/var/synthetic_data/gen_shapes/'
DATA_PATH = '/home/var/synthetic_data/dependent_gen/'
TRAIN_PATH = os.path.join(DATA_PATH, 'train')
VAL_PATH = os.path.join(DATA_PATH, 'valid')
TEST_PATH = os.path.join(DATA_PATH, 'test')

# %%
train_df = datasets.ImageFolder(root=TRAIN_PATH, transform=data_transforms['train'])
val_df = datasets.ImageFolder(root=VAL_PATH, transform=data_transforms['val'])
test_df = datasets.ImageFolder(root=TEST_PATH, transform=data_transforms['val'])

# %%
# train_loader = DataLoader(train_df, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
# val_loader = DataLoader(val_df, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
# test_loader = DataLoader(test_df, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

# %%
gender_train = GenderDataset(train_df)
gender_valid = GenderDataset(val_df)
gender_test = GenderDataset(test_df)

# %%
train_loader = DataLoader(gender_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
val_loader = DataLoader(gender_valid, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)
test_loader = DataLoader(gender_test, batch_size=batch_size, shuffle=False, num_workers=num_workers, pin_memory=pin_memory)

# %% [markdown]
# ## Train only encoder first

# %%
encoder = LeNet()
classifier = ClassNet()

# %%
encoder.to(device)
classifier.to(device)
# Out:
# ClassNet(
#   (fc1): Linear(in_features=128, out_features=8, bias=True)
#   (fc2): Linear(in_features=8, out_features=1, bias=True)
#   (out_acc): Sigmoid()
# )

# %%
criterion = nn.BCELoss()
opt_cls = optim.Adam(classifier.parameters(), lr=0.001, betas=(0.9, 0.999))
opt_enc = optim.Adam(encoder.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler_cls = lr_scheduler.StepLR(optimizer=opt_cls, gamma=0.99, step_size=1)
scheduler_enc = lr_scheduler.StepLR(optimizer=opt_enc, gamma=0.99, step_size=1)

# %%
train_losses = []
train_accs = []
val_losses = []
val_accs = []
epoch_time = AverageMeter()
ep_end = time.time()
for epoch in range(0, 20):
        print('Epoch: {}/{}'.format(epoch, num_epochs))
        scheduler_cls.step()
        scheduler_enc.step()
        # train
        train_loss, train_acc = train_encoder_classifier_epoch(train_loader, encoder,
                                classifier, opt_enc,
                                opt_cls, criterion, device)
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        # validate
        print('-'*10)
        val_loss, val_acc = validate_encoder_classifier_epoch(val_loader, encoder, classifier,
                                 criterion, device)

        print('Avg validation loss: {} \t Accuracy: {}'.format(val_loss, val_acc))
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        
        print('-' * 20)
        epoch_time.update(time.time() - ep_end)
        ep_end = time.time()
        print('Epoch {}/{}\t'
              'Time {epoch_time.val:.3f} sec ({epoch_time.avg:.3f} sec)'.format(epoch, num_epochs, epoch_time=epoch_time))
        print('-'*20)
# Out:
# Epoch: 0/20
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/40]	Time 2.880 (2.880)	Loss 0.6937 (0.6937)	Accuracy 0.5312 (0.5312)
# Batch: [10/40]	Time 0.068 (0.604)	Loss 0.3392 (0.5024)	Accuracy 0.8281 (0.7301)
# Batch: [20/40]	Time 1.775 (0.602)	Loss 0.2432 (0.4009)	Accuracy 0.8906 (0.7946)
# Batch: [30/40]	Time 0.071 (0.542)	Loss 0.1200 (0.3383)	Accuracy 0.9688 (0.8352)
# ----------
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Test: [0/4]	Time 2.139 (2.139)	Loss 0.1096 (0.1096)	Accuracy 0.9609 (0.9609)
# Avg validation loss: 0.125885986328125 	 Accuracy: 0.95
# --------------------
# Epoch 0/20	Time 22.404 sec (22.404 sec)
# --------------------
# Epoch: 1/20
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([116])) that is different to the input size (torch.Size([116, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/40]	Time 2.667 (2.667)	Loss 0.1440 (0.1440)	Accuracy 0.9453 (0.9453)
# Batch: [10/40]	Time 0.076 (0.627)	Loss 0.0451 (0.1146)	Accuracy 1.0000 (0.9553)
# Batch: [20/40]	Time 1.564 (0.605)	Loss 0.0371 (0.0871)	Accuracy 0.9688 (0.9661)
# Batch: [30/40]	Time 0.088 (0.556)	Loss 0.0111 (0.0680)	Accuracy 1.0000 (0.9733)
# ----------
# Test: [0/4]	Time 2.311 (2.311)	Loss 0.0190 (0.0190)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.022139892786741257 	 Accuracy: 0.99
# --------------------
# Epoch 1/20	Time 22.843 sec (22.624 sec)
# --------------------
# Epoch: 2/20
# Batch: [0/40]	Time 1.967 (1.967)	Loss 0.0198 (0.0198)	Accuracy 0.9922 (0.9922)
# Batch: [10/40]	Time 0.149 (0.499)	Loss 0.0120 (0.0198)	Accuracy 0.9922 (0.9901)
# Batch: [20/40]	Time 1.238 (0.482)	Loss 0.0541 (0.0214)	Accuracy 0.9844 (0.9914)
# Batch: [30/40]	Time 0.048 (0.448)	Loss 0.0244 (0.0173)	Accuracy 0.9844 (0.9934)
# ----------
# Test: [0/4]	Time 1.576 (1.576)	Loss 0.0193 (0.0193)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.029050790414214135 	 Accuracy: 0.984
# --------------------
# Epoch 2/20	Time 18.175 sec (21.141 sec)
# --------------------
# Epoch: 3/20
# Batch: [0/40]	Time 2.107 (2.107)	Loss 0.0286 (0.0286)	Accuracy 0.9844 (0.9844)
# Batch: [10/40]	Time 0.048 (0.509)	Loss 0.0045 (0.0085)	Accuracy 1.0000 (0.9972)
# Batch: [20/40]	Time 1.389 (0.491)	Loss 0.0063 (0.0065)	Accuracy 1.0000 (0.9985)
# Batch: [30/40]	Time 0.074 (0.445)	Loss 0.0202 (0.0071)	Accuracy 0.9922 (0.9985)
# ----------
# Test: [0/4]	Time 1.675 (1.675)	Loss 0.0240 (0.0240)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.013362565875053406 	 Accuracy: 0.994
# --------------------
# Epoch 3/20	Time 18.516 sec (20.485 sec)
# --------------------
# Epoch: 4/20
# Batch: [0/40]	Time 1.901 (1.901)	Loss 0.0006 (0.0006)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.079 (0.508)	Loss 0.0007 (0.0050)	Accuracy 1.0000 (0.9986)
# Batch: [20/40]	Time 1.336 (0.495)	Loss 0.0012 (0.0046)	Accuracy 1.0000 (0.9985)
# Batch: [30/40]	Time 0.060 (0.446)	Loss 0.0002 (0.0036)	Accuracy 1.0000 (0.9990)
# ----------
# Test: [0/4]	Time 1.853 (1.853)	Loss 0.0019 (0.0019)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.0075826626718044285 	 Accuracy: 0.994
# --------------------
# Epoch 4/20	Time 18.916 sec (20.171 sec)
# --------------------
# Epoch: 5/20
# Batch: [0/40]	Time 2.072 (2.072)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.072 (0.534)	Loss 0.0037 (0.0052)	Accuracy 1.0000 (0.9979)
# Batch: [20/40]	Time 1.269 (0.510)	Loss 0.0003 (0.0058)	Accuracy 1.0000 (0.9978)
# Batch: [30/40]	Time 0.054 (0.476)	Loss 0.0025 (0.0050)	Accuracy 1.0000 (0.9982)
# ----------
# Test: [0/4]	Time 1.888 (1.888)	Loss 0.0354 (0.0354)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.02227757677063346 	 Accuracy: 0.992
# --------------------
# Epoch 5/20	Time 19.542 sec (20.066 sec)
# --------------------
# Epoch: 6/20
# Batch: [0/40]	Time 2.010 (2.010)	Loss 0.0022 (0.0022)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.064 (0.509)	Loss 0.0053 (0.0017)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.060 (0.478)	Loss 0.0013 (0.0012)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.095 (0.442)	Loss 0.0002 (0.0010)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.748 (1.748)	Loss 0.0131 (0.0131)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.019437654939480124 	 Accuracy: 0.992
# --------------------
# Epoch 6/20	Time 18.266 sec (19.809 sec)
# --------------------
# Epoch: 7/20
# Batch: [0/40]	Time 1.659 (1.659)	Loss 0.0008 (0.0008)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.052 (0.458)	Loss 0.0001 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.241 (0.452)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.037 (0.421)	Loss 0.0001 (0.0002)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.731 (1.731)	Loss 0.0129 (0.0129)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.020272998912259935 	 Accuracy: 0.992
# --------------------
# Epoch 7/20	Time 17.679 sec (19.543 sec)
# --------------------
# Epoch: 8/20
# Batch: [0/40]	Time 1.863 (1.863)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.048 (0.460)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.403 (0.470)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.058 (0.423)	Loss 0.0002 (0.0001)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.435 (1.435)	Loss 0.0164 (0.0164)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.021184053590521217 	 Accuracy: 0.992
# --------------------
# Epoch 8/20	Time 17.537 sec (19.320 sec)
# --------------------
# Epoch: 9/20
# Batch: [0/40]	Time 1.429 (1.429)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.079 (0.456)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.955 (0.439)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.056 (0.421)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.179 (1.179)	Loss 0.0184 (0.0184)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.02098364997468889 	 Accuracy: 0.992
# --------------------
# Epoch 9/20	Time 17.592 sec (19.147 sec)
# --------------------
# Epoch: 10/20
# Batch: [0/40]	Time 1.779 (1.779)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.065 (0.461)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.373 (0.455)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.048 (0.419)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.602 (1.602)	Loss 0.0201 (0.0201)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.020929886017926037 	 Accuracy: 0.992
# --------------------
# Epoch 10/20	Time 17.636 sec (19.010 sec)
# --------------------
# Epoch: 11/20
# Batch: [0/40]	Time 1.775 (1.775)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.366 (0.472)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.018 (0.444)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.330 (0.407)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.124 (1.124)	Loss 0.0221 (0.0221)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.020948259701952337 	 Accuracy: 0.992
# --------------------
# Epoch 11/20	Time 17.308 sec (18.868 sec)
# --------------------
# Epoch: 12/20
# Batch: [0/40]	Time 1.864 (1.864)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.080 (0.465)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.439 (0.455)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.050 (0.413)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.439 (1.439)	Loss 0.0235 (0.0235)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.021053165201097727 	 Accuracy: 0.992
# --------------------
# Epoch 12/20	Time 17.320 sec (18.749 sec)
# --------------------
# Epoch: 13/20
# Batch: [0/40]	Time 1.721 (1.721)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.049 (0.443)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.346 (0.446)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.044 (0.412)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.804 (1.804)	Loss 0.0248 (0.0248)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.02132167538907379 	 Accuracy: 0.992
# --------------------
# Epoch 13/20	Time 17.548 sec (18.663 sec)
# --------------------
# Epoch: 14/20
# Batch: [0/40]	Time 1.733 (1.733)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.062 (0.450)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.429 (0.445)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.084 (0.409)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.789 (1.789)	Loss 0.0265 (0.0265)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.021636097160167993 	 Accuracy: 0.992
# --------------------
# Epoch 14/20	Time 17.216 sec (18.566 sec)
# --------------------
# Epoch: 15/20
# Batch: [0/40]	Time 1.543 (1.543)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.352 (0.426)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.950 (0.422)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.176 (0.405)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.706 (1.706)	Loss 0.0280 (0.0280)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.02213343666680157 	 Accuracy: 0.992
# --------------------
# Epoch 15/20	Time 17.206 sec (18.481 sec)
# --------------------
# Epoch: 16/20
# Batch: [0/40]	Time 1.386 (1.386)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.050 (0.401)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.842 (0.405)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.117 (0.387)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.870 (1.870)	Loss 0.0293 (0.0293)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.022359303017146885 	 Accuracy: 0.992
# --------------------
# Epoch 16/20	Time 17.019 sec (18.395 sec)
# --------------------
# Epoch: 17/20
# Batch: [0/40]	Time 1.669 (1.669)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.055 (0.399)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.926 (0.406)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.052 (0.390)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.927 (1.927)	Loss 0.0297 (0.0297)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.022274522610008715 	 Accuracy: 0.992
# --------------------
# Epoch 17/20	Time 17.237 sec (18.331 sec)
# --------------------
# Epoch: 18/20
# Batch: [0/40]	Time 1.490 (1.490)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.392 (0.436)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.924 (0.413)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.060 (0.394)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.862 (1.862)	Loss 0.0304 (0.0304)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.022391154173295943 	 Accuracy: 0.992
# --------------------
# Epoch 18/20	Time 16.930 sec (18.257 sec)
# --------------------
# Epoch: 19/20
# Batch: [0/40]	Time 1.837 (1.837)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.060 (0.412)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.364 (0.430)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.048 (0.391)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.921 (1.921)	Loss 0.0307 (0.0307)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.022017932039685547 	 Accuracy: 0.992
# --------------------
# Epoch 19/20	Time 16.751 sec (18.182 sec)
# --------------------

# %%
validate_encoder_classifier_epoch(test_loader, encoder, classifier,
                                 criterion, device)
# Out:
# Test: [0/4]	Time 1.662 (1.662)	Loss 0.0644 (0.0644)	Accuracy 0.9844 (0.9844)
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([116])) that is different to the input size (torch.Size([116, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# (0.023937764636822977, 0.992)

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(221)
plt.title('training classification loss')
plt.plot(train_losses)
plt.subplot(222)
plt.title('training accuracy')
plt.plot(train_accs)
plt.subplot(223)
plt.title('validation loss')
plt.plot(val_losses)
plt.subplot(224)
plt.title('validation accuracy')
plt.plot(val_accs)

# %%
from synthetic_dataloader import *

# %%
shape_gender_train = ShapeGenderDataset(train_df)
shape_gender_val = ShapeGenderDataset(val_df)
shape_gender_test = ShapeGenderDataset(test_df)

# %%
reps = []
shapes = []
colors= []
encoder.eval()
with torch.no_grad():
    for i in range(len(train_df)):
        img, shape, color = shape_gender_train[i]
        img = img.to(device).float()
        img.unsqueeze_(0)
        encoding = encoder(img)
        reps.append(encoding[0].cpu().numpy())
        shapes.append(shape)
        colors.append(color)
        if i == 0: 
            print(i)
# Out:
# 0

# %%
y_num = pd.DataFrame(shapes)
s = pd.DataFrame(colors)
X = pd.DataFrame(reps)

# %%
import matplotlib.cm as cm
font = {'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)
plt.style.use('bmh')

# %%
colors = cm.Dark2(np.linspace(0, 1, len(train_df.classes)))

# %%
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

# %%
X_pca = PCA(n_components=50).fit_transform(X, X)
tsne = TSNE(n_components=2, init='random', random_state=0)
# X_r = tsne.fit_transform(X)
X_r = tsne.fit_transform(X_pca)

# %%
train_df.class_to_idx
# Out:
# {'circle': 0, 'rectangle': 1}

# %%
plt.figure(figsize=(10,10))
plt.scatter(X_r[(y_num == 0)[0], 0], X_r[(y_num == 0)[0], 1], c=colors[0], label='circle')
plt.scatter(X_r[(y_num == 1)[0], 0], X_r[(y_num == 1)[0], 1], c=colors[1], label='rectangle')
plt.legend()
# plt.show()
out = "dep_adv_tsne_train_y.pdf"
plt.savefig(out)
print("Saved to: {}".format(out))
# Out:
# Saved to: dep_adv_tsne_train_y.pdf

# %%
plt.figure(figsize=(10,10))
plt.scatter(X_r[(s == 1)[0], 0], X_r[(s == 1)[0], 1], c='red', label='red')
plt.scatter(X_r[(s == 0)[0], 0], X_r[(s == 0)[0], 1], c='green', label='green')
plt.legend()
out = "dep_adv_tsne_train_s.pdf"
plt.savefig(out)
print("Saved to: {}".format(out))
# plt.show()
# Out:
# Saved to: dep_adv_tsne_train_s.pdf

# %%
reps_test = []
shapes_test = []
colors_test = []
encoder.eval()
with torch.no_grad():
    for i in range(len(test_df)):
        img, shape, color = shape_gender_test[i]
        img = img.to(device).float()
        img.unsqueeze_(0)
        encoding = encoder(img)
        reps_test.append(encoding[0].cpu().numpy())
        shapes_test.append(shape)
        colors_test.append(color)
        if i == 0: 
            print(i)
# Out:
# 0

# %%
y_num_test = pd.DataFrame(shapes_test)
s_test = pd.DataFrame(colors_test)
X_test = pd.DataFrame(reps_test)

# %%
X_pca_test = PCA(n_components=50).fit_transform(X_test, X_test)
tsne_test = TSNE(n_components=2, init='random', random_state=0)
# X_r = tsne.fit_transform(X)
X_r_test = tsne_test.fit_transform(X_pca_test)

# %%
colors = cm.Dark2(np.linspace(0, 1, len(train_df.classes)))

# %%
plt.figure(figsize=(10,10))
plt.scatter(X_r_test[(y_num_test == 0)[0], 0], X_r_test[(y_num_test == 0)[0], 1], c=colors[0], label='circle')
plt.scatter(X_r_test[(y_num_test == 1)[0], 0], X_r_test[(y_num_test == 1)[0], 1], c=colors[1], label='rectangle')
plt.legend()
out = "dep_adv_tsne_test_y.pdf"
plt.savefig(out)
print("Saved to: {}".format(out))
# Out:
# Saved to: dep_adv_tsne_test_y.pdf

# %%
plt.figure(figsize=(10,10))
plt.scatter(X_r_test[(s_test == 1)[0], 0], X_r_test[(s_test == 1)[0], 1], c='red', label='red')
plt.scatter(X_r_test[(s_test == 0)[0], 0], X_r_test[(s_test == 0)[0], 1], c='green', label='green')
plt.legend()
out = "dep_adv_tsne_test_s.pdf"
plt.savefig(out)
print("Saved to: {}".format(out))
# Out:
# Saved to: dep_adv_tsne_test_s.pdf
