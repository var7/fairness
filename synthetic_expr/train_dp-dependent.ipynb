# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib

# %%
import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torchvision import transforms, utils, models, datasets
from torch.utils.data import Dataset, DataLoader

# %%
from synthetic_utils import *

# %%
from trainer_dataloader import *
from networks import *
from losses import *

# %%
input_size = 96
batch_size = 128
num_workers = 4
num_epochs = 20

# %%
cuda = False
pin_memory = False
if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    cuda = True
    cudnn.benchmark = True
    pin_memory = True
else:
    device = torch.device("cpu")

print('Device set: {}'.format(device))
# Out:
# Device set: cuda

# %%
data_transforms = {
        'train': transforms.Compose([
            transforms.Resize((input_size, input_size)),
#             transforms.RandomRotation(10),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ]),
        'val': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])
}

# %%
DATA_PATH = '/home/var/synthetic_data/dependent_gen/'
TRAIN_PATH = os.path.join(DATA_PATH, 'train')
VAL_PATH = os.path.join(DATA_PATH, 'valid')
TEST_PATH = os.path.join(DATA_PATH, 'test')

# %%
train_df = datasets.ImageFolder(root=TRAIN_PATH, transform=data_transforms['train'])
val_df = datasets.ImageFolder(root=VAL_PATH, transform=data_transforms['val'])
test_df = datasets.ImageFolder(root=TEST_PATH, transform=data_transforms['val'])

# %%
train_loader = DataLoader(train_df, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
val_loader = DataLoader(val_df, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
test_loader = DataLoader(test_df, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)

# %% [markdown]
# ## Train only encoder first

# %%
encoder = LeNet()
classifier = ClassNet()

# %%
criterion = nn.BCELoss()
opt_cls = optim.Adam(classifier.parameters(), lr=0.001, betas=(0.9, 0.999))
opt_enc = optim.Adam(encoder.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler_cls = lr_scheduler.StepLR(optimizer=opt_cls, gamma=0.99, step_size=1)
scheduler_enc = lr_scheduler.StepLR(optimizer=opt_enc, gamma=0.99, step_size=1)

# %%
train_losses = []
train_accs = []
val_losses = []
val_accs = []
epoch_time = AverageMeter()
ep_end = time.time()
for epoch in range(0, num_epochs):
        print('Epoch: {}/{}'.format(epoch, num_epochs))
        scheduler_cls.step()
        scheduler_enc.step()
        # train
        train_loss, train_acc = train_encoder_classifier_epoch(train_loader, encoder,
                                classifier, opt_enc,
                                opt_cls, criterion, device)
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        # validate
        print('-'*10)
        val_loss, val_acc = validate_encoder_classifier_epoch(val_loader, encoder, classifier,
                                 criterion, device)

        print('Avg validation loss: {} \t Accuracy: {}'.format(val_loss, val_acc))
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        
        print('-' * 20)
        epoch_time.update(time.time() - ep_end)
        ep_end = time.time()
        print('Epoch {}/{}\t'
              'Time {epoch_time.val:.3f} sec ({epoch_time.avg:.3f} sec)'.format(epoch, num_epochs, epoch_time=epoch_time))
        print('-'*20)
# Out:
# Epoch: 0/20
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/40]	Time 2.360 (2.360)	Loss 0.6889 (0.6889)	Accuracy 0.5781 (0.5781)
# Batch: [5/40]	Time 0.086 (0.624)	Loss 0.5237 (0.6163)	Accuracy 0.7578 (0.6562)
# Batch: [10/40]	Time 0.047 (0.489)	Loss 0.5271 (0.5739)	Accuracy 0.6953 (0.7045)
# Batch: [15/40]	Time 0.052 (0.447)	Loss 0.6080 (0.5589)	Accuracy 0.6641 (0.7134)
# Batch: [20/40]	Time 1.334 (0.478)	Loss 0.4229 (0.5341)	Accuracy 0.8125 (0.7303)
# Batch: [25/40]	Time 0.073 (0.458)	Loss 0.3771 (0.5092)	Accuracy 0.8359 (0.7512)
# Batch: [30/40]	Time 0.044 (0.429)	Loss 0.3955 (0.4944)	Accuracy 0.8516 (0.7659)
# Batch: [35/40]	Time 0.055 (0.410)	Loss 0.4216 (0.4814)	Accuracy 0.8047 (0.7745)
# ----------
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Test: [0/4]	Time 1.654 (1.654)	Loss 0.4087 (0.4087)	Accuracy 0.8125 (0.8125)
# Avg validation loss: 0.4166659462451935 	 Accuracy: 0.826
# --------------------
# Epoch 0/20	Time 18.284 sec (18.284 sec)
# --------------------
# Epoch: 1/20
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([116])) that is different to the input size (torch.Size([116, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/40]	Time 1.756 (1.756)	Loss 0.3520 (0.3520)	Accuracy 0.8594 (0.8594)
# Batch: [5/40]	Time 0.042 (0.558)	Loss 0.3380 (0.3735)	Accuracy 0.8594 (0.8398)
# Batch: [10/40]	Time 0.076 (0.448)	Loss 0.3867 (0.3691)	Accuracy 0.8125 (0.8438)
# Batch: [15/40]	Time 0.062 (0.406)	Loss 0.3659 (0.3589)	Accuracy 0.8438 (0.8467)
# Batch: [20/40]	Time 1.372 (0.436)	Loss 0.3784 (0.3529)	Accuracy 0.8516 (0.8523)
# Batch: [25/40]	Time 0.056 (0.393)	Loss 0.3105 (0.3460)	Accuracy 0.8594 (0.8546)
# Batch: [30/40]	Time 0.052 (0.374)	Loss 0.3480 (0.3470)	Accuracy 0.8359 (0.8533)
# Batch: [35/40]	Time 0.070 (0.362)	Loss 0.3920 (0.3476)	Accuracy 0.8359 (0.8533)
# ----------
# Test: [0/4]	Time 1.600 (1.600)	Loss 0.3343 (0.3343)	Accuracy 0.8516 (0.8516)
# Avg validation loss: 0.38226978802680966 	 Accuracy: 0.836
# --------------------
# Epoch 1/20	Time 16.323 sec (17.303 sec)
# --------------------
# Epoch: 2/20
# Batch: [0/40]	Time 1.701 (1.701)	Loss 0.2962 (0.2962)	Accuracy 0.8906 (0.8906)
# Batch: [5/40]	Time 0.042 (0.556)	Loss 0.3924 (0.3141)	Accuracy 0.8672 (0.8737)
# Batch: [10/40]	Time 0.048 (0.452)	Loss 0.2940 (0.3207)	Accuracy 0.8672 (0.8636)
# Batch: [15/40]	Time 0.048 (0.408)	Loss 0.2871 (0.3114)	Accuracy 0.8594 (0.8672)
# Batch: [20/40]	Time 0.812 (0.425)	Loss 0.3603 (0.3030)	Accuracy 0.8906 (0.8754)
# Batch: [25/40]	Time 0.052 (0.380)	Loss 0.2683 (0.3012)	Accuracy 0.8750 (0.8765)
# Batch: [30/40]	Time 0.296 (0.372)	Loss 0.2537 (0.2984)	Accuracy 0.8984 (0.8773)
# Batch: [35/40]	Time 0.041 (0.353)	Loss 0.3283 (0.2924)	Accuracy 0.8672 (0.8789)
# ----------
# Test: [0/4]	Time 1.510 (1.510)	Loss 0.4188 (0.4188)	Accuracy 0.8438 (0.8438)
# Avg validation loss: 0.33187875628471375 	 Accuracy: 0.864
# --------------------
# Epoch 2/20	Time 15.869 sec (16.825 sec)
# --------------------
# Epoch: 3/20
# Batch: [0/40]	Time 1.856 (1.856)	Loss 0.2087 (0.2087)	Accuracy 0.9297 (0.9297)
# Batch: [5/40]	Time 0.044 (0.587)	Loss 0.1967 (0.2189)	Accuracy 0.9219 (0.9154)
# Batch: [10/40]	Time 0.048 (0.456)	Loss 0.1965 (0.2246)	Accuracy 0.9141 (0.9119)
# Batch: [15/40]	Time 0.045 (0.413)	Loss 0.2180 (0.2181)	Accuracy 0.9375 (0.9185)
# Batch: [20/40]	Time 0.822 (0.426)	Loss 0.1949 (0.2053)	Accuracy 0.9453 (0.9234)
# Batch: [25/40]	Time 0.129 (0.384)	Loss 0.1407 (0.1939)	Accuracy 0.9375 (0.9282)
# Batch: [30/40]	Time 0.052 (0.366)	Loss 0.0702 (0.1824)	Accuracy 0.9766 (0.9330)
# Batch: [35/40]	Time 0.348 (0.353)	Loss 0.1388 (0.1755)	Accuracy 0.9609 (0.9358)
# ----------
# Test: [0/4]	Time 1.681 (1.681)	Loss 0.2265 (0.2265)	Accuracy 0.9062 (0.9062)
# Avg validation loss: 0.20479872524738313 	 Accuracy: 0.928
# --------------------
# Epoch 3/20	Time 15.530 sec (16.501 sec)
# --------------------
# Epoch: 4/20
# Batch: [0/40]	Time 1.597 (1.597)	Loss 0.1253 (0.1253)	Accuracy 0.9375 (0.9375)
# Batch: [5/40]	Time 0.060 (0.551)	Loss 0.0964 (0.1249)	Accuracy 0.9453 (0.9479)
# Batch: [10/40]	Time 0.040 (0.445)	Loss 0.1890 (0.1240)	Accuracy 0.9297 (0.9524)
# Batch: [15/40]	Time 0.046 (0.406)	Loss 0.1377 (0.1182)	Accuracy 0.9609 (0.9561)
# Batch: [20/40]	Time 1.164 (0.444)	Loss 0.1235 (0.1172)	Accuracy 0.9688 (0.9580)
# Batch: [25/40]	Time 0.054 (0.410)	Loss 0.0606 (0.1115)	Accuracy 0.9766 (0.9594)
# Batch: [30/40]	Time 0.203 (0.381)	Loss 0.0289 (0.1038)	Accuracy 0.9922 (0.9627)
# Batch: [35/40]	Time 0.043 (0.362)	Loss 0.0649 (0.0961)	Accuracy 0.9766 (0.9659)
# ----------
# Test: [0/4]	Time 1.755 (1.755)	Loss 0.2388 (0.2388)	Accuracy 0.8906 (0.8906)
# Avg validation loss: 0.24926742458343507 	 Accuracy: 0.914
# --------------------
# Epoch 4/20	Time 15.982 sec (16.397 sec)
# --------------------
# Epoch: 5/20
# Batch: [0/40]	Time 1.852 (1.852)	Loss 0.0718 (0.0718)	Accuracy 0.9688 (0.9688)
# Batch: [5/40]	Time 0.048 (0.568)	Loss 0.0809 (0.0921)	Accuracy 0.9531 (0.9544)
# Batch: [10/40]	Time 0.070 (0.449)	Loss 0.0248 (0.0706)	Accuracy 0.9922 (0.9688)
# Batch: [15/40]	Time 0.060 (0.398)	Loss 0.0723 (0.0657)	Accuracy 0.9688 (0.9727)
# Batch: [20/40]	Time 1.453 (0.443)	Loss 0.0107 (0.0561)	Accuracy 1.0000 (0.9777)
# Batch: [25/40]	Time 0.055 (0.420)	Loss 0.0652 (0.0547)	Accuracy 0.9688 (0.9781)
# Batch: [30/40]	Time 0.056 (0.390)	Loss 0.0573 (0.0523)	Accuracy 0.9766 (0.9788)
# Batch: [35/40]	Time 0.040 (0.375)	Loss 0.0184 (0.0500)	Accuracy 0.9922 (0.9796)
# ----------
# Test: [0/4]	Time 2.086 (2.086)	Loss 0.0693 (0.0693)	Accuracy 0.9766 (0.9766)
# Avg validation loss: 0.11360706788301468 	 Accuracy: 0.964
# --------------------
# Epoch 5/20	Time 16.620 sec (16.434 sec)
# --------------------
# Epoch: 6/20
# Batch: [0/40]	Time 1.888 (1.888)	Loss 0.0070 (0.0070)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.050 (0.593)	Loss 0.0042 (0.0108)	Accuracy 1.0000 (0.9987)
# Batch: [10/40]	Time 0.065 (0.458)	Loss 0.0215 (0.0133)	Accuracy 0.9922 (0.9964)
# Batch: [15/40]	Time 0.098 (0.412)	Loss 0.0087 (0.0132)	Accuracy 1.0000 (0.9971)
# Batch: [20/40]	Time 1.248 (0.445)	Loss 0.0284 (0.0127)	Accuracy 0.9922 (0.9974)
# Batch: [25/40]	Time 0.081 (0.428)	Loss 0.0033 (0.0122)	Accuracy 1.0000 (0.9973)
# Batch: [30/40]	Time 0.244 (0.402)	Loss 0.0043 (0.0113)	Accuracy 1.0000 (0.9975)
# Batch: [35/40]	Time 0.048 (0.388)	Loss 0.0044 (0.0103)	Accuracy 1.0000 (0.9978)
# ----------
# Test: [0/4]	Time 2.578 (2.578)	Loss 0.1767 (0.1767)	Accuracy 0.9609 (0.9609)
# Avg validation loss: 0.10889925122261047 	 Accuracy: 0.97
# --------------------
# Epoch 6/20	Time 17.632 sec (16.606 sec)
# --------------------
# Epoch: 7/20
# Batch: [0/40]	Time 2.822 (2.822)	Loss 0.0125 (0.0125)	Accuracy 0.9922 (0.9922)
# Batch: [5/40]	Time 0.178 (0.858)	Loss 0.0032 (0.0125)	Accuracy 1.0000 (0.9948)
# Batch: [10/40]	Time 0.064 (0.687)	Loss 0.0130 (0.0123)	Accuracy 0.9922 (0.9957)
# Batch: [15/40]	Time 0.071 (0.621)	Loss 0.0034 (0.0117)	Accuracy 1.0000 (0.9956)
# Batch: [20/40]	Time 1.583 (0.647)	Loss 0.0007 (0.0104)	Accuracy 1.0000 (0.9963)
# Batch: [25/40]	Time 0.444 (0.626)	Loss 0.0005 (0.0089)	Accuracy 1.0000 (0.9970)
# Batch: [30/40]	Time 0.064 (0.591)	Loss 0.0042 (0.0084)	Accuracy 1.0000 (0.9972)
# Batch: [35/40]	Time 0.090 (0.550)	Loss 0.0132 (0.0085)	Accuracy 0.9922 (0.9967)
# ----------
# Test: [0/4]	Time 2.284 (2.284)	Loss 0.1574 (0.1574)	Accuracy 0.9609 (0.9609)
# Avg validation loss: 0.08875470554828643 	 Accuracy: 0.974
# --------------------
# Epoch 7/20	Time 24.002 sec (17.530 sec)
# --------------------
# Epoch: 8/20
# Batch: [0/40]	Time 2.637 (2.637)	Loss 0.0018 (0.0018)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.128 (0.829)	Loss 0.0005 (0.0011)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.064 (0.663)	Loss 0.0005 (0.0010)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.093 (0.602)	Loss 0.0029 (0.0012)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.852 (0.656)	Loss 0.0013 (0.0013)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.066 (0.614)	Loss 0.0008 (0.0013)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.136 (0.588)	Loss 0.0005 (0.0014)	Accuracy 1.0000 (0.9997)
# Batch: [35/40]	Time 0.052 (0.552)	Loss 0.0042 (0.0017)	Accuracy 1.0000 (0.9998)
# ----------
# Test: [0/4]	Time 2.215 (2.215)	Loss 0.0358 (0.0358)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.09824717935919762 	 Accuracy: 0.976
# --------------------
# Epoch 8/20	Time 23.938 sec (18.242 sec)
# --------------------
# Epoch: 9/20
# Batch: [0/40]	Time 2.725 (2.725)	Loss 0.0004 (0.0004)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.065 (0.835)	Loss 0.0002 (0.0012)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.064 (0.664)	Loss 0.0006 (0.0008)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.084 (0.598)	Loss 0.0006 (0.0007)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 2.116 (0.658)	Loss 0.0007 (0.0007)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.076 (0.621)	Loss 0.0002 (0.0006)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.043 (0.593)	Loss 0.0006 (0.0006)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.047 (0.563)	Loss 0.0003 (0.0005)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 2.151 (2.151)	Loss 0.0408 (0.0408)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.10121735835075378 	 Accuracy: 0.976
# --------------------
# Epoch 9/20	Time 24.040 sec (18.822 sec)
# --------------------
# Epoch: 10/20
# Batch: [0/40]	Time 2.628 (2.628)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.214 (0.829)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.056 (0.663)	Loss 0.0003 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.080 (0.598)	Loss 0.0004 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.920 (0.652)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.260 (0.618)	Loss 0.0001 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.066 (0.588)	Loss 0.0003 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.075 (0.559)	Loss 0.0001 (0.0002)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 2.430 (2.430)	Loss 0.0652 (0.0652)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.11269320088624954 	 Accuracy: 0.974
# --------------------
# Epoch 10/20	Time 24.140 sec (19.305 sec)
# --------------------
# Epoch: 11/20
# Batch: [0/40]	Time 2.751 (2.751)	Loss 0.0003 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.072 (0.847)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.089 (0.673)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.136 (0.610)	Loss 0.0003 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.738 (0.653)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.062 (0.614)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.432 (0.597)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.078 (0.569)	Loss 0.0001 (0.0002)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.914 (1.914)	Loss 0.1201 (0.1201)	Accuracy 0.9766 (0.9766)
# Avg validation loss: 0.11661181908845901 	 Accuracy: 0.974
# --------------------
# Epoch 11/20	Time 24.144 sec (19.709 sec)
# --------------------
# Epoch: 12/20
# Batch: [0/40]	Time 2.504 (2.504)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.296 (0.830)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.060 (0.662)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.072 (0.593)	Loss 0.0002 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 2.046 (0.651)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.065 (0.616)	Loss 0.0002 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.064 (0.593)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.055 (0.565)	Loss 0.0002 (0.0001)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 2.241 (2.241)	Loss 0.2339 (0.2339)	Accuracy 0.9609 (0.9609)
# Avg validation loss: 0.12032657086849213 	 Accuracy: 0.972
# --------------------
# Epoch 12/20	Time 24.157 sec (20.051 sec)
# --------------------
# Epoch: 13/20
# Batch: [0/40]	Time 2.683 (2.683)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.157 (0.860)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.092 (0.670)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.082 (0.602)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.984 (0.658)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.072 (0.619)	Loss 0.0002 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.064 (0.592)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.052 (0.567)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.747 (1.747)	Loss 0.0685 (0.0685)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.12371695366501809 	 Accuracy: 0.972
# --------------------
# Epoch 13/20	Time 24.259 sec (20.351 sec)
# --------------------
# Epoch: 14/20
# Batch: [0/40]	Time 2.775 (2.775)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.062 (0.809)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.078 (0.653)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.068 (0.591)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 2.036 (0.650)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.072 (0.615)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.068 (0.591)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.066 (0.567)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 2.259 (2.259)	Loss 0.1586 (0.1586)	Accuracy 0.9531 (0.9531)
# Avg validation loss: 0.12757175171375273 	 Accuracy: 0.972
# --------------------
# Epoch 14/20	Time 23.933 sec (20.590 sec)
# --------------------
# Epoch: 15/20
# Batch: [0/40]	Time 2.576 (2.576)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.176 (0.828)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.076 (0.669)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.100 (0.602)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.707 (0.646)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.364 (0.624)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.074 (0.594)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.051 (0.573)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 2.223 (2.223)	Loss 0.1731 (0.1731)	Accuracy 0.9609 (0.9609)
# Avg validation loss: 0.13023608335852624 	 Accuracy: 0.972
# --------------------
# Epoch 15/20	Time 24.400 sec (20.828 sec)
# --------------------
# Epoch: 16/20
# Batch: [0/40]	Time 2.143 (2.143)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.060 (0.638)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.045 (0.510)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.078 (0.455)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.144 (0.469)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.061 (0.438)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.078 (0.417)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.111 (0.400)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.424 (1.424)	Loss 0.1226 (0.1226)	Accuracy 0.9844 (0.9844)
# Avg validation loss: 0.13310397231578827 	 Accuracy: 0.972
# --------------------
# Epoch 16/20	Time 16.631 sec (20.581 sec)
# --------------------
# Epoch: 17/20
# Batch: [0/40]	Time 1.695 (1.695)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.123 (0.542)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.056 (0.441)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.047 (0.392)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.214 (0.425)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.344 (0.399)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.270 (0.390)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.039 (0.376)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.594 (1.594)	Loss 0.1671 (0.1671)	Accuracy 0.9688 (0.9688)
# Avg validation loss: 0.13624758416414262 	 Accuracy: 0.972
# --------------------
# Epoch 17/20	Time 15.884 sec (20.320 sec)
# --------------------
# Epoch: 18/20
# Batch: [0/40]	Time 1.904 (1.904)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.052 (0.566)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.051 (0.447)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.075 (0.404)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.285 (0.433)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.044 (0.409)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.060 (0.388)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.228 (0.378)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.487 (1.487)	Loss 0.2006 (0.2006)	Accuracy 0.9531 (0.9531)
# Avg validation loss: 0.13834769701957703 	 Accuracy: 0.974
# --------------------
# Epoch 18/20	Time 15.954 sec (20.091 sec)
# --------------------
# Epoch: 19/20
# Batch: [0/40]	Time 1.408 (1.408)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.395 (0.547)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.072 (0.447)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.056 (0.400)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.840 (0.411)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.580 (0.407)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.042 (0.385)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.060 (0.373)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.499 (1.499)	Loss 0.1317 (0.1317)	Accuracy 0.9688 (0.9688)
# Avg validation loss: 0.1394776728153229 	 Accuracy: 0.972
# --------------------
# Epoch 19/20	Time 15.831 sec (19.878 sec)
# --------------------

# %%
plt.subplot(221)
plt.title('training classification loss')
plt.plot(train_losses)
plt.subplot(222)
plt.title('training accuracy')
plt.plot(train_accs)
plt.subplot(223)
plt.title('validation loss')
plt.plot(val_losses)
plt.subplot(224)
plt.title('validation accuracy')
plt.plot(val_accs)

# %% [markdown]
# ## Train only adversary

# %%
from synthetic_dataloader import *
gender_train = GenderDataset(train_df)
gender_valid = GenderDataset(val_df)

# %%
advtrain_loader = DataLoader(gender_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
advval_loader = DataLoader(gender_valid, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)

# %%
adv_encoder = LeNet()
adversary = ClassNet()

# %%
adv_criterion = nn.BCELoss()
opt_adv = optim.Adam(adversary.parameters(), lr=0.001, betas=(0.9, 0.999))
opt_adv_enc = optim.Adam(adv_encoder.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler_adv = lr_scheduler.StepLR(optimizer=opt_adv, gamma=0.99, step_size=1)
scheduler_adv_enc = lr_scheduler.StepLR(optimizer=opt_adv_enc, gamma=0.99, step_size=1)

# %%
num_epochs = 20
train_losses = []
train_accs = []
val_losses = []
val_accs = []
epoch_time = AverageMeter()
ep_end = time.time()
for epoch in range(0, num_epochs):
        print('Epoch: {}/{}'.format(epoch, num_epochs))
        scheduler_adv_enc.step()
        scheduler_adv.step()
        # train
        train_loss, train_acc = train_encoder_classifier_epoch(advtrain_loader,adv_encoder,
                                adversary, opt_adv_enc,
                                opt_adv, adv_criterion, device)
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        # validate
        print('-'*10)
        val_loss, val_acc = validate_encoder_classifier_epoch(advval_loader, adv_encoder, adversary,
                                 adv_criterion, device)

        print('Avg validation loss: {} \t Accuracy: {}'.format(val_loss, val_acc))
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        
        print('-' * 20)
        epoch_time.update(time.time() - ep_end)
        ep_end = time.time()
        print('Epoch {}/{}\t'
              'Time {epoch_time.val:.3f} sec ({epoch_time.avg:.3f} sec)'.format(epoch, num_epochs, epoch_time=epoch_time))
        print('-'*20)
# Out:
# Epoch: 0/20
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/40]	Time 1.836 (1.836)	Loss 0.6934 (0.6934)	Accuracy 0.5156 (0.5156)
# Batch: [5/40]	Time 0.109 (0.553)	Loss 0.3970 (0.5677)	Accuracy 0.8281 (0.6901)
# Batch: [10/40]	Time 0.048 (0.444)	Loss 0.2235 (0.4190)	Accuracy 0.9297 (0.7926)
# Batch: [15/40]	Time 0.060 (0.402)	Loss 0.0874 (0.3426)	Accuracy 0.9609 (0.8359)
# Batch: [20/40]	Time 1.259 (0.436)	Loss 0.1017 (0.3045)	Accuracy 0.9609 (0.8594)
# Batch: [25/40]	Time 0.073 (0.409)	Loss 0.0800 (0.2689)	Accuracy 0.9844 (0.8786)
# Batch: [30/40]	Time 0.048 (0.389)	Loss 0.0984 (0.2428)	Accuracy 0.9609 (0.8929)
# Batch: [35/40]	Time 0.037 (0.359)	Loss 0.0756 (0.2175)	Accuracy 0.9688 (0.9052)
# ----------
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Test: [0/4]	Time 1.561 (1.561)	Loss 0.0947 (0.0947)	Accuracy 0.9531 (0.9531)
# Avg validation loss: 0.0548993019759655 	 Accuracy: 0.98
# --------------------
# Epoch 0/20	Time 15.603 sec (15.603 sec)
# --------------------
# Epoch: 1/20
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([116])) that is different to the input size (torch.Size([116, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/40]	Time 1.999 (1.999)	Loss 0.0747 (0.0747)	Accuracy 0.9766 (0.9766)
# Batch: [5/40]	Time 0.052 (0.599)	Loss 0.0310 (0.0500)	Accuracy 0.9844 (0.9831)
# Batch: [10/40]	Time 0.040 (0.460)	Loss 0.0791 (0.0440)	Accuracy 0.9922 (0.9858)
# Batch: [15/40]	Time 0.046 (0.407)	Loss 0.0572 (0.0399)	Accuracy 0.9922 (0.9883)
# Batch: [20/40]	Time 1.116 (0.436)	Loss 0.0187 (0.0356)	Accuracy 1.0000 (0.9900)
# Batch: [25/40]	Time 0.053 (0.417)	Loss 0.0201 (0.0323)	Accuracy 1.0000 (0.9916)
# Batch: [30/40]	Time 0.050 (0.399)	Loss 0.0196 (0.0301)	Accuracy 0.9844 (0.9917)
# Batch: [35/40]	Time 0.054 (0.371)	Loss 0.0058 (0.0271)	Accuracy 1.0000 (0.9928)
# ----------
# Test: [0/4]	Time 1.715 (1.715)	Loss 0.0055 (0.0055)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.004822519898414612 	 Accuracy: 1.0
# --------------------
# Epoch 1/20	Time 16.358 sec (15.981 sec)
# --------------------
# Epoch: 2/20
# Batch: [0/40]	Time 1.653 (1.653)	Loss 0.0103 (0.0103)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.175 (0.546)	Loss 0.0039 (0.0052)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.056 (0.429)	Loss 0.0022 (0.0050)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.052 (0.393)	Loss 0.0035 (0.0052)	Accuracy 1.0000 (0.9995)
# Batch: [20/40]	Time 1.122 (0.418)	Loss 0.0123 (0.0050)	Accuracy 0.9922 (0.9993)
# Batch: [25/40]	Time 0.044 (0.392)	Loss 0.0014 (0.0051)	Accuracy 1.0000 (0.9988)
# Batch: [30/40]	Time 0.043 (0.377)	Loss 0.0237 (0.0060)	Accuracy 0.9844 (0.9980)
# Batch: [35/40]	Time 0.085 (0.356)	Loss 0.0011 (0.0057)	Accuracy 1.0000 (0.9983)
# ----------
# Test: [0/4]	Time 1.509 (1.509)	Loss 0.0031 (0.0031)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.002510822453536093 	 Accuracy: 1.0
# --------------------
# Epoch 2/20	Time 15.528 sec (15.830 sec)
# --------------------
# Epoch: 3/20
# Batch: [0/40]	Time 1.860 (1.860)	Loss 0.0023 (0.0023)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.078 (0.551)	Loss 0.0048 (0.0031)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.068 (0.427)	Loss 0.0069 (0.0052)	Accuracy 1.0000 (0.9986)
# Batch: [15/40]	Time 0.055 (0.385)	Loss 0.0052 (0.0046)	Accuracy 1.0000 (0.9990)
# Batch: [20/40]	Time 0.905 (0.408)	Loss 0.0049 (0.0039)	Accuracy 1.0000 (0.9993)
# Batch: [25/40]	Time 0.188 (0.397)	Loss 0.0004 (0.0033)	Accuracy 1.0000 (0.9994)
# Batch: [30/40]	Time 0.200 (0.387)	Loss 0.0001 (0.0029)	Accuracy 1.0000 (0.9995)
# Batch: [35/40]	Time 0.065 (0.364)	Loss 0.0023 (0.0027)	Accuracy 1.0000 (0.9996)
# ----------
# Test: [0/4]	Time 1.723 (1.723)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.0023315666394191793 	 Accuracy: 1.0
# --------------------
# Epoch 3/20	Time 16.174 sec (15.916 sec)
# --------------------
# Epoch: 4/20
# Batch: [0/40]	Time 1.739 (1.739)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.564 (0.597)	Loss 0.0001 (0.0005)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.056 (0.478)	Loss 0.0002 (0.0008)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.064 (0.432)	Loss 0.0003 (0.0007)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.837 (0.427)	Loss 0.0002 (0.0005)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.320 (0.416)	Loss 0.0002 (0.0005)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.216 (0.404)	Loss 0.0000 (0.0005)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.051 (0.375)	Loss 0.0002 (0.0005)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.626 (1.626)	Loss 0.0023 (0.0023)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.0009321473098061688 	 Accuracy: 1.0
# --------------------
# Epoch 4/20	Time 16.598 sec (16.052 sec)
# --------------------
# Epoch: 5/20
# Batch: [0/40]	Time 1.939 (1.939)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.050 (0.570)	Loss 0.0001 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.048 (0.447)	Loss 0.0001 (0.0006)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.060 (0.403)	Loss 0.0000 (0.0005)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.140 (0.433)	Loss 0.0001 (0.0004)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.036 (0.406)	Loss 0.0031 (0.0013)	Accuracy 1.0000 (0.9997)
# Batch: [30/40]	Time 0.048 (0.385)	Loss 0.0010 (0.0015)	Accuracy 1.0000 (0.9995)
# Batch: [35/40]	Time 0.076 (0.369)	Loss 0.0087 (0.0018)	Accuracy 0.9922 (0.9993)
# ----------
# Test: [0/4]	Time 1.765 (1.765)	Loss 0.0101 (0.0101)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.005931207314133644 	 Accuracy: 0.998
# --------------------
# Epoch 5/20	Time 15.992 sec (16.042 sec)
# --------------------
# Epoch: 6/20
# Batch: [0/40]	Time 1.816 (1.816)	Loss 0.0016 (0.0016)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.057 (0.550)	Loss 0.0019 (0.0033)	Accuracy 1.0000 (0.9987)
# Batch: [10/40]	Time 0.142 (0.443)	Loss 0.0176 (0.0136)	Accuracy 0.9922 (0.9943)
# Batch: [15/40]	Time 0.047 (0.390)	Loss 0.0385 (0.0208)	Accuracy 0.9844 (0.9922)
# Batch: [20/40]	Time 1.274 (0.434)	Loss 0.0006 (0.0248)	Accuracy 1.0000 (0.9903)
# Batch: [25/40]	Time 0.056 (0.408)	Loss 0.0001 (0.0211)	Accuracy 1.0000 (0.9919)
# Batch: [30/40]	Time 0.047 (0.384)	Loss 0.0413 (0.0205)	Accuracy 0.9922 (0.9924)
# Batch: [35/40]	Time 0.080 (0.362)	Loss 0.0014 (0.0178)	Accuracy 1.0000 (0.9935)
# ----------
# Test: [0/4]	Time 1.219 (1.219)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.008787547398358584 	 Accuracy: 0.996
# --------------------
# Epoch 6/20	Time 15.341 sec (15.942 sec)
# --------------------
# Epoch: 7/20
# Batch: [0/40]	Time 1.518 (1.518)	Loss 0.0013 (0.0013)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.804 (0.607)	Loss 0.0011 (0.0050)	Accuracy 1.0000 (0.9987)
# Batch: [10/40]	Time 0.054 (0.466)	Loss 0.0021 (0.0034)	Accuracy 1.0000 (0.9993)
# Batch: [15/40]	Time 0.056 (0.418)	Loss 0.0015 (0.0028)	Accuracy 1.0000 (0.9995)
# Batch: [20/40]	Time 0.620 (0.420)	Loss 0.0002 (0.0024)	Accuracy 1.0000 (0.9996)
# Batch: [25/40]	Time 0.876 (0.420)	Loss 0.0011 (0.0023)	Accuracy 1.0000 (0.9997)
# Batch: [30/40]	Time 0.068 (0.400)	Loss 0.0004 (0.0024)	Accuracy 1.0000 (0.9995)
# Batch: [35/40]	Time 0.048 (0.382)	Loss 0.0002 (0.0022)	Accuracy 1.0000 (0.9996)
# ----------
# Test: [0/4]	Time 1.501 (1.501)	Loss 0.0003 (0.0003)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.004828862890251912 	 Accuracy: 0.996
# --------------------
# Epoch 7/20	Time 16.290 sec (15.986 sec)
# --------------------
# Epoch: 8/20
# Batch: [0/40]	Time 1.890 (1.890)	Loss 0.0002 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.060 (0.567)	Loss 0.0011 (0.0004)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.062 (0.444)	Loss 0.0000 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.076 (0.401)	Loss 0.0001 (0.0004)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.227 (0.435)	Loss 0.0001 (0.0004)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.054 (0.414)	Loss 0.0002 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.052 (0.395)	Loss 0.0000 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.037 (0.370)	Loss 0.0000 (0.0003)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.716 (1.716)	Loss 0.0112 (0.0112)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.004550385275069857 	 Accuracy: 0.996
# --------------------
# Epoch 8/20	Time 16.294 sec (16.020 sec)
# --------------------
# Epoch: 9/20
# Batch: [0/40]	Time 1.725 (1.725)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.214 (0.542)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.378 (0.469)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.049 (0.407)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.826 (0.424)	Loss 0.0003 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.484 (0.417)	Loss 0.0003 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.186 (0.399)	Loss 0.0002 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.044 (0.376)	Loss 0.0000 (0.0001)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.664 (1.664)	Loss 0.0048 (0.0048)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.0017919473464353358 	 Accuracy: 1.0
# --------------------
# Epoch 9/20	Time 16.259 sec (16.044 sec)
# --------------------
# Epoch: 10/20
# Batch: [0/40]	Time 1.689 (1.689)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.040 (0.534)	Loss 0.0001 (0.0001)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.072 (0.444)	Loss 0.0000 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.098 (0.401)	Loss 0.0000 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.220 (0.438)	Loss 0.0000 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.070 (0.410)	Loss 0.0001 (0.0003)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.051 (0.389)	Loss 0.0001 (0.0002)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.048 (0.367)	Loss 0.0003 (0.0002)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.548 (1.548)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.007390034448704682 	 Accuracy: 0.996
# --------------------
# Epoch 10/20	Time 15.945 sec (16.035 sec)
# --------------------
# Epoch: 11/20
# Batch: [0/40]	Time 2.079 (2.079)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.053 (0.607)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.056 (0.475)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.052 (0.434)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.320 (0.461)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.056 (0.430)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.081 (0.404)	Loss 0.0002 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.048 (0.377)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.765 (1.765)	Loss 0.0258 (0.0258)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.011202262550206796 	 Accuracy: 0.996
# --------------------
# Epoch 11/20	Time 16.324 sec (16.059 sec)
# --------------------
# Epoch: 12/20
# Batch: [0/40]	Time 1.638 (1.638)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.056 (0.521)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.064 (0.425)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.052 (0.394)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.363 (0.440)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.048 (0.399)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.242 (0.382)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.060 (0.361)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.871 (1.871)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.012251965381961782 	 Accuracy: 0.996
# --------------------
# Epoch 12/20	Time 15.904 sec (16.047 sec)
# --------------------
# Epoch: 13/20
# Batch: [0/40]	Time 1.888 (1.888)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.052 (0.567)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.079 (0.442)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.081 (0.399)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.307 (0.433)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.052 (0.410)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.052 (0.383)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.056 (0.361)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.701 (1.701)	Loss 0.0038 (0.0038)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.013460822459310294 	 Accuracy: 0.996
# --------------------
# Epoch 13/20	Time 15.896 sec (16.036 sec)
# --------------------
# Epoch: 14/20
# Batch: [0/40]	Time 1.797 (1.797)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.187 (0.532)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.205 (0.444)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.083 (0.402)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 0.874 (0.415)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.202 (0.399)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.092 (0.381)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.097 (0.357)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.417 (1.417)	Loss 0.0375 (0.0375)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.013525157350406516 	 Accuracy: 0.996
# --------------------
# Epoch 14/20	Time 15.606 sec (16.007 sec)
# --------------------
# Epoch: 15/20
# Batch: [0/40]	Time 1.889 (1.889)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.071 (0.574)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.040 (0.447)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.040 (0.393)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.232 (0.430)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.092 (0.407)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.056 (0.391)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.037 (0.365)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.339 (1.339)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.01562072706732215 	 Accuracy: 0.996
# --------------------
# Epoch 15/20	Time 15.516 sec (15.977 sec)
# --------------------
# Epoch: 16/20
# Batch: [0/40]	Time 1.855 (1.855)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.052 (0.559)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.070 (0.450)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.080 (0.407)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.215 (0.436)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.070 (0.412)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.076 (0.394)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.050 (0.375)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.617 (1.617)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Avg validation loss: 0.015427447115172981 	 Accuracy: 0.996
# --------------------
# Epoch 16/20	Time 16.034 sec (15.980 sec)
# --------------------
# Epoch: 17/20
# Batch: [0/40]	Time 1.886 (1.886)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.080 (0.565)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.081 (0.444)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.079 (0.397)	Loss 0.0001 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.408 (0.441)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.059 (0.414)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.084 (0.396)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.039 (0.373)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.266 (1.266)	Loss 0.0178 (0.0178)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.015812636989830934 	 Accuracy: 0.996
# --------------------
# Epoch 17/20	Time 15.784 sec (15.969 sec)
# --------------------
# Epoch: 18/20
# Batch: [0/40]	Time 1.766 (1.766)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.048 (0.535)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.196 (0.443)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.060 (0.406)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.184 (0.428)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.049 (0.405)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.253 (0.395)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.047 (0.375)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.273 (1.273)	Loss 0.0179 (0.0179)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.01613520247111501 	 Accuracy: 0.996
# --------------------
# Epoch 18/20	Time 15.673 sec (15.954 sec)
# --------------------
# Epoch: 19/20
# Batch: [0/40]	Time 1.690 (1.690)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [5/40]	Time 0.076 (0.571)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [10/40]	Time 0.054 (0.448)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [15/40]	Time 0.044 (0.416)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [20/40]	Time 1.275 (0.458)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [25/40]	Time 0.343 (0.440)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [30/40]	Time 0.056 (0.418)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# Batch: [35/40]	Time 0.082 (0.389)	Loss 0.0000 (0.0000)	Accuracy 1.0000 (1.0000)
# ----------
# Test: [0/4]	Time 1.567 (1.567)	Loss 0.0422 (0.0422)	Accuracy 0.9922 (0.9922)
# Avg validation loss: 0.016059023868176155 	 Accuracy: 0.996
# --------------------
# Epoch 19/20	Time 16.475 sec (15.980 sec)
# --------------------

# %%
plt.subplot(221)
plt.title('training classification loss')
plt.plot(train_losses)
plt.subplot(222)
plt.title('training accuracy')
plt.plot(train_accs)
plt.subplot(223)
plt.title('validation loss')
plt.plot(val_losses)
plt.subplot(224)
plt.title('validation accuracy')
plt.plot(val_accs)

# %% [markdown]
# ## Train adversary on original encoder

# %% [markdown]
# ## LAFTR Training

# %%
from synthetic_dataloader import *
gender_train = ShapeGenderDataset(train_df)
gender_valid = ShapeGenderDataset(val_df)

# %%
laftrtrain_loader = DataLoader(gender_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
laftrval_loader = DataLoader(gender_valid, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)

# %%
laftr_encoder = LeNet()
laftr_adversary = ClassNet()
laftr_classifier = ClassNet()

# %%
laftr_adv_criterion = AdvDemographicParityLoss()
laftr_cls_criterion = nn.BCELoss()

# %%
laftr_opt_adv = optim.Adam(laftr_adversary.parameters(), lr=0.001, betas=(0.9, 0.999))
laftr_opt_cls = optim.Adam(laftr_classifier.parameters(), lr=0.001, betas=(0.9, 0.999))
laftr_opt_enc = optim.Adam(laftr_encoder.parameters(), lr=0.001, betas=(0.9, 0.999))

laftr_scheduler_adv = lr_scheduler.StepLR(optimizer=laftr_opt_adv, gamma=0.99, step_size=1)
laftr_scheduler_cls = lr_scheduler.StepLR(optimizer=laftr_opt_cls, gamma=0.99, step_size=1)
laftr_scheduler_enc = lr_scheduler.StepLR(optimizer=laftr_opt_enc, gamma=0.99, step_size=1)

# %%
num_epochs = 20

clsTrain_losses = []
clsTrain_accs = []
clsTrainCombined_losses = []
advTrain_losses = []
advTrain_accs = []
advTrainCombined_losses = []

combinedVal_losses = []
clsVal_losses = []
clsVal_accs = []
advVal_losses = []
advVal_accs = []

epoch_time = AverageMeter()

# %%
ep_end = time.time()
for epoch in range(0, num_epochs):
        print('Epoch: {}/{}'.format(epoch, num_epochs))

        laftr_scheduler_adv.step()
        laftr_scheduler_cls.step()
        laftr_scheduler_enc.step()
        
        cls_loss, cls_en_combinedLoss, cls_en_acc, adv_loss, adv_combinedLoss, adv_acc = laftr_epoch_dp(laftrtrain_loader,
                                                        laftr_encoder, laftr_classifier, laftr_adversary, laftr_opt_enc,
                                                        laftr_opt_cls, laftr_opt_adv, 
                                                        laftr_cls_criterion, laftr_adv_criterion, device)
        
        clsTrain_losses.append(cls_loss)
        clsTrain_accs.append(cls_en_acc)
        clsTrainCombined_losses.append(cls_en_combinedLoss)
        advTrain_losses.append(adv_loss)
        advTrain_accs.append(adv_acc)
        advTrainCombined_losses.append(adv_combinedLoss)
        
        print('Classifier accuracy: {}\t Adversary Accuracy: {}'.format(cls_en_acc, adv_acc))
        # validate
        print('-'*10)
        
        combinedVal_loss, clsVal_loss, clsVal_acc, advVal_loss, advVal_acc = laftr_validate_dp(laftrval_loader,
                                                        laftr_encoder, laftr_classifier, laftr_adversary, 
                                                        laftr_cls_criterion, laftr_adv_criterion, device)
        
        combinedVal_losses.append(combinedVal_loss)
        clsVal_losses.append(clsVal_loss)
        clsVal_accs.append(clsVal_acc)
        advVal_losses.append(advVal_loss)
        advVal_accs.append(advVal_acc)
        
        print('Classifier validation acc: {:.4f} \t Adv validation acc: {:.4f}'.format(clsVal_acc, advVal_acc))
        
        print('-' * 20)
        epoch_time.update(time.time() - ep_end)
        ep_end = time.time()
        print('Epoch {}/{}\t'
              'Time {epoch_time.val:.3f} sec ({epoch_time.avg:.3f} sec)'.format(epoch, num_epochs, epoch_time=epoch_time))
        print('-'*20)
# Out:
# Epoch: 0/20
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([128])) that is different to the input size (torch.Size([128, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/40]	Time 1.887 (1.887)
# Classifier loss 0.6932 (0.6932)	Adversary loss -0.0414 (-0.0414)
# Combined Loss during classifier step 0.6930 (0.6930)	Combined Loss during adversary step -0.6379 (-0.6379)
# Classifier Accuracy 0.5078 (0.5078)	Adversary Accuracy 0.5234 (0.5234)
# Batch: [5/40]	Time 0.095 (0.576)
# Classifier loss 0.6025 (0.6427)	Adversary loss -0.3699 (-0.2155)
# Combined Loss during classifier step 0.3580 (0.5158)	Combined Loss during adversary step -0.2261 (-0.4007)
# Classifier Accuracy 0.6641 (0.6055)	Adversary Accuracy 0.2188 (0.3685)
# Batch: [10/40]	Time 0.082 (0.449)
# Classifier loss 0.5747 (0.6111)	Adversary loss -0.5835 (-0.3666)
# Combined Loss during classifier step 0.0757 (0.3320)	Combined Loss during adversary step 0.0620 (-0.2201)
# Classifier Accuracy 0.7188 (0.6712)	Adversary Accuracy 0.1094 (0.2663)
# Batch: [15/40]	Time 0.082 (0.410)
# Classifier loss 0.4709 (0.5986)	Adversary loss -0.6557 (-0.4443)
# Combined Loss during classifier step -0.1502 (0.2274)	Combined Loss during adversary step 0.2088 (-0.1310)
# Classifier Accuracy 0.8203 (0.6880)	Adversary Accuracy 0.1406 (0.2305)
# Batch: [20/40]	Time 1.156 (0.434)
# Classifier loss 0.5733 (0.5997)	Adversary loss -0.6002 (-0.4866)
# Combined Loss during classifier step 0.3947 (0.2258)	Combined Loss during adversary step 0.0077 (-0.0939)
# Classifier Accuracy 0.7422 (0.6979)	Adversary Accuracy 0.1562 (0.2102)
# Batch: [25/40]	Time 0.074 (0.410)
# Classifier loss 0.5594 (0.5826)	Adversary loss -0.1499 (-0.4697)
# Combined Loss during classifier step 0.5148 (0.2578)	Combined Loss during adversary step -0.4794 (-0.0980)
# Classifier Accuracy 0.7812 (0.7118)	Adversary Accuracy 0.4375 (0.2200)
# Batch: [30/40]	Time 0.105 (0.383)
# Classifier loss 0.7821 (0.6019)	Adversary loss -0.0008 (-0.3958)
# Combined Loss during classifier step 0.7816 (0.3288)	Combined Loss during adversary step -0.5498 (-0.1795)
# Classifier Accuracy 0.6953 (0.7114)	Adversary Accuracy 0.4922 (0.2676)
# Batch: [35/40]	Time 0.251 (0.370)
# Classifier loss 0.5292 (0.6319)	Adversary loss 0.0002 (-0.3408)
# Combined Loss during classifier step 0.5294 (0.3967)	Combined Loss during adversary step -0.5743 (-0.2589)
# Classifier Accuracy 0.7500 (0.6992)	Adversary Accuracy 0.5078 (0.2975)
# Classifier accuracy: 0.7032	 Adversary Accuracy: 0.3114
# ----------
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Test batch: [0/4]	Time 1.825 (1.825)
# Classifier loss 0.5853 (0.5853)	Adversary loss 0.0001 (0.0001)
# Combined Loss 0.5854 (0.5854)	Classifier Accuracy 0.7500 (0.7500)	Adversary Accuracy 0.5000 (0.5000)
# Classifier validation acc: 0.7300 	 Adv validation acc: 0.4800
# --------------------
# Epoch 0/20	Time 16.153 sec (16.153 sec)
# --------------------
# Epoch: 1/20
# /home/var/anaconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([116])) that is different to the input size (torch.Size([116, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/40]	Time 2.107 (2.107)
# Classifier loss 0.5842 (0.5842)	Adversary loss 0.0000 (0.0000)
# Combined Loss during classifier step 0.5843 (0.5843)	Combined Loss during adversary step -0.5916 (-0.5916)
# Classifier Accuracy 0.7266 (0.7266)	Adversary Accuracy 0.5469 (0.5469)
# Batch: [5/40]	Time 0.124 (0.628)
# Classifier loss 0.6048 (0.6052)	Adversary loss -0.0037 (-0.0010)
# Combined Loss during classifier step 0.6034 (0.6053)	Combined Loss during adversary step -0.6137 (-0.6124)
# Classifier Accuracy 0.6797 (0.6940)	Adversary Accuracy 0.5000 (0.5117)
# Batch: [10/40]	Time 0.089 (0.490)
# Classifier loss 0.5772 (0.6046)	Adversary loss -0.0278 (-0.0077)
# Combined Loss during classifier step 0.5586 (0.6004)	Combined Loss during adversary step -0.5329 (-0.5968)
# Classifier Accuracy 0.6562 (0.6520)	Adversary Accuracy 0.4844 (0.5178)
# Batch: [15/40]	Time 0.083 (0.437)
# Classifier loss 0.5628 (0.5939)	Adversary loss -0.0729 (-0.0217)
# Combined Loss during classifier step 0.5081 (0.5793)	Combined Loss during adversary step -0.4859 (-0.5686)
# Classifier Accuracy 0.7734 (0.6787)	Adversary Accuracy 0.5156 (0.5195)
# Batch: [20/40]	Time 1.285 (0.463)
# Classifier loss 0.5187 (0.5822)	Adversary loss -0.2089 (-0.0468)
# Combined Loss during classifier step 0.3470 (0.5478)	Combined Loss during adversary step -0.3119 (-0.5329)
# Classifier Accuracy 0.8203 (0.7031)	Adversary Accuracy 0.4844 (0.5197)
# Batch: [25/40]	Time 0.082 (0.430)
# Classifier loss 0.5439 (0.5801)	Adversary loss -0.2588 (-0.0824)
# Combined Loss during classifier step 0.3227 (0.5138)	Combined Loss during adversary step -0.2830 (-0.4958)
# Classifier Accuracy 0.8047 (0.7172)	Adversary Accuracy 0.5000 (0.5150)
# Batch: [30/40]	Time 0.084 (0.389)
# Classifier loss 0.5659 (0.5775)	Adversary loss -0.3617 (-0.1190)
# Combined Loss during classifier step 0.2418 (0.4791)	Combined Loss during adversary step -0.2067 (-0.4575)
# Classifier Accuracy 0.7812 (0.7296)	Adversary Accuracy 0.5078 (0.5129)
# Batch: [35/40]	Time 0.104 (0.372)
# Classifier loss 0.6235 (0.5785)	Adversary loss -0.4340 (-0.1563)
# Combined Loss during classifier step 0.2151 (0.4441)	Combined Loss during adversary step -0.1856 (-0.4199)
# Classifier Accuracy 0.7344 (0.7331)	Adversary Accuracy 0.3281 (0.5037)
# Classifier accuracy: 0.7336	 Adversary Accuracy: 0.4902
# ----------
# Test batch: [0/4]	Time 1.748 (1.748)
# Classifier loss 0.5997 (0.5997)	Adversary loss -0.4959 (-0.4959)
# Combined Loss 0.1038 (0.1038)	Classifier Accuracy 0.6406 (0.6406)	Adversary Accuracy 0.1719 (0.1719)
# Classifier validation acc: 0.6740 	 Adv validation acc: 0.1960
# --------------------
# Epoch 1/20	Time 16.218 sec (16.186 sec)
# --------------------
# Epoch: 2/20
# Batch: [0/40]	Time 1.894 (1.894)
# Classifier loss 0.5912 (0.5912)	Adversary loss -0.5151 (-0.5151)
# Combined Loss during classifier step 0.1033 (0.1033)	Combined Loss during adversary step -0.0641 (-0.0641)
# Classifier Accuracy 0.7109 (0.7109)	Adversary Accuracy 0.0156 (0.0156)
# Batch: [5/40]	Time 0.182 (0.584)
# Classifier loss 0.6795 (0.5914)	Adversary loss -0.5849 (-0.5387)
# Combined Loss during classifier step 0.1433 (0.0907)	Combined Loss during adversary step -0.0061 (-0.0291)
# Classifier Accuracy 0.7344 (0.6758)	Adversary Accuracy 0.0312 (0.0286)
# Batch: [10/40]	Time 0.093 (0.455)
# Classifier loss 0.5395 (0.5569)	Adversary loss -0.7963 (-0.6417)
# Combined Loss during classifier step -0.2213 (-0.0404)	Combined Loss during adversary step 0.2454 (0.1022)
# Classifier Accuracy 0.7734 (0.7308)	Adversary Accuracy 0.0703 (0.0376)
# Batch: [15/40]	Time 0.085 (0.413)
# Classifier loss 0.6724 (0.5754)	Adversary loss -0.8525 (-0.7011)
# Combined Loss during classifier step -0.1599 (-0.0896)	Combined Loss during adversary step 0.2340 (0.1513)
# Classifier Accuracy 0.5703 (0.7402)	Adversary Accuracy 0.0703 (0.0493)
# Batch: [20/40]	Time 1.006 (0.437)
# Classifier loss 0.5913 (0.5650)	Adversary loss -0.8803 (-0.7337)
# Combined Loss during classifier step -0.2602 (-0.1353)	Combined Loss during adversary step 0.2918 (0.1935)
# Classifier Accuracy 0.7812 (0.7437)	Adversary Accuracy 0.0469 (0.0521)
# Batch: [25/40]	Time 0.104 (0.412)
# Classifier loss 0.5976 (0.5757)	Adversary loss -0.8386 (-0.7585)
# Combined Loss during classifier step -0.2121 (-0.1492)	Combined Loss during adversary step 0.1577 (0.2083)
# Classifier Accuracy 0.6797 (0.7449)	Adversary Accuracy 0.0469 (0.0508)
# Batch: [30/40]	Time 0.075 (0.383)
# Classifier loss 0.4606 (0.5679)	Adversary loss -0.8230 (-0.7698)
# Combined Loss during classifier step -0.0549 (-0.1574)	Combined Loss during adversary step 0.3920 (0.2347)
# Classifier Accuracy 0.8125 (0.7437)	Adversary Accuracy 0.0547 (0.0532)
# Batch: [35/40]	Time 0.095 (0.368)
# Classifier loss 0.4646 (0.5592)	Adversary loss -0.3788 (-0.7484)
# Combined Loss during classifier step 0.2894 (-0.1035)	Combined Loss during adversary step -0.0990 (0.2191)
# Classifier Accuracy 0.7500 (0.7491)	Adversary Accuracy 0.2969 (0.0686)
# Classifier accuracy: 0.7522	 Adversary Accuracy: 0.0742
# ----------
# Test batch: [0/4]	Time 1.792 (1.792)
# Classifier loss 0.7308 (0.7308)	Adversary loss -0.0074 (-0.0074)
# Combined Loss 0.7234 (0.7234)	Classifier Accuracy 0.7344 (0.7344)	Adversary Accuracy 0.4688 (0.4688)
# Classifier validation acc: 0.7460 	 Adv validation acc: 0.5180
# --------------------
# Epoch 2/20	Time 16.020 sec (16.131 sec)
# --------------------
# Epoch: 3/20
# Batch: [0/40]	Time 1.770 (1.770)
# Classifier loss 0.7846 (0.7846)	Adversary loss -0.0090 (-0.0090)
# Combined Loss during classifier step 0.7811 (0.7811)	Combined Loss during adversary step -0.5296 (-0.5296)
# Classifier Accuracy 0.7344 (0.7344)	Adversary Accuracy 0.4219 (0.4219)
# Batch: [5/40]	Time 0.316 (0.568)
# Classifier loss 0.4528 (0.5824)	Adversary loss 0.0000 (-0.0016)
# Combined Loss during classifier step 0.4529 (0.5817)	Combined Loss during adversary step -0.5086 (-0.5371)
# Classifier Accuracy 0.8047 (0.7344)	Adversary Accuracy 0.4766 (0.4935)
# Batch: [10/40]	Time 0.077 (0.445)
# Classifier loss 0.5175 (0.5551)	Adversary loss -0.0000 (-0.0008)
# Combined Loss during classifier step 0.5175 (0.5548)	Combined Loss during adversary step -0.4882 (-0.5197)
# Classifier Accuracy 0.8203 (0.7599)	Adversary Accuracy 0.4531 (0.5007)
# Batch: [15/40]	Time 0.316 (0.415)
# Classifier loss 0.5224 (0.5349)	Adversary loss 0.0000 (-0.0006)
# Combined Loss during classifier step 0.5224 (0.5347)	Combined Loss during adversary step -0.5278 (-0.5050)
# Classifier Accuracy 0.7578 (0.7642)	Adversary Accuracy 0.4688 (0.4961)
# Batch: [20/40]	Time 0.792 (0.424)
# Classifier loss 0.5056 (0.5157)	Adversary loss 0.0003 (-0.0005)
# Combined Loss during classifier step 0.5058 (0.5155)	Combined Loss during adversary step -0.4269 (-0.4859)
# Classifier Accuracy 0.7812 (0.7749)	Adversary Accuracy 0.4766 (0.4918)
# Batch: [25/40]	Time 0.307 (0.400)
# Classifier loss 0.3678 (0.4879)	Adversary loss 0.0026 (-0.0003)
# Combined Loss during classifier step 0.3698 (0.4878)	Combined Loss during adversary step -0.3846 (-0.4639)
# Classifier Accuracy 0.8594 (0.7924)	Adversary Accuracy 0.5234 (0.4952)
# Batch: [30/40]	Time 0.122 (0.380)
# Classifier loss 0.3425 (0.4741)	Adversary loss 0.0087 (0.0002)
# Combined Loss during classifier step 0.3538 (0.4746)	Combined Loss during adversary step -0.3551 (-0.4526)
# Classifier Accuracy 0.8516 (0.7971)	Adversary Accuracy 0.4844 (0.4962)
# Batch: [35/40]	Time 0.075 (0.365)
# Classifier loss 0.5548 (0.4703)	Adversary loss 0.0029 (0.0002)
# Combined Loss during classifier step 0.5600 (0.4708)	Combined Loss during adversary step -0.4911 (-0.4479)
# Classifier Accuracy 0.7812 (0.8012)	Adversary Accuracy 0.5703 (0.4991)
# Classifier accuracy: 0.8046	 Adversary Accuracy: 0.4964
# ----------
# Test batch: [0/4]	Time 1.892 (1.892)
# Classifier loss 0.4717 (0.4717)	Adversary loss 0.0045 (0.0045)
# Combined Loss 0.4762 (0.4762)	Classifier Accuracy 0.7969 (0.7969)	Adversary Accuracy 0.5078 (0.5078)
# Classifier validation acc: 0.7980 	 Adv validation acc: 0.5220
# --------------------
# Epoch 3/20	Time 15.981 sec (16.093 sec)
# --------------------
# Epoch: 4/20
# Batch: [0/40]	Time 1.828 (1.828)
# Classifier loss 0.3536 (0.3536)	Adversary loss -0.0000 (-0.0000)
# Combined Loss during classifier step 0.3536 (0.3536)	Combined Loss during adversary step -0.3740 (-0.3740)
# Classifier Accuracy 0.8516 (0.8516)	Adversary Accuracy 0.4688 (0.4688)
# Batch: [5/40]	Time 0.146 (0.575)
# Classifier loss 0.4022 (0.4137)	Adversary loss -0.0003 (0.0002)
# Combined Loss during classifier step 0.4019 (0.4137)	Combined Loss during adversary step -0.4056 (-0.3962)
# Classifier Accuracy 0.8125 (0.8060)	Adversary Accuracy 0.5156 (0.4831)
# Batch: [10/40]	Time 0.081 (0.450)
# Classifier loss 0.3853 (0.4017)	Adversary loss 0.0028 (0.0016)
# Combined Loss during classifier step 0.3893 (0.4042)	Combined Loss during adversary step -0.4095 (-0.3842)
# Classifier Accuracy 0.8359 (0.8246)	Adversary Accuracy 0.4844 (0.4830)
# Batch: [15/40]	Time 0.070 (0.406)
# Classifier loss 0.4186 (0.4117)	Adversary loss -0.0041 (0.0011)
# Combined Loss during classifier step 0.4203 (0.4137)	Combined Loss during adversary step -0.3391 (-0.3894)
# Classifier Accuracy 0.7734 (0.8193)	Adversary Accuracy 0.5703 (0.4907)
# Batch: [20/40]	Time 1.133 (0.438)
# Classifier loss 0.4196 (0.4043)	Adversary loss 0.0023 (0.0019)
# Combined Loss during classifier step 0.4262 (0.4078)	Combined Loss during adversary step -0.4231 (-0.3899)
# Classifier Accuracy 0.8281 (0.8263)	Adversary Accuracy 0.5156 (0.4918)
# Batch: [25/40]	Time 0.376 (0.417)
# Classifier loss 0.3593 (0.3968)	Adversary loss 0.0061 (0.0017)
# Combined Loss during classifier step 0.3669 (0.4000)	Combined Loss during adversary step -0.3847 (-0.3821)
# Classifier Accuracy 0.8359 (0.8335)	Adversary Accuracy 0.4219 (0.4871)
# Batch: [30/40]	Time 0.076 (0.388)
# Classifier loss 0.3074 (0.3882)	Adversary loss -0.0000 (0.0020)
# Combined Loss during classifier step 0.3074 (0.3918)	Combined Loss during adversary step -0.3172 (-0.3741)
# Classifier Accuracy 0.8828 (0.8372)	Adversary Accuracy 0.5547 (0.4947)
# Batch: [35/40]	Time 0.076 (0.369)
# Classifier loss 0.3540 (0.3850)	Adversary loss 0.0000 (0.0017)
# Combined Loss during classifier step 0.3540 (0.3881)	Combined Loss during adversary step -0.3574 (-0.3715)
# Classifier Accuracy 0.8672 (0.8390)	Adversary Accuracy 0.5078 (0.4957)
# Classifier accuracy: 0.8408	 Adversary Accuracy: 0.496
# ----------
# Test batch: [0/4]	Time 1.690 (1.690)
# Classifier loss 0.3245 (0.3245)	Adversary loss 0.0110 (0.0110)
# Combined Loss 0.3355 (0.3355)	Classifier Accuracy 0.8672 (0.8672)	Adversary Accuracy 0.4766 (0.4766)
# Classifier validation acc: 0.8420 	 Adv validation acc: 0.5220
# --------------------
# Epoch 4/20	Time 15.848 sec (16.044 sec)
# --------------------
# Epoch: 5/20
# Batch: [0/40]	Time 1.978 (1.978)
# Classifier loss 0.3356 (0.3356)	Adversary loss 0.0004 (0.0004)
# Combined Loss during classifier step 0.3361 (0.3361)	Combined Loss during adversary step -0.3443 (-0.3443)
# Classifier Accuracy 0.8672 (0.8672)	Adversary Accuracy 0.5078 (0.5078)
# Batch: [5/40]	Time 0.119 (0.581)
# Classifier loss 0.3199 (0.3328)	Adversary loss 0.0018 (0.0021)
# Combined Loss during classifier step 0.3203 (0.3353)	Combined Loss during adversary step -0.3196 (-0.3302)
# Classifier Accuracy 0.8672 (0.8802)	Adversary Accuracy 0.4531 (0.5013)
# Batch: [10/40]	Time 0.073 (0.451)
# Classifier loss 0.3182 (0.3307)	Adversary loss 0.0002 (0.0005)
# Combined Loss during classifier step 0.3188 (0.3332)	Combined Loss during adversary step -0.3162 (-0.3271)
# Classifier Accuracy 0.8672 (0.8729)	Adversary Accuracy 0.5312 (0.5021)
# Batch: [15/40]	Time 0.119 (0.417)
# Classifier loss 0.4052 (0.3314)	Adversary loss 0.0001 (0.0004)
# Combined Loss during classifier step 0.4060 (0.3333)	Combined Loss during adversary step -0.3886 (-0.3245)
# Classifier Accuracy 0.8594 (0.8711)	Adversary Accuracy 0.5000 (0.4878)
# Batch: [20/40]	Time 1.077 (0.446)
# Classifier loss 0.3220 (0.3288)	Adversary loss 0.0000 (-0.0004)
# Combined Loss during classifier step 0.3220 (0.3295)	Combined Loss during adversary step -0.3186 (-0.3205)
# Classifier Accuracy 0.8828 (0.8709)	Adversary Accuracy 0.5000 (0.4948)
# Batch: [25/40]	Time 0.091 (0.419)
# Classifier loss 0.2506 (0.3166)	Adversary loss 0.0000 (-0.0009)
# Combined Loss during classifier step 0.2507 (0.3166)	Combined Loss during adversary step -0.2261 (-0.3071)
# Classifier Accuracy 0.9141 (0.8789)	Adversary Accuracy 0.5312 (0.4994)
# Batch: [30/40]	Time 0.066 (0.393)
# Classifier loss 0.2421 (0.3085)	Adversary loss -0.0458 (-0.0028)
# Combined Loss during classifier step 0.1963 (0.3066)	Combined Loss during adversary step -0.1884 (-0.2977)
# Classifier Accuracy 0.8984 (0.8808)	Adversary Accuracy 0.4766 (0.4977)
# Batch: [35/40]	Time 0.083 (0.379)
# Classifier loss 0.2799 (0.3069)	Adversary loss -0.0287 (-0.0042)
# Combined Loss during classifier step 0.2519 (0.3035)	Combined Loss during adversary step -0.2459 (-0.2946)
# Classifier Accuracy 0.9062 (0.8809)	Adversary Accuracy 0.5000 (0.4959)
# Classifier accuracy: 0.8826	 Adversary Accuracy: 0.4938
# ----------
# Test batch: [0/4]	Time 1.705 (1.705)
# Classifier loss 0.3009 (0.3009)	Adversary loss -0.0229 (-0.0229)
# Combined Loss 0.2780 (0.2780)	Classifier Accuracy 0.8984 (0.8984)	Adversary Accuracy 0.5000 (0.5000)
# Classifier validation acc: 0.8620 	 Adv validation acc: 0.5160
# --------------------
# Epoch 5/20	Time 16.478 sec (16.116 sec)
# --------------------
# Epoch: 6/20
# Batch: [0/40]	Time 1.829 (1.829)
# Classifier loss 0.2049 (0.2049)	Adversary loss 0.0003 (0.0003)
# Combined Loss during classifier step 0.2055 (0.2055)	Combined Loss during adversary step -0.2088 (-0.2088)
# Classifier Accuracy 0.9141 (0.9141)	Adversary Accuracy 0.4766 (0.4766)
# Batch: [5/40]	Time 0.400 (0.606)
# Classifier loss 0.2166 (0.2751)	Adversary loss 0.0000 (-0.0079)
# Combined Loss during classifier step 0.2168 (0.2694)	Combined Loss during adversary step -0.2202 (-0.2562)
# Classifier Accuracy 0.9219 (0.9049)	Adversary Accuracy 0.5469 (0.5117)
# Batch: [10/40]	Time 0.090 (0.468)
# Classifier loss 0.1894 (0.2737)	Adversary loss -0.0150 (-0.0118)
# Combined Loss during classifier step 0.1744 (0.2636)	Combined Loss during adversary step -0.1725 (-0.2532)
# Classifier Accuracy 0.9141 (0.8963)	Adversary Accuracy 0.5078 (0.5142)
# Batch: [15/40]	Time 0.133 (0.427)
# Classifier loss 0.2563 (0.2708)	Adversary loss 0.0120 (-0.0081)
# Combined Loss during classifier step 0.2686 (0.2641)	Combined Loss during adversary step -0.2641 (-0.2538)
# Classifier Accuracy 0.8984 (0.8960)	Adversary Accuracy 0.4141 (0.5020)
# Batch: [20/40]	Time 0.900 (0.444)
# Classifier loss 0.2641 (0.2735)	Adversary loss -0.0006 (-0.0086)
# Combined Loss during classifier step 0.2632 (0.2661)	Combined Loss during adversary step -0.2669 (-0.2540)
# Classifier Accuracy 0.8906 (0.8969)	Adversary Accuracy 0.5156 (0.4978)
# Batch: [25/40]	Time 0.490 (0.430)
# Classifier loss 0.1954 (0.2662)	Adversary loss 0.0003 (-0.0082)
# Combined Loss during classifier step 0.1962 (0.2590)	Combined Loss during adversary step -0.1993 (-0.2476)
# Classifier Accuracy 0.9609 (0.9011)	Adversary Accuracy 0.4609 (0.4916)
# Batch: [30/40]	Time 0.096 (0.399)
# Classifier loss 0.2193 (0.2620)	Adversary loss -0.0370 (-0.0087)
# Combined Loss during classifier step 0.1970 (0.2546)	Combined Loss during adversary step -0.1712 (-0.2430)
# Classifier Accuracy 0.8984 (0.9005)	Adversary Accuracy 0.4531 (0.4902)
# Batch: [35/40]	Time 0.055 (0.383)
# Classifier loss 0.2935 (0.2623)	Adversary loss -0.0146 (-0.0083)
# Combined Loss during classifier step 0.2789 (0.2553)	Combined Loss during adversary step -0.2746 (-0.2438)
# Classifier Accuracy 0.8672 (0.9013)	Adversary Accuracy 0.5234 (0.4922)
# Classifier accuracy: 0.9008	 Adversary Accuracy: 0.4922
# ----------
# Test batch: [0/4]	Time 1.854 (1.854)
# Classifier loss 0.3424 (0.3424)	Adversary loss -0.0147 (-0.0147)
# Combined Loss 0.3278 (0.3278)	Classifier Accuracy 0.8750 (0.8750)	Adversary Accuracy 0.5234 (0.5234)
# Classifier validation acc: 0.8740 	 Adv validation acc: 0.5100
# --------------------
# Epoch 6/20	Time 16.510 sec (16.173 sec)
# --------------------
# Epoch: 7/20
# Batch: [0/40]	Time 1.968 (1.968)
# Classifier loss 0.2778 (0.2778)	Adversary loss -0.0133 (-0.0133)
# Combined Loss during classifier step 0.2644 (0.2644)	Combined Loss during adversary step -0.3136 (-0.3136)
# Classifier Accuracy 0.8828 (0.8828)	Adversary Accuracy 0.5781 (0.5781)
# Batch: [5/40]	Time 0.094 (0.585)
# Classifier loss 0.2056 (0.2666)	Adversary loss 0.0020 (-0.0021)
# Combined Loss during classifier step 0.2062 (0.2644)	Combined Loss during adversary step -0.2175 (-0.2601)
# Classifier Accuracy 0.9219 (0.8997)	Adversary Accuracy 0.4844 (0.5104)
# Batch: [10/40]	Time 0.084 (0.475)
# Classifier loss 0.2581 (0.2631)	Adversary loss -0.0168 (-0.0004)
# Combined Loss during classifier step 0.2413 (0.2661)	Combined Loss during adversary step -0.2058 (-0.2517)
# Classifier Accuracy 0.8906 (0.9020)	Adversary Accuracy 0.4609 (0.5071)
# Batch: [15/40]	Time 0.102 (0.426)
# Classifier loss 0.2261 (0.2613)	Adversary loss 0.0006 (0.0013)
# Combined Loss during classifier step 0.2492 (0.2705)	Combined Loss during adversary step -0.1952 (-0.2466)
# Classifier Accuracy 0.9375 (0.9023)	Adversary Accuracy 0.5156 (0.5044)
# Batch: [20/40]	Time 1.303 (0.461)
# Classifier loss 0.2538 (0.2532)	Adversary loss -0.0290 (-0.0034)
# Combined Loss during classifier step 0.2248 (0.2570)	Combined Loss during adversary step -0.2228 (-0.2378)
# Classifier Accuracy 0.8984 (0.9022)	Adversary Accuracy 0.5234 (0.5026)
# Batch: [25/40]	Time 0.074 (0.429)
# Classifier loss 0.2027 (0.2463)	Adversary loss -0.0003 (-0.0054)
# Combined Loss during classifier step 0.2022 (0.2471)	Combined Loss during adversary step -0.1997 (-0.2295)
# Classifier Accuracy 0.9297 (0.9056)	Adversary Accuracy 0.4922 (0.5012)
# Batch: [30/40]	Time 0.084 (0.401)
# Classifier loss 0.3108 (0.2450)	Adversary loss -0.0024 (-0.0057)
# Combined Loss during classifier step 0.3108 (0.2449)	Combined Loss during adversary step -0.2714 (-0.2281)
# Classifier Accuracy 0.8828 (0.9073)	Adversary Accuracy 0.4297 (0.4934)
# Batch: [35/40]	Time 0.070 (0.382)
# Classifier loss 0.2766 (0.2444)	Adversary loss -0.0164 (-0.0084)
# Combined Loss during classifier step 0.2602 (0.2409)	Combined Loss during adversary step -0.2284 (-0.2241)
# Classifier Accuracy 0.9062 (0.9073)	Adversary Accuracy 0.4688 (0.4922)
# Classifier accuracy: 0.9088	 Adversary Accuracy: 0.4912
# ----------
# Test batch: [0/4]	Time 1.880 (1.880)
# Classifier loss 0.3615 (0.3615)	Adversary loss -0.0449 (-0.0449)
# Combined Loss 0.3166 (0.3166)	Classifier Accuracy 0.8438 (0.8438)	Adversary Accuracy 0.4688 (0.4688)
# Classifier validation acc: 0.8740 	 Adv validation acc: 0.5060
# --------------------
# Epoch 7/20	Time 16.660 sec (16.233 sec)
# --------------------
# Epoch: 8/20
# Batch: [0/40]	Time 1.949 (1.949)
# Classifier loss 0.2452 (0.2452)	Adversary loss 0.0016 (0.0016)
# Combined Loss during classifier step 0.2551 (0.2551)	Combined Loss during adversary step -0.2237 (-0.2237)
# Classifier Accuracy 0.9141 (0.9141)	Adversary Accuracy 0.4688 (0.4688)
# Batch: [5/40]	Time 0.072 (0.596)
# Classifier loss 0.2624 (0.2250)	Adversary loss -0.0287 (-0.0211)
# Combined Loss during classifier step 0.2335 (0.2053)	Combined Loss during adversary step -0.2071 (-0.1910)
# Classifier Accuracy 0.9141 (0.9219)	Adversary Accuracy 0.5234 (0.4727)
# Batch: [10/40]	Time 0.072 (0.466)
# Classifier loss 0.2028 (0.2166)	Adversary loss -0.0471 (-0.0184)
# Combined Loss during classifier step 0.1557 (0.2000)	Combined Loss during adversary step -0.1469 (-0.1867)
# Classifier Accuracy 0.9297 (0.9268)	Adversary Accuracy 0.4688 (0.4858)
# Batch: [15/40]	Time 0.087 (0.424)
# Classifier loss 0.1736 (0.2065)	Adversary loss -0.0164 (-0.0181)
# Combined Loss during classifier step 0.1574 (0.1905)	Combined Loss during adversary step -0.1280 (-0.1776)
# Classifier Accuracy 0.9531 (0.9302)	Adversary Accuracy 0.4922 (0.4897)
# Batch: [20/40]	Time 1.188 (0.445)
# Classifier loss 0.1446 (0.1987)	Adversary loss -0.0182 (-0.0170)
# Combined Loss during classifier step 0.1264 (0.1835)	Combined Loss during adversary step -0.1019 (-0.1708)
# Classifier Accuracy 0.9375 (0.9304)	Adversary Accuracy 0.4219 (0.4855)
# Batch: [25/40]	Time 0.123 (0.420)
# Classifier loss 0.2033 (0.1923)	Adversary loss 0.0000 (-0.0154)
# Combined Loss during classifier step 0.2033 (0.1785)	Combined Loss during adversary step -0.2001 (-0.1671)
# Classifier Accuracy 0.9141 (0.9333)	Adversary Accuracy 0.4766 (0.4898)
# Batch: [30/40]	Time 0.105 (0.395)
# Classifier loss 0.2206 (0.1953)	Adversary loss -0.0141 (-0.0148)
# Combined Loss during classifier step 0.2160 (0.1822)	Combined Loss during adversary step -0.1335 (-0.1684)
# Classifier Accuracy 0.9141 (0.9309)	Adversary Accuracy 0.5234 (0.4889)
# Batch: [35/40]	Time 0.082 (0.382)
# Classifier loss 0.1461 (0.1903)	Adversary loss 0.0001 (-0.0125)
# Combined Loss during classifier step 0.1470 (0.1799)	Combined Loss during adversary step -0.1386 (-0.1670)
# Classifier Accuracy 0.9375 (0.9334)	Adversary Accuracy 0.5312 (0.4920)
# Classifier accuracy: 0.9348	 Adversary Accuracy: 0.489
# ----------
# Test batch: [0/4]	Time 1.729 (1.729)
# Classifier loss 0.3282 (0.3282)	Adversary loss -0.0307 (-0.0307)
# Combined Loss 0.2976 (0.2976)	Classifier Accuracy 0.8594 (0.8594)	Adversary Accuracy 0.5391 (0.5391)
# Classifier validation acc: 0.8900 	 Adv validation acc: 0.5060
# --------------------
# Epoch 8/20	Time 16.348 sec (16.246 sec)
# --------------------
# Epoch: 9/20
# Batch: [0/40]	Time 2.006 (2.006)
# Classifier loss 0.1773 (0.1773)	Adversary loss -0.0295 (-0.0295)
# Combined Loss during classifier step 0.1539 (0.1539)	Combined Loss during adversary step -0.1750 (-0.1750)
# Classifier Accuracy 0.9219 (0.9219)	Adversary Accuracy 0.5000 (0.5000)
# Batch: [5/40]	Time 0.090 (0.587)
# Classifier loss 0.1397 (0.2082)	Adversary loss 0.0001 (-0.0141)
# Combined Loss during classifier step 0.1424 (0.1982)	Combined Loss during adversary step -0.1436 (-0.1884)
# Classifier Accuracy 0.9609 (0.9232)	Adversary Accuracy 0.5156 (0.4948)
# Batch: [10/40]	Time 0.093 (0.465)
# Classifier loss 0.1995 (0.1989)	Adversary loss 0.0017 (-0.0113)
# Combined Loss during classifier step 0.2149 (0.1913)	Combined Loss during adversary step -0.1715 (-0.1788)
# Classifier Accuracy 0.8984 (0.9254)	Adversary Accuracy 0.5547 (0.4787)
# Batch: [15/40]	Time 0.089 (0.419)
# Classifier loss 0.1397 (0.1913)	Adversary loss 0.0001 (-0.0119)
# Combined Loss during classifier step 0.1399 (0.1815)	Combined Loss during adversary step -0.1258 (-0.1707)
# Classifier Accuracy 0.9531 (0.9277)	Adversary Accuracy 0.5156 (0.4868)
# Batch: [20/40]	Time 1.132 (0.441)
# Classifier loss 0.1502 (0.1795)	Adversary loss -0.0130 (-0.0114)
# Combined Loss during classifier step 0.1373 (0.1698)	Combined Loss during adversary step -0.1351 (-0.1593)
# Classifier Accuracy 0.9453 (0.9319)	Adversary Accuracy 0.5938 (0.4888)
# Batch: [25/40]	Time 0.176 (0.422)
# Classifier loss 0.1500 (0.1764)	Adversary loss -0.0163 (-0.0130)
# Combined Loss during classifier step 0.1346 (0.1658)	Combined Loss during adversary step -0.1419 (-0.1541)
# Classifier Accuracy 0.9219 (0.9336)	Adversary Accuracy 0.4688 (0.4877)
# Batch: [30/40]	Time 0.155 (0.392)
# Classifier loss 0.1842 (0.1715)	Adversary loss -0.0175 (-0.0142)
# Combined Loss during classifier step 0.1676 (0.1597)	Combined Loss during adversary step -0.1475 (-0.1482)
# Classifier Accuracy 0.9297 (0.9365)	Adversary Accuracy 0.4375 (0.4844)
# Batch: [35/40]	Time 0.076 (0.371)
# Classifier loss 0.1937 (0.1699)	Adversary loss -0.0156 (-0.0151)
# Combined Loss during classifier step 0.1783 (0.1576)	Combined Loss during adversary step -0.1668 (-0.1457)
# Classifier Accuracy 0.9375 (0.9373)	Adversary Accuracy 0.4922 (0.4872)
# Classifier accuracy: 0.9364	 Adversary Accuracy: 0.488
# ----------
# Test batch: [0/4]	Time 1.988 (1.988)
# Classifier loss 0.6096 (0.6096)	Adversary loss -0.0103 (-0.0103)
# Combined Loss 0.5993 (0.5993)	Classifier Accuracy 0.6953 (0.6953)	Adversary Accuracy 0.5156 (0.5156)
# Classifier validation acc: 0.7260 	 Adv validation acc: 0.5040
# --------------------
# Epoch 9/20	Time 16.404 sec (16.262 sec)
# --------------------
# Epoch: 10/20
# Batch: [0/40]	Time 1.894 (1.894)
# Classifier loss 0.3679 (0.3679)	Adversary loss -0.0151 (-0.0151)
# Combined Loss during classifier step 0.3535 (0.3535)	Combined Loss during adversary step -0.1418 (-0.1418)
# Classifier Accuracy 0.7812 (0.7812)	Adversary Accuracy 0.5078 (0.5078)
# Batch: [5/40]	Time 0.124 (0.576)
# Classifier loss 0.1435 (0.1956)	Adversary loss 0.0116 (-0.0240)
# Combined Loss during classifier step 0.1676 (0.1775)	Combined Loss during adversary step -0.1604 (-0.1249)
# Classifier Accuracy 0.9453 (0.9115)	Adversary Accuracy 0.5547 (0.4753)
# Batch: [10/40]	Time 0.104 (0.474)
# Classifier loss 0.2122 (0.1833)	Adversary loss -0.0145 (-0.0244)
# Combined Loss during classifier step 0.1977 (0.1639)	Combined Loss during adversary step -0.1570 (-0.1297)
# Classifier Accuracy 0.9297 (0.9254)	Adversary Accuracy 0.5312 (0.4830)
# Batch: [15/40]	Time 0.113 (0.422)
# Classifier loss 0.2167 (0.1818)	Adversary loss -0.0555 (-0.0272)
# Combined Loss during classifier step 0.1631 (0.1607)	Combined Loss during adversary step -0.2101 (-0.1345)
# Classifier Accuracy 0.9531 (0.9277)	Adversary Accuracy 0.5312 (0.4902)
# Batch: [20/40]	Time 1.258 (0.460)
# Classifier loss 0.1411 (0.1822)	Adversary loss -0.0173 (-0.0236)
# Combined Loss during classifier step 0.1252 (0.1639)	Combined Loss during adversary step -0.1275 (-0.1375)
# Classifier Accuracy 0.9688 (0.9312)	Adversary Accuracy 0.4453 (0.4896)
# Batch: [25/40]	Time 0.626 (0.432)
# Classifier loss 0.1743 (0.1832)	Adversary loss -0.0433 (-0.0259)
# Combined Loss during classifier step 0.1361 (0.1625)	Combined Loss during adversary step -0.1205 (-0.1373)
# Classifier Accuracy 0.9141 (0.9306)	Adversary Accuracy 0.4297 (0.4835)
# Batch: [30/40]	Time 0.089 (0.400)
# Classifier loss 0.1667 (0.1748)	Adversary loss -0.0149 (-0.0268)
# Combined Loss during classifier step 0.1519 (0.1547)	Combined Loss during adversary step -0.1395 (-0.1308)
# Classifier Accuracy 0.9375 (0.9347)	Adversary Accuracy 0.5156 (0.4851)
# Batch: [35/40]	Time 0.075 (0.373)
# Classifier loss 0.1363 (0.1703)	Adversary loss -0.1605 (-0.0334)
# Combined Loss during classifier step -0.0138 (0.1433)	Combined Loss during adversary step 0.0330 (-0.1209)
# Classifier Accuracy 0.9453 (0.9358)	Adversary Accuracy 0.3750 (0.4794)
# Classifier accuracy: 0.9376	 Adversary Accuracy: 0.4796
# ----------
# Test batch: [0/4]	Time 1.094 (1.094)
# Classifier loss 0.2110 (0.2110)	Adversary loss -0.0486 (-0.0486)
# Combined Loss 0.1624 (0.1624)	Classifier Accuracy 0.9531 (0.9531)	Adversary Accuracy 0.4844 (0.4844)
# Classifier validation acc: 0.9060 	 Adv validation acc: 0.4920
# --------------------
# Epoch 10/20	Time 16.123 sec (16.249 sec)
# --------------------
# Epoch: 11/20
# Batch: [0/40]	Time 1.864 (1.864)
# Classifier loss 0.1455 (0.1455)	Adversary loss -0.0299 (-0.0299)
# Combined Loss during classifier step 0.1155 (0.1155)	Combined Loss during adversary step -0.1366 (-0.1366)
# Classifier Accuracy 0.9531 (0.9531)	Adversary Accuracy 0.5078 (0.5078)
# Batch: [5/40]	Time 0.093 (0.598)
# Classifier loss 0.1545 (0.1514)	Adversary loss -0.0267 (-0.0287)
# Combined Loss during classifier step 0.1278 (0.1240)	Combined Loss during adversary step -0.1152 (-0.1023)
# Classifier Accuracy 0.9297 (0.9401)	Adversary Accuracy 0.5703 (0.5000)
# Batch: [10/40]	Time 0.087 (0.482)
# Classifier loss 0.0763 (0.1411)	Adversary loss -0.0781 (-0.0439)
# Combined Loss during classifier step -0.0018 (0.0994)	Combined Loss during adversary step 0.0070 (-0.0818)
# Classifier Accuracy 0.9844 (0.9489)	Adversary Accuracy 0.4609 (0.4893)
# Batch: [15/40]	Time 0.084 (0.429)
# Classifier loss 0.1007 (0.1400)	Adversary loss -0.0734 (-0.0514)
# Combined Loss during classifier step 0.0367 (0.0909)	Combined Loss during adversary step -0.0322 (-0.0747)
# Classifier Accuracy 0.9609 (0.9478)	Adversary Accuracy 0.4688 (0.4800)
# Batch: [20/40]	Time 1.129 (0.451)
# Classifier loss 0.2185 (0.1403)	Adversary loss -0.1572 (-0.0599)
# Combined Loss during classifier step 0.0859 (0.0844)	Combined Loss during adversary step -0.0514 (-0.0682)
# Classifier Accuracy 0.9219 (0.9501)	Adversary Accuracy 0.5078 (0.4769)
# Batch: [25/40]	Time 0.092 (0.425)
# Classifier loss 0.1195 (0.1428)	Adversary loss -0.3028 (-0.0854)
# Combined Loss during classifier step -0.1809 (0.0628)	Combined Loss during adversary step 0.1845 (-0.0438)
# Classifier Accuracy 0.9531 (0.9492)	Adversary Accuracy 0.3047 (0.4612)
# Batch: [30/40]	Time 0.108 (0.411)
# Classifier loss 0.1754 (0.1451)	Adversary loss -0.3202 (-0.1034)
# Combined Loss during classifier step -0.0990 (0.0550)	Combined Loss during adversary step 0.1459 (-0.0303)
# Classifier Accuracy 0.9219 (0.9478)	Adversary Accuracy 0.3516 (0.4516)
# Batch: [35/40]	Time 0.079 (0.386)
# Classifier loss 0.2092 (0.1498)	Adversary loss -0.7412 (-0.1767)
# Combined Loss during classifier step -0.4827 (0.0016)	Combined Loss during adversary step 0.5315 (0.0378)
# Classifier Accuracy 0.9375 (0.9464)	Adversary Accuracy 0.1172 (0.4132)
# Classifier accuracy: 0.9456	 Adversary Accuracy: 0.3878
# ----------
# Test batch: [0/4]	Time 1.515 (1.515)
# Classifier loss 0.2095 (0.2095)	Adversary loss -0.9218 (-0.9218)
# Combined Loss -0.7123 (-0.7123)	Classifier Accuracy 0.9297 (0.9297)	Adversary Accuracy 0.0312 (0.0312)
# Classifier validation acc: 0.9160 	 Adv validation acc: 0.0620
# --------------------
# Epoch 11/20	Time 16.560 sec (16.275 sec)
# --------------------
# Epoch: 12/20
# Batch: [0/40]	Time 1.825 (1.825)
# Classifier loss 0.1645 (0.1645)	Adversary loss -0.8725 (-0.8725)
# Combined Loss during classifier step -0.6955 (-0.6955)	Combined Loss during adversary step 0.7193 (0.7193)
# Classifier Accuracy 0.9141 (0.9141)	Adversary Accuracy 0.0625 (0.0625)
# Batch: [5/40]	Time 0.094 (0.572)
# Classifier loss 0.2156 (0.2243)	Adversary loss -0.9473 (-0.9195)
# Combined Loss during classifier step -0.7095 (-0.6764)	Combined Loss during adversary step 0.7674 (0.7235)
# Classifier Accuracy 0.8906 (0.9219)	Adversary Accuracy 0.0156 (0.0365)
# Batch: [10/40]	Time 0.076 (0.440)
# Classifier loss 0.1225 (0.2051)	Adversary loss -0.9904 (-0.9358)
# Combined Loss during classifier step -0.8642 (-0.7187)	Combined Loss during adversary step 0.8673 (0.7493)
# Classifier Accuracy 0.9688 (0.9276)	Adversary Accuracy 0.0000 (0.0277)
# Batch: [15/40]	Time 0.066 (0.404)
# Classifier loss 0.1751 (0.1963)	Adversary loss -0.9520 (-0.9381)
# Combined Loss during classifier step -0.7756 (-0.7308)	Combined Loss during adversary step 0.8109 (0.7601)
# Classifier Accuracy 0.9375 (0.9302)	Adversary Accuracy 0.0156 (0.0259)
# Batch: [20/40]	Time 1.153 (0.437)
# Classifier loss 0.2400 (0.1869)	Adversary loss -0.9466 (-0.9366)
# Combined Loss during classifier step -0.6768 (-0.7288)	Combined Loss during adversary step 0.7281 (0.7648)
# Classifier Accuracy 0.9297 (0.9382)	Adversary Accuracy 0.0156 (0.0253)
# Batch: [25/40]	Time 0.120 (0.415)
# Classifier loss 0.2483 (0.1890)	Adversary loss -0.9959 (-0.9439)
# Combined Loss during classifier step -0.7425 (-0.7347)	Combined Loss during adversary step 0.7359 (0.7696)
# Classifier Accuracy 0.9141 (0.9381)	Adversary Accuracy 0.0000 (0.0222)
# Batch: [30/40]	Time 0.092 (0.399)
# Classifier loss 0.1945 (0.1898)	Adversary loss -0.9766 (-0.9487)
# Combined Loss during classifier step -0.7720 (-0.7400)	Combined Loss during adversary step 0.7825 (0.7742)
# Classifier Accuracy 0.9297 (0.9360)	Adversary Accuracy 0.0078 (0.0199)
# Batch: [35/40]	Time 0.090 (0.381)
# Classifier loss 0.1804 (0.1932)	Adversary loss -0.9385 (-0.9506)
# Combined Loss during classifier step -0.7483 (-0.7404)	Combined Loss during adversary step 0.7770 (0.7733)
# Classifier Accuracy 0.9219 (0.9345)	Adversary Accuracy 0.0234 (0.0189)
# Classifier accuracy: 0.9328	 Adversary Accuracy: 0.0182
# ----------
# Test batch: [0/4]	Time 1.514 (1.514)
# Classifier loss 0.4430 (0.4430)	Adversary loss -0.9553 (-0.9553)
# Combined Loss -0.5122 (-0.5122)	Classifier Accuracy 0.8984 (0.8984)	Adversary Accuracy 0.0156 (0.0156)
# Classifier validation acc: 0.9020 	 Adv validation acc: 0.0220
# --------------------
# Epoch 12/20	Time 16.193 sec (16.269 sec)
# --------------------
# Epoch: 13/20
# Batch: [0/40]	Time 1.831 (1.831)
# Classifier loss 0.1569 (0.1569)	Adversary loss -0.9569 (-0.9569)
# Combined Loss during classifier step -0.7883 (-0.7883)	Combined Loss during adversary step 0.7907 (0.7907)
# Classifier Accuracy 0.9531 (0.9531)	Adversary Accuracy 0.0234 (0.0234)
# Batch: [5/40]	Time 0.191 (0.597)
# Classifier loss 0.2438 (0.2171)	Adversary loss -0.9298 (-0.9515)
# Combined Loss during classifier step -0.6695 (-0.7069)	Combined Loss during adversary step 0.7299 (0.7565)
# Classifier Accuracy 0.9062 (0.9271)	Adversary Accuracy 0.0234 (0.0169)
# Batch: [10/40]	Time 0.156 (0.493)
# Classifier loss 0.2177 (0.2102)	Adversary loss -0.9401 (-0.9494)
# Combined Loss during classifier step -0.6117 (-0.6942)	Combined Loss during adversary step 0.4747 (0.7350)
# Classifier Accuracy 0.9141 (0.9276)	Adversary Accuracy 0.0156 (0.0135)
# Batch: [15/40]	Time 0.129 (0.448)
# Classifier loss 0.5145 (0.2518)	Adversary loss -0.9613 (-0.9450)
# Combined Loss during classifier step -0.3856 (-0.5808)	Combined Loss during adversary step 0.7938 (0.7182)
# Classifier Accuracy 0.7344 (0.9053)	Adversary Accuracy 0.0078 (0.0146)
# Batch: [20/40]	Time 0.769 (0.444)
# Classifier loss 0.1990 (0.2633)	Adversary loss -0.9732 (-0.9437)
# Combined Loss during classifier step -0.7202 (-0.5733)	Combined Loss during adversary step 0.6814 (0.7002)
# Classifier Accuracy 0.9297 (0.9048)	Adversary Accuracy 0.0078 (0.0156)
# Batch: [25/40]	Time 0.508 (0.440)
# Classifier loss 0.2277 (0.2541)	Adversary loss -0.9592 (-0.9469)
# Combined Loss during classifier step -0.6672 (-0.5994)	Combined Loss during adversary step 0.7923 (0.7164)
# Classifier Accuracy 0.9375 (0.9059)	Adversary Accuracy 0.0156 (0.0153)
# Batch: [30/40]	Time 0.132 (0.420)
# Classifier loss 0.3153 (0.2561)	Adversary loss -0.9752 (-0.9488)
# Combined Loss during classifier step -0.2259 (-0.5952)	Combined Loss during adversary step 0.7536 (0.7203)
# Classifier Accuracy 0.9141 (0.9075)	Adversary Accuracy 0.0000 (0.0146)
# Batch: [35/40]	Time 0.123 (0.393)
# Classifier loss 0.1726 (0.2525)	Adversary loss -0.9580 (-0.9511)
# Combined Loss during classifier step -0.7528 (-0.6063)	Combined Loss during adversary step 0.7268 (0.7179)
# Classifier Accuracy 0.9531 (0.9086)	Adversary Accuracy 0.0078 (0.0139)
# Classifier accuracy: 0.9086	 Adversary Accuracy: 0.013
# ----------
# Test batch: [0/4]	Time 1.479 (1.479)
# Classifier loss 0.3533 (0.3533)	Adversary loss -0.9668 (-0.9668)
# Combined Loss -0.6135 (-0.6135)	Classifier Accuracy 0.7969 (0.7969)	Adversary Accuracy 0.0000 (0.0000)
# Classifier validation acc: 0.7440 	 Adv validation acc: 0.0100
# --------------------
# Epoch 13/20	Time 16.326 sec (16.273 sec)
# --------------------
# Epoch: 14/20
# Batch: [0/40]	Time 1.840 (1.840)
# Classifier loss 0.4292 (0.4292)	Adversary loss -0.9757 (-0.9757)
# Combined Loss during classifier step -0.5303 (-0.5303)	Combined Loss during adversary step 0.5336 (0.5336)
# Classifier Accuracy 0.7578 (0.7578)	Adversary Accuracy 0.0078 (0.0078)
# Batch: [5/40]	Time 0.140 (0.612)
# Classifier loss 0.2318 (0.2745)	Adversary loss -0.9164 (-0.9518)
# Combined Loss during classifier step -0.5756 (-0.6319)	Combined Loss during adversary step 0.6569 (0.6969)
# Classifier Accuracy 0.8984 (0.8763)	Adversary Accuracy 0.0234 (0.0104)
# Batch: [10/40]	Time 0.086 (0.472)
# Classifier loss 0.4390 (0.2808)	Adversary loss -0.9702 (-0.9575)
# Combined Loss during classifier step -0.4682 (-0.6149)	Combined Loss during adversary step 0.5496 (0.6964)
# Classifier Accuracy 0.7969 (0.8814)	Adversary Accuracy 0.0000 (0.0078)
# Batch: [15/40]	Time 0.057 (0.424)
# Classifier loss 0.1825 (0.2878)	Adversary loss -0.9681 (-0.9635)
# Combined Loss during classifier step -0.7719 (-0.6216)	Combined Loss during adversary step 0.6244 (0.6929)
# Classifier Accuracy 0.9531 (0.8818)	Adversary Accuracy 0.0000 (0.0059)
# Batch: [20/40]	Time 1.204 (0.452)
# Classifier loss 0.3691 (0.2909)	Adversary loss -0.9574 (-0.9635)
# Combined Loss during classifier step -0.5132 (-0.6190)	Combined Loss during adversary step 0.7132 (0.6957)
# Classifier Accuracy 0.8438 (0.8813)	Adversary Accuracy 0.0078 (0.0071)
# Batch: [25/40]	Time 0.123 (0.425)
# Classifier loss 0.1947 (0.2775)	Adversary loss -0.5521 (-0.9399)
# Combined Loss during classifier step 0.1618 (-0.5367)	Combined Loss during adversary step 0.4212 (0.6869)
# Classifier Accuracy 0.9219 (0.8870)	Adversary Accuracy 0.2422 (0.0174)
# Batch: [30/40]	Time 0.081 (0.408)
# Classifier loss 0.1934 (0.2762)	Adversary loss -0.0116 (-0.8008)
# Combined Loss during classifier step 0.1870 (-0.4125)	Combined Loss during adversary step -0.1756 (0.5475)
# Classifier Accuracy 0.9297 (0.8891)	Adversary Accuracy 0.4688 (0.0869)
# Batch: [35/40]	Time 0.055 (0.388)
# Classifier loss 0.2104 (0.2707)	Adversary loss -0.0159 (-0.6909)
# Combined Loss during classifier step 0.2014 (-0.3224)	Combined Loss during adversary step -0.1611 (0.4421)
# Classifier Accuracy 0.9297 (0.8924)	Adversary Accuracy 0.4922 (0.1465)
# Classifier accuracy: 0.8928	 Adversary Accuracy: 0.1732
# ----------
# Test batch: [0/4]	Time 1.632 (1.632)
# Classifier loss 0.3183 (0.3183)	Adversary loss -0.0300 (-0.0300)
# Combined Loss 0.2883 (0.2883)	Classifier Accuracy 0.8984 (0.8984)	Adversary Accuracy 0.5547 (0.5547)
# Classifier validation acc: 0.8820 	 Adv validation acc: 0.5120
# --------------------
# Epoch 14/20	Time 16.397 sec (16.281 sec)
# --------------------
# Epoch: 15/20
# Batch: [0/40]	Time 2.036 (2.036)
# Classifier loss 0.2723 (0.2723)	Adversary loss -0.0245 (-0.0245)
# Combined Loss during classifier step 0.2527 (0.2527)	Combined Loss during adversary step -0.1791 (-0.1791)
# Classifier Accuracy 0.9141 (0.9141)	Adversary Accuracy 0.4531 (0.4531)
# Batch: [5/40]	Time 0.101 (0.606)
# Classifier loss 0.2074 (0.2544)	Adversary loss -0.0463 (-0.0235)
# Combined Loss during classifier step 0.1624 (0.2331)	Combined Loss during adversary step -0.1475 (-0.1813)
# Classifier Accuracy 0.9141 (0.9167)	Adversary Accuracy 0.4844 (0.4870)
# Batch: [10/40]	Time 0.097 (0.484)
# Classifier loss 0.1386 (0.2058)	Adversary loss -0.0106 (-0.0285)
# Combined Loss during classifier step 0.1384 (0.1819)	Combined Loss during adversary step -0.1188 (-0.1460)
# Classifier Accuracy 0.9375 (0.9290)	Adversary Accuracy 0.4688 (0.4794)
# Batch: [15/40]	Time 0.105 (0.435)
# Classifier loss 0.1404 (0.1949)	Adversary loss -0.0253 (-0.0313)
# Combined Loss during classifier step 0.1208 (0.1708)	Combined Loss during adversary step -0.1165 (-0.1378)
# Classifier Accuracy 0.9609 (0.9346)	Adversary Accuracy 0.4766 (0.4849)
# Batch: [20/40]	Time 1.167 (0.460)
# Classifier loss 0.1755 (0.1951)	Adversary loss -0.1256 (-0.0386)
# Combined Loss during classifier step 0.0736 (0.1644)	Combined Loss during adversary step -0.0670 (-0.1344)
# Classifier Accuracy 0.9453 (0.9312)	Adversary Accuracy 0.4453 (0.4807)
# Batch: [25/40]	Time 0.183 (0.438)
# Classifier loss 0.2307 (0.1927)	Adversary loss -0.0859 (-0.0477)
# Combined Loss during classifier step 0.1758 (0.1544)	Combined Loss during adversary step -0.1070 (-0.1233)
# Classifier Accuracy 0.8828 (0.9300)	Adversary Accuracy 0.5078 (0.4736)
# Batch: [30/40]	Time 0.100 (0.418)
# Classifier loss 0.2418 (0.1915)	Adversary loss -0.0920 (-0.0599)
# Combined Loss during classifier step 0.1522 (0.1437)	Combined Loss during adversary step -0.1617 (-0.1131)
# Classifier Accuracy 0.9062 (0.9297)	Adversary Accuracy 0.5156 (0.4655)
# Batch: [35/40]	Time 0.076 (0.400)
# Classifier loss 0.1825 (0.1991)	Adversary loss -0.1498 (-0.0752)
# Combined Loss during classifier step 0.0481 (0.1371)	Combined Loss during adversary step -0.0252 (-0.1050)
# Classifier Accuracy 0.9453 (0.9277)	Adversary Accuracy 0.4453 (0.4629)
# Classifier accuracy: 0.9268	 Adversary Accuracy: 0.4552
# ----------
# Test batch: [0/4]	Time 1.157 (1.157)
# Classifier loss 0.2094 (0.2094)	Adversary loss -0.1970 (-0.1970)
# Combined Loss 0.0125 (0.0125)	Classifier Accuracy 0.9062 (0.9062)	Adversary Accuracy 0.4219 (0.4219)
# Classifier validation acc: 0.8960 	 Adv validation acc: 0.4280
# --------------------
# Epoch 15/20	Time 16.692 sec (16.307 sec)
# --------------------
# Epoch: 16/20
# Batch: [0/40]	Time 1.898 (1.898)
# Classifier loss 0.1380 (0.1380)	Adversary loss -0.1685 (-0.1685)
# Combined Loss during classifier step -0.0212 (-0.0212)	Combined Loss during adversary step 0.0350 (0.0350)
# Classifier Accuracy 0.9453 (0.9453)	Adversary Accuracy 0.3438 (0.3438)
# Batch: [5/40]	Time 0.189 (0.598)
# Classifier loss 0.1405 (0.1353)	Adversary loss -0.3209 (-0.2198)
# Combined Loss during classifier step -0.1557 (-0.0648)	Combined Loss during adversary step 0.1804 (0.0914)
# Classifier Accuracy 0.9375 (0.9414)	Adversary Accuracy 0.3438 (0.3633)
# Batch: [10/40]	Time 0.089 (0.474)
# Classifier loss 0.2404 (0.1578)	Adversary loss -0.4412 (-0.2992)
# Combined Loss during classifier step -0.1570 (-0.1043)	Combined Loss during adversary step 0.2251 (0.1465)
# Classifier Accuracy 0.8828 (0.9325)	Adversary Accuracy 0.2656 (0.3409)
# Batch: [15/40]	Time 0.084 (0.429)
# Classifier loss 0.1735 (0.1618)	Adversary loss -0.9320 (-0.4296)
# Combined Loss during classifier step -0.6720 (-0.2004)	Combined Loss during adversary step 0.7583 (0.2714)
# Classifier Accuracy 0.9453 (0.9355)	Adversary Accuracy 0.0312 (0.2793)
# Batch: [20/40]	Time 1.179 (0.449)
# Classifier loss 0.3383 (0.1710)	Adversary loss -0.9829 (-0.5534)
# Combined Loss during classifier step -0.5964 (-0.3219)	Combined Loss during adversary step 0.7593 (0.3907)
# Classifier Accuracy 0.8906 (0.9334)	Adversary Accuracy 0.0078 (0.2188)
# Batch: [25/40]	Time 0.470 (0.432)
# Classifier loss 0.1842 (0.1792)	Adversary loss -0.9884 (-0.6346)
# Combined Loss during classifier step -0.7938 (-0.3993)	Combined Loss during adversary step 0.8051 (0.4675)
# Classifier Accuracy 0.9219 (0.9336)	Adversary Accuracy 0.0000 (0.1785)
# Batch: [30/40]	Time 0.090 (0.415)
# Classifier loss 0.1641 (0.1822)	Adversary loss -0.9937 (-0.6906)
# Combined Loss during classifier step -0.8233 (-0.4606)	Combined Loss during adversary step 0.8564 (0.5228)
# Classifier Accuracy 0.9375 (0.9332)	Adversary Accuracy 0.0000 (0.1502)
# Batch: [35/40]	Time 0.084 (0.398)
# Classifier loss 0.1204 (0.1818)	Adversary loss -0.9835 (-0.7315)
# Combined Loss during classifier step -0.8626 (-0.5082)	Combined Loss during adversary step 0.8743 (0.5653)
# Classifier Accuracy 0.9688 (0.9323)	Adversary Accuracy 0.0078 (0.1302)
# Classifier accuracy: 0.9326	 Adversary Accuracy: 0.1208
# ----------
# Test batch: [0/4]	Time 1.411 (1.411)
# Classifier loss 0.3003 (0.3003)	Adversary loss -0.9988 (-0.9988)
# Combined Loss -0.6985 (-0.6985)	Classifier Accuracy 0.8516 (0.8516)	Adversary Accuracy 0.0000 (0.0000)
# Classifier validation acc: 0.8780 	 Adv validation acc: 0.0060
# --------------------
# Epoch 16/20	Time 16.552 sec (16.321 sec)
# --------------------
# Epoch: 17/20
# Batch: [0/40]	Time 1.821 (1.821)
# Classifier loss 0.2204 (0.2204)	Adversary loss -0.9933 (-0.9933)
# Combined Loss during classifier step -0.7684 (-0.7684)	Combined Loss during adversary step 0.7959 (0.7959)
# Classifier Accuracy 0.9062 (0.9062)	Adversary Accuracy 0.0000 (0.0000)
# Batch: [5/40]	Time 0.084 (0.558)
# Classifier loss 0.1379 (0.1836)	Adversary loss -0.9912 (-0.9888)
# Combined Loss during classifier step -0.8460 (-0.8011)	Combined Loss during adversary step 0.8812 (0.8424)
# Classifier Accuracy 0.9375 (0.9232)	Adversary Accuracy 0.0000 (0.0026)
# Batch: [10/40]	Time 0.090 (0.441)
# Classifier loss 0.0955 (0.1499)	Adversary loss -0.9947 (-0.9897)
# Combined Loss during classifier step -0.8824 (-0.8332)	Combined Loss during adversary step 0.9139 (0.8639)
# Classifier Accuracy 0.9688 (0.9411)	Adversary Accuracy 0.0000 (0.0028)
# Batch: [15/40]	Time 0.094 (0.414)
# Classifier loss 0.0843 (0.1355)	Adversary loss -0.9857 (-0.9894)
# Combined Loss during classifier step -0.8992 (-0.8476)	Combined Loss during adversary step 0.9059 (0.8715)
# Classifier Accuracy 0.9609 (0.9458)	Adversary Accuracy 0.0078 (0.0039)
# Batch: [20/40]	Time 1.194 (0.452)
# Classifier loss 0.0796 (0.1292)	Adversary loss -0.9717 (-0.9896)
# Combined Loss during classifier step -0.8911 (-0.8553)	Combined Loss during adversary step 0.8927 (0.8765)
# Classifier Accuracy 0.9844 (0.9490)	Adversary Accuracy 0.0156 (0.0041)
# Batch: [25/40]	Time 0.081 (0.425)
# Classifier loss 0.1447 (0.1237)	Adversary loss -0.9898 (-0.9896)
# Combined Loss during classifier step -0.8386 (-0.8599)	Combined Loss during adversary step 0.8517 (0.8813)
# Classifier Accuracy 0.9375 (0.9513)	Adversary Accuracy 0.0000 (0.0042)
# Batch: [30/40]	Time 0.091 (0.405)
# Classifier loss 0.0653 (0.1168)	Adversary loss -0.9990 (-0.9902)
# Combined Loss during classifier step -0.9297 (-0.8678)	Combined Loss during adversary step 0.9351 (0.8879)
# Classifier Accuracy 0.9609 (0.9534)	Adversary Accuracy 0.0000 (0.0040)
# Batch: [35/40]	Time 0.076 (0.389)
# Classifier loss 0.1260 (0.1123)	Adversary loss -0.9973 (-0.9912)
# Combined Loss during classifier step -0.8699 (-0.8737)	Combined Loss during adversary step 0.8732 (0.8922)
# Classifier Accuracy 0.9453 (0.9562)	Adversary Accuracy 0.0000 (0.0035)
# Classifier accuracy: 0.9576	 Adversary Accuracy: 0.0032
# ----------
# Test batch: [0/4]	Time 1.462 (1.462)
# Classifier loss 0.1026 (0.1026)	Adversary loss -0.9997 (-0.9997)
# Combined Loss -0.8971 (-0.8971)	Classifier Accuracy 0.9688 (0.9688)	Adversary Accuracy 0.0000 (0.0000)
# Classifier validation acc: 0.9460 	 Adv validation acc: 0.0020
# --------------------
# Epoch 17/20	Time 16.528 sec (16.333 sec)
# --------------------
# Epoch: 18/20
# Batch: [0/40]	Time 1.857 (1.857)
# Classifier loss 0.0532 (0.0532)	Adversary loss -0.9858 (-0.9858)
# Combined Loss during classifier step -0.9311 (-0.9311)	Combined Loss during adversary step 0.9395 (0.9395)
# Classifier Accuracy 0.9844 (0.9844)	Adversary Accuracy 0.0078 (0.0078)
# Batch: [5/40]	Time 0.076 (0.582)
# Classifier loss 0.0392 (0.0458)	Adversary loss -1.0000 (-0.9976)
# Combined Loss during classifier step -0.9608 (-0.9515)	Combined Loss during adversary step 0.9666 (0.9557)
# Classifier Accuracy 0.9844 (0.9844)	Adversary Accuracy 0.0000 (0.0013)
# Batch: [10/40]	Time 0.128 (0.473)
# Classifier loss 0.0305 (0.0451)	Adversary loss -0.9828 (-0.9968)
# Combined Loss during classifier step -0.9523 (-0.9515)	Combined Loss during adversary step 0.9562 (0.9557)
# Classifier Accuracy 0.9922 (0.9865)	Adversary Accuracy 0.0078 (0.0014)
# Batch: [15/40]	Time 0.087 (0.425)
# Classifier loss 0.0276 (0.0483)	Adversary loss -1.0000 (-0.9976)
# Combined Loss during classifier step -0.9723 (-0.9492)	Combined Loss during adversary step 0.9753 (0.9545)
# Classifier Accuracy 0.9844 (0.9854)	Adversary Accuracy 0.0000 (0.0010)
# Batch: [20/40]	Time 1.228 (0.456)
# Classifier loss 0.1084 (0.0550)	Adversary loss -0.9999 (-0.9968)
# Combined Loss during classifier step -0.8915 (-0.9417)	Combined Loss during adversary step 0.9022 (0.9498)
# Classifier Accuracy 0.9609 (0.9829)	Adversary Accuracy 0.0000 (0.0015)
# Batch: [25/40]	Time 0.088 (0.431)
# Classifier loss 0.0141 (0.0539)	Adversary loss -0.9991 (-0.9969)
# Combined Loss during classifier step -0.9851 (-0.9427)	Combined Loss during adversary step 0.9807 (0.9523)
# Classifier Accuracy 1.0000 (0.9835)	Adversary Accuracy 0.0000 (0.0015)
# Batch: [30/40]	Time 0.201 (0.408)
# Classifier loss 0.0314 (0.0554)	Adversary loss -0.9799 (-0.9965)
# Combined Loss during classifier step -0.9482 (-0.9407)	Combined Loss during adversary step 0.9457 (0.9486)
# Classifier Accuracy 0.9922 (0.9829)	Adversary Accuracy 0.0078 (0.0015)
# Batch: [35/40]	Time 0.116 (0.394)
# Classifier loss 0.1301 (0.0549)	Adversary loss -0.9993 (-0.9964)
# Combined Loss during classifier step -0.8673 (-0.9411)	Combined Loss during adversary step 0.9122 (0.9491)
# Classifier Accuracy 0.9531 (0.9824)	Adversary Accuracy 0.0000 (0.0015)
# Classifier accuracy: 0.9824	 Adversary Accuracy: 0.0016
# ----------
# Test batch: [0/4]	Time 1.347 (1.347)
# Classifier loss 0.1325 (0.1325)	Adversary loss -0.9998 (-0.9998)
# Combined Loss -0.8674 (-0.8674)	Classifier Accuracy 0.9453 (0.9453)	Adversary Accuracy 0.0000 (0.0000)
# Classifier validation acc: 0.9500 	 Adv validation acc: 0.0040
# --------------------
# Epoch 18/20	Time 16.324 sec (16.332 sec)
# --------------------
# Epoch: 19/20
# Batch: [0/40]	Time 1.932 (1.932)
# Classifier loss 0.0412 (0.0412)	Adversary loss -1.0000 (-1.0000)
# Combined Loss during classifier step -0.9588 (-0.9588)	Combined Loss during adversary step 0.9568 (0.9568)
# Classifier Accuracy 0.9844 (0.9844)	Adversary Accuracy 0.0000 (0.0000)
# Batch: [5/40]	Time 0.109 (0.594)
# Classifier loss 0.0207 (0.0391)	Adversary loss -0.9903 (-0.9956)
# Combined Loss during classifier step -0.9657 (-0.9558)	Combined Loss during adversary step 0.9718 (0.9610)
# Classifier Accuracy 1.0000 (0.9896)	Adversary Accuracy 0.0078 (0.0026)
# Batch: [10/40]	Time 0.121 (0.482)
# Classifier loss 0.0302 (0.0336)	Adversary loss -0.9997 (-0.9974)
# Combined Loss during classifier step -0.9694 (-0.9629)	Combined Loss during adversary step 0.9717 (0.9676)
# Classifier Accuracy 0.9922 (0.9922)	Adversary Accuracy 0.0000 (0.0014)
# Batch: [15/40]	Time 0.084 (0.433)
# Classifier loss 0.0333 (0.0366)	Adversary loss -0.9995 (-0.9978)
# Combined Loss during classifier step -0.9655 (-0.9601)	Combined Loss during adversary step 0.9682 (0.9656)
# Classifier Accuracy 0.9844 (0.9893)	Adversary Accuracy 0.0000 (0.0010)
# Batch: [20/40]	Time 1.184 (0.461)
# Classifier loss 0.0279 (0.0357)	Adversary loss -0.9985 (-0.9981)
# Combined Loss during classifier step -0.9692 (-0.9610)	Combined Loss during adversary step 0.9734 (0.9670)
# Classifier Accuracy 0.9922 (0.9888)	Adversary Accuracy 0.0000 (0.0007)
# Batch: [25/40]	Time 0.091 (0.429)
# Classifier loss 0.0268 (0.0328)	Adversary loss -0.9986 (-0.9971)
# Combined Loss during classifier step -0.9710 (-0.9629)	Combined Loss during adversary step 0.9750 (0.9683)
# Classifier Accuracy 0.9922 (0.9898)	Adversary Accuracy 0.0000 (0.0012)
# Batch: [30/40]	Time 0.145 (0.423)
# Classifier loss 0.0543 (0.0322)	Adversary loss -0.9996 (-0.9970)
# Combined Loss during classifier step -0.9452 (-0.9633)	Combined Loss during adversary step 0.9539 (0.9687)
# Classifier Accuracy 0.9688 (0.9897)	Adversary Accuracy 0.0000 (0.0013)
# Batch: [35/40]	Time 0.094 (0.405)
# Classifier loss 0.0176 (0.0320)	Adversary loss -0.9995 (-0.9973)
# Combined Loss during classifier step -0.9819 (-0.9640)	Combined Loss during adversary step 0.9824 (0.9693)
# Classifier Accuracy 0.9922 (0.9889)	Adversary Accuracy 0.0000 (0.0011)
# Classifier accuracy: 0.9894	 Adversary Accuracy: 0.001
# ----------
# Test batch: [0/4]	Time 1.317 (1.317)
# Classifier loss 0.1704 (0.1704)	Adversary loss -1.0000 (-1.0000)
# Combined Loss -0.8296 (-0.8296)	Classifier Accuracy 0.9453 (0.9453)	Adversary Accuracy 0.0000 (0.0000)
# Classifier validation acc: 0.9540 	 Adv validation acc: 0.0000
# --------------------
# Epoch 19/20	Time 16.731 sec (16.352 sec)
# --------------------

# %%
plt.figure(figsize=(20,20))
plt.subplot(431)
plt.title('Combined Cls-Enc-Adv Train Loss for Cls-Enc Step')
plt.plot(clsTrainCombined_losses)
plt.subplot(432)
plt.title('Cls-Enc Train Loss')
plt.plot(clsTrain_losses)
plt.subplot(433)
plt.title('Cls-Enc Train Accuracy')
plt.plot(clsTrain_accs)
plt.subplot(434)
plt.title('Combined Cls-Enc-Adv Train Loss for Adv Step')
plt.plot(advTrainCombined_losses)
plt.subplot(435)
plt.title('Adv Train Loss')
plt.plot(advTrain_losses)
plt.subplot(436)
plt.title('Adv Train Accuracy')
plt.plot(advTrain_accs)

plt.subplot(437)
plt.title('Cls-Enc Val Losses')
plt.plot(clsVal_losses)
plt.subplot(438)
plt.title('Cls-Enc Val Accuracy')
plt.plot(clsVal_accs)
plt.subplot(4,3,10)
plt.title('Adv Val Losses')
plt.plot(advVal_losses)
plt.subplot(4,3,11)
plt.title('Adv Val Accuracy')
plt.plot(advVal_accs)

plt.tight_layout()

# %%
plt.plot(combinedVal_losses)
