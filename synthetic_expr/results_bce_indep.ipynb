# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
import argparse

plt.switch_backend('agg')
# In[3]:
font = {'weight' : 'bold',
        'size'   : 22}

matplotlib.rc('font', **font)

import torch
import torch.nn as nn
import torch.backends.cudnn as cudnn
import torch.optim as optim
import torch.nn.functional as F
import torch.optim.lr_scheduler as lr_scheduler
from torchvision import transforms, utils, models, datasets
from torch.utils.data import Dataset, DataLoader

# %%
from synthetic_dataloader import *


from synthetic_utils import *


# In[5]:


from trainer_dataloader import *
from networks import *
from losses import *


# In[6]:

# %%
input_size = 96
batch_size = 64
num_workers = 4


cuda = False
pin_memory = False
if torch.cuda.is_available():
    device = torch.device("cuda")
    torch.set_default_tensor_type('torch.cuda.FloatTensor')
    cuda = True
    cudnn.benchmark = True
    pin_memory = True
else:
    device = torch.device("cpu")

print('Device set: {}'.format(device))


# In[8]:


data_transforms = {
        'train': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ]),
        'val': transforms.Compose([
            transforms.Resize((input_size, input_size)),
            transforms.ToTensor(),
            transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
        ])
}
# Out:
# Device set: cuda

# %%
# if independent:
DATA_PATH = '/home/s1791387/diss/gen_shapes/'
# else:
#     DATA_PATH = '/home/s1791387/diss/dependent_gen/'
print(DATA_PATH)
TRAIN_PATH = os.path.join(DATA_PATH, 'train')
VAL_PATH = os.path.join(DATA_PATH, 'valid')
TEST_PATH = os.path.join(DATA_PATH, 'test')
# Out:
# /home/s1791387/diss/gen_shapes/

# %%
train_df = datasets.ImageFolder(root=TRAIN_PATH, transform=data_transforms['train'])
val_df = datasets.ImageFolder(root=VAL_PATH, transform=data_transforms['val'])
test_df = datasets.ImageFolder(root=TEST_PATH, transform=data_transforms['val'])

# %%
LOAD_PATH = './bce_indep_2/weights/encoder_258_0.736.pth'

# %%
laftr_encoder = torch.load(LOAD_PATH)

# %%
gender_train = GenderDataset(train_df)
gender_valid = GenderDataset(val_df)

# %%
advtrain_loader = DataLoader(gender_train, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)
advval_loader = DataLoader(gender_valid, batch_size=batch_size, shuffle=True, num_workers=num_workers, pin_memory=pin_memory)

# %%
adversary = ClassNet()

adv_criterion = nn.BCELoss()
opt_adv = optim.Adam(adversary.parameters(), lr=0.001, betas=(0.9, 0.999))
scheduler_adv = lr_scheduler.StepLR(optimizer=opt_adv, gamma=0.99, step_size=1)

# %%
num_epochs = 20
train_losses = []
train_accs = []
val_losses = []
val_accs = []
epoch_time = AverageMeter()
ep_end = time.time()
for epoch in range(0, num_epochs):
        print('Epoch: {}/{}'.format(epoch, num_epochs))
        scheduler_adv.step()
        # train
        train_loss, train_acc = train_classifier_epoch(advtrain_loader, laftr_encoder,
                                adversary, opt_adv, adv_criterion, device)
        train_losses.append(train_loss)
        train_accs.append(train_acc)
        # validate
        print('-'*10)
        val_loss, val_acc = validate_classifier_epoch(advval_loader, laftr_encoder, adversary,
                                 adv_criterion, device)

        print('Avg validation loss: {} \t Accuracy: {}'.format(val_loss, val_acc))
        val_losses.append(val_loss)
        val_accs.append(val_acc)
        
        print('-' * 20)
        epoch_time.update(time.time() - ep_end)
        ep_end = time.time()
        print('Epoch {}/{}\t'
              'Time {epoch_time.val:.3f} sec ({epoch_time.avg:.3f} sec)'.format(epoch, num_epochs, epoch_time=epoch_time))
        print('-'*20)
# Out:
# Epoch: 0/20
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([64])) that is different to the input size (torch.Size([64, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/79]	Time 8.085 (8.085)	Loss 0.6988 (0.6988)	Accuracy 0.4375 (0.4375)
# Batch: [10/79]	Time 0.174 (1.672)	Loss 0.6925 (0.6928)	Accuracy 0.5156 (0.5014)
# Batch: [20/79]	Time 4.763 (1.611)	Loss 0.7032 (0.6945)	Accuracy 0.4375 (0.4955)
# Batch: [30/79]	Time 0.103 (1.450)	Loss 0.6915 (0.6946)	Accuracy 0.5312 (0.4919)
# Batch: [40/79]	Time 4.765 (1.448)	Loss 0.6964 (0.6945)	Accuracy 0.4688 (0.4909)
# Batch: [50/79]	Time 0.115 (1.367)	Loss 0.6916 (0.6940)	Accuracy 0.5625 (0.5009)
# Batch: [60/79]	Time 5.071 (1.402)	Loss 0.6925 (0.6935)	Accuracy 0.5625 (0.5072)
# Batch: [70/79]	Time 0.186 (1.382)	Loss 0.6842 (0.6932)	Accuracy 0.6094 (0.5075)
# ----------
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([8])) that is different to the input size (torch.Size([8, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Avg validation loss: 0.6920696816444397 	 Accuracy: 0.514
# --------------------
# Epoch 0/20	Time 126.295 sec (126.295 sec)
# --------------------
# Epoch: 1/20
# /home/s1791387/miniconda3/envs/diss/lib/python3.6/site-packages/torch/nn/functional.py:1594: UserWarning: Using a target size (torch.Size([52])) that is different to the input size (torch.Size([52, 1])) is deprecated. Please ensure they have the same size.
#   "Please ensure they have the same size.".format(target.size(), input.size()))
# Batch: [0/79]	Time 10.424 (10.424)	Loss 0.6968 (0.6968)	Accuracy 0.4688 (0.4688)
# Batch: [10/79]	Time 0.083 (2.162)	Loss 0.6848 (0.6923)	Accuracy 0.5781 (0.5128)
# Batch: [20/79]	Time 5.759 (2.041)	Loss 0.6859 (0.6903)	Accuracy 0.5625 (0.5275)
# Batch: [30/79]	Time 0.137 (1.809)	Loss 0.6987 (0.6913)	Accuracy 0.5000 (0.5257)
# Batch: [40/79]	Time 5.794 (1.805)	Loss 0.6929 (0.6916)	Accuracy 0.4219 (0.5202)
# Batch: [50/79]	Time 0.091 (1.691)	Loss 0.6722 (0.6913)	Accuracy 0.6250 (0.5214)
# Batch: [60/79]	Time 4.746 (1.694)	Loss 0.6902 (0.6910)	Accuracy 0.5156 (0.5184)
# Batch: [70/79]	Time 0.074 (1.640)	Loss 0.6952 (0.6910)	Accuracy 0.5312 (0.5213)
# ----------
# Avg validation loss: 0.696295424938202 	 Accuracy: 0.476
# --------------------
# Epoch 1/20	Time 144.032 sec (135.164 sec)
# --------------------
# Epoch: 2/20
# Batch: [0/79]	Time 10.346 (10.346)	Loss 0.6865 (0.6865)	Accuracy 0.5312 (0.5312)
# Batch: [10/79]	Time 0.117 (2.139)	Loss 0.6711 (0.7003)	Accuracy 0.5938 (0.4972)
# Batch: [20/79]	Time 6.110 (2.037)	Loss 0.6985 (0.6972)	Accuracy 0.4688 (0.5037)
# Batch: [30/79]	Time 0.066 (1.814)	Loss 0.6835 (0.6950)	Accuracy 0.5156 (0.5121)
# Batch: [40/79]	Time 5.956 (1.812)	Loss 0.6977 (0.6932)	Accuracy 0.5469 (0.5206)
# Batch: [50/79]	Time 0.049 (1.698)	Loss 0.7042 (0.6946)	Accuracy 0.4219 (0.5119)
# Batch: [60/79]	Time 5.491 (1.708)	Loss 0.6956 (0.6941)	Accuracy 0.5625 (0.5164)
# Batch: [70/79]	Time 0.073 (1.653)	Loss 0.6909 (0.6938)	Accuracy 0.5156 (0.5180)
# ----------
# Avg validation loss: 0.6919315104484558 	 Accuracy: 0.528
# --------------------
# Epoch 2/20	Time 145.002 sec (138.443 sec)
# --------------------
# Epoch: 3/20
# Batch: [0/79]	Time 10.950 (10.950)	Loss 0.6863 (0.6863)	Accuracy 0.4844 (0.4844)
# Batch: [10/79]	Time 0.171 (2.230)	Loss 0.6934 (0.6925)	Accuracy 0.5469 (0.4972)
# Batch: [20/79]	Time 5.957 (2.075)	Loss 0.6810 (0.6914)	Accuracy 0.6094 (0.5067)
# Batch: [30/79]	Time 0.108 (1.839)	Loss 0.6906 (0.6911)	Accuracy 0.5312 (0.5186)
# Batch: [40/79]	Time 5.732 (1.810)	Loss 0.7071 (0.6902)	Accuracy 0.4375 (0.5213)
# Batch: [50/79]	Time 0.058 (1.705)	Loss 0.6945 (0.6914)	Accuracy 0.6719 (0.5193)
# Batch: [60/79]	Time 5.185 (1.701)	Loss 0.6907 (0.6910)	Accuracy 0.5312 (0.5228)
# Batch: [70/79]	Time 0.075 (1.644)	Loss 0.6769 (0.6904)	Accuracy 0.6094 (0.5266)
# ----------
# Avg validation loss: 0.6933788328170777 	 Accuracy: 0.494
# --------------------
# Epoch 3/20	Time 143.595 sec (139.731 sec)
# --------------------
# Epoch: 4/20
# Batch: [0/79]	Time 10.657 (10.657)	Loss 0.6902 (0.6902)	Accuracy 0.4688 (0.4688)
# Batch: [10/79]	Time 0.094 (2.179)	Loss 0.6956 (0.6904)	Accuracy 0.4688 (0.5185)
# Batch: [20/79]	Time 6.125 (2.054)	Loss 0.6856 (0.6893)	Accuracy 0.5625 (0.5260)
# Batch: [30/79]	Time 0.136 (1.820)	Loss 0.6868 (0.6901)	Accuracy 0.6094 (0.5272)
# Batch: [40/79]	Time 5.638 (1.814)	Loss 0.6925 (0.6898)	Accuracy 0.4688 (0.5267)
# Batch: [50/79]	Time 0.204 (1.714)	Loss 0.6963 (0.6896)	Accuracy 0.5000 (0.5288)
# Batch: [60/79]	Time 5.707 (1.721)	Loss 0.7107 (0.6894)	Accuracy 0.4219 (0.5297)
# Batch: [70/79]	Time 0.284 (1.655)	Loss 0.6961 (0.6899)	Accuracy 0.4844 (0.5255)
# ----------
# Avg validation loss: 0.6912155594825745 	 Accuracy: 0.54
# --------------------
# Epoch 4/20	Time 144.781 sec (140.741 sec)
# --------------------
# Epoch: 5/20
# Batch: [0/79]	Time 10.726 (10.726)	Loss 0.6859 (0.6859)	Accuracy 0.6094 (0.6094)
# Batch: [10/79]	Time 0.135 (2.164)	Loss 0.6890 (0.6905)	Accuracy 0.5000 (0.5426)
# Batch: [20/79]	Time 6.035 (2.045)	Loss 0.6908 (0.6879)	Accuracy 0.5469 (0.5595)
# Batch: [30/79]	Time 0.150 (1.822)	Loss 0.6934 (0.6878)	Accuracy 0.4844 (0.5524)
# Batch: [40/79]	Time 5.630 (1.807)	Loss 0.6846 (0.6880)	Accuracy 0.5781 (0.5549)
# Batch: [50/79]	Time 0.063 (1.712)	Loss 0.6829 (0.6885)	Accuracy 0.5625 (0.5484)
# Batch: [60/79]	Time 5.277 (1.713)	Loss 0.7030 (0.6889)	Accuracy 0.5156 (0.5415)
# Batch: [70/79]	Time 0.092 (1.646)	Loss 0.6923 (0.6890)	Accuracy 0.4688 (0.5390)
# ----------
# Avg validation loss: 0.6906869583129883 	 Accuracy: 0.542
# --------------------
# Epoch 5/20	Time 144.119 sec (141.304 sec)
# --------------------
# Epoch: 6/20
# Batch: [0/79]	Time 10.826 (10.826)	Loss 0.6886 (0.6886)	Accuracy 0.6406 (0.6406)
# Batch: [10/79]	Time 0.170 (2.173)	Loss 0.6812 (0.6913)	Accuracy 0.6250 (0.5369)
# Batch: [20/79]	Time 6.187 (2.063)	Loss 0.6739 (0.6897)	Accuracy 0.6094 (0.5372)
# Batch: [30/79]	Time 0.150 (1.825)	Loss 0.7040 (0.6895)	Accuracy 0.4062 (0.5398)
# Batch: [40/79]	Time 5.589 (1.833)	Loss 0.6878 (0.6888)	Accuracy 0.4688 (0.5404)
# Batch: [50/79]	Time 0.199 (1.732)	Loss 0.6849 (0.6886)	Accuracy 0.5625 (0.5374)
# Batch: [60/79]	Time 5.698 (1.724)	Loss 0.6907 (0.6885)	Accuracy 0.4844 (0.5348)
# Batch: [70/79]	Time 0.348 (1.650)	Loss 0.6902 (0.6885)	Accuracy 0.5469 (0.5321)
# ----------
# Avg validation loss: 0.6904553174972534 	 Accuracy: 0.546
# --------------------
# Epoch 6/20	Time 144.468 sec (141.756 sec)
# --------------------
# Epoch: 7/20
# Batch: [0/79]	Time 10.466 (10.466)	Loss 0.6925 (0.6925)	Accuracy 0.5156 (0.5156)
# Batch: [10/79]	Time 0.159 (2.142)	Loss 0.6914 (0.6863)	Accuracy 0.4688 (0.5327)
# Batch: [20/79]	Time 6.075 (2.043)	Loss 0.6804 (0.6865)	Accuracy 0.5781 (0.5513)
# Batch: [30/79]	Time 0.328 (1.821)	Loss 0.6746 (0.6873)	Accuracy 0.6875 (0.5529)
# Batch: [40/79]	Time 4.759 (1.814)	Loss 0.6858 (0.6880)	Accuracy 0.5312 (0.5419)
# Batch: [50/79]	Time 0.357 (1.723)	Loss 0.6840 (0.6870)	Accuracy 0.6250 (0.5530)
# Batch: [60/79]	Time 4.987 (1.706)	Loss 0.6898 (0.6873)	Accuracy 0.4375 (0.5456)
# Batch: [70/79]	Time 0.097 (1.637)	Loss 0.6870 (0.6874)	Accuracy 0.4844 (0.5429)
# ----------
# Avg validation loss: 0.6907085738182068 	 Accuracy: 0.56
# --------------------
# Epoch 7/20	Time 143.601 sec (141.987 sec)
# --------------------
# Epoch: 8/20
# Batch: [0/79]	Time 10.360 (10.360)	Loss 0.6824 (0.6824)	Accuracy 0.5938 (0.5938)
# Batch: [10/79]	Time 0.154 (2.124)	Loss 0.6901 (0.6871)	Accuracy 0.5312 (0.5412)
# Batch: [20/79]	Time 5.878 (2.022)	Loss 0.6901 (0.6872)	Accuracy 0.5781 (0.5461)
# Batch: [30/79]	Time 0.152 (1.793)	Loss 0.6753 (0.6872)	Accuracy 0.6250 (0.5459)
# Batch: [40/79]	Time 4.575 (1.791)	Loss 0.6907 (0.6863)	Accuracy 0.5156 (0.5534)
# Batch: [50/79]	Time 0.470 (1.701)	Loss 0.7011 (0.6879)	Accuracy 0.5000 (0.5435)
# Batch: [60/79]	Time 4.542 (1.688)	Loss 0.6959 (0.6880)	Accuracy 0.4844 (0.5435)
# Batch: [70/79]	Time 0.188 (1.621)	Loss 0.6844 (0.6881)	Accuracy 0.5156 (0.5420)
# ----------
# Avg validation loss: 0.6890328059196472 	 Accuracy: 0.55
# --------------------
# Epoch 8/20	Time 142.063 sec (141.995 sec)
# --------------------
# Epoch: 9/20
# Batch: [0/79]	Time 10.519 (10.519)	Loss 0.6971 (0.6971)	Accuracy 0.4375 (0.4375)
# Batch: [10/79]	Time 0.151 (2.135)	Loss 0.6940 (0.6827)	Accuracy 0.5156 (0.5597)
# Batch: [20/79]	Time 5.703 (2.014)	Loss 0.6768 (0.6860)	Accuracy 0.5625 (0.5409)
# Batch: [30/79]	Time 0.393 (1.802)	Loss 0.6905 (0.6852)	Accuracy 0.5156 (0.5504)
# Batch: [40/79]	Time 4.586 (1.790)	Loss 0.6930 (0.6855)	Accuracy 0.5000 (0.5503)
# Batch: [50/79]	Time 0.516 (1.717)	Loss 0.6930 (0.6862)	Accuracy 0.5312 (0.5469)
# Batch: [60/79]	Time 5.476 (1.703)	Loss 0.6740 (0.6858)	Accuracy 0.6562 (0.5533)
# Batch: [70/79]	Time 0.902 (1.634)	Loss 0.6699 (0.6861)	Accuracy 0.6875 (0.5526)
# ----------
# Avg validation loss: 0.6882605009078979 	 Accuracy: 0.554
# --------------------
# Epoch 9/20	Time 142.257 sec (142.021 sec)
# --------------------
# Epoch: 10/20
# Batch: [0/79]	Time 10.691 (10.691)	Loss 0.6944 (0.6944)	Accuracy 0.4531 (0.4531)
# Batch: [10/79]	Time 0.231 (2.137)	Loss 0.6858 (0.6864)	Accuracy 0.6094 (0.5369)
# Batch: [20/79]	Time 5.841 (2.023)	Loss 0.6943 (0.6874)	Accuracy 0.5000 (0.5372)
# Batch: [30/79]	Time 0.159 (1.793)	Loss 0.6788 (0.6868)	Accuracy 0.6719 (0.5383)
# Batch: [40/79]	Time 4.724 (1.792)	Loss 0.6902 (0.6864)	Accuracy 0.5312 (0.5419)
# Batch: [50/79]	Time 0.146 (1.700)	Loss 0.6822 (0.6863)	Accuracy 0.5469 (0.5420)
# Batch: [60/79]	Time 5.475 (1.696)	Loss 0.6867 (0.6862)	Accuracy 0.5781 (0.5425)
# Batch: [70/79]	Time 0.096 (1.626)	Loss 0.6792 (0.6866)	Accuracy 0.5469 (0.5405)
# ----------
# Avg validation loss: 0.6877465310096741 	 Accuracy: 0.558
# --------------------
# Epoch 10/20	Time 141.914 sec (142.012 sec)
# --------------------
# Epoch: 11/20
# Batch: [0/79]	Time 10.743 (10.743)	Loss 0.6789 (0.6789)	Accuracy 0.6562 (0.6562)
# Batch: [10/79]	Time 0.195 (2.159)	Loss 0.6836 (0.6852)	Accuracy 0.5156 (0.5739)
# Batch: [20/79]	Time 5.720 (2.029)	Loss 0.6600 (0.6833)	Accuracy 0.6562 (0.5759)
# Batch: [30/79]	Time 0.495 (1.823)	Loss 0.6846 (0.6849)	Accuracy 0.5781 (0.5640)
# Batch: [40/79]	Time 4.721 (1.818)	Loss 0.6791 (0.6851)	Accuracy 0.6094 (0.5610)
# Batch: [50/79]	Time 0.759 (1.733)	Loss 0.6942 (0.6853)	Accuracy 0.4844 (0.5548)
# Batch: [60/79]	Time 3.900 (1.677)	Loss 0.6753 (0.6854)	Accuracy 0.6562 (0.5499)
# Batch: [70/79]	Time 0.335 (1.575)	Loss 0.6875 (0.6856)	Accuracy 0.5938 (0.5500)
# ----------
# Avg validation loss: 0.6866189699172973 	 Accuracy: 0.572
# --------------------
# Epoch 11/20	Time 130.458 sec (141.049 sec)
# --------------------
# Epoch: 12/20
# Batch: [0/79]	Time 7.655 (7.655)	Loss 0.6912 (0.6912)	Accuracy 0.5156 (0.5156)
# Batch: [10/79]	Time 0.148 (1.590)	Loss 0.6669 (0.6844)	Accuracy 0.7344 (0.5511)
# Batch: [20/79]	Time 4.453 (1.510)	Loss 0.6828 (0.6833)	Accuracy 0.5000 (0.5506)
# Batch: [30/79]	Time 0.064 (1.340)	Loss 0.6807 (0.6838)	Accuracy 0.6406 (0.5474)
# Batch: [40/79]	Time 4.014 (1.363)	Loss 0.6793 (0.6840)	Accuracy 0.6094 (0.5484)
# Batch: [50/79]	Time 0.102 (1.290)	Loss 0.6917 (0.6845)	Accuracy 0.5000 (0.5472)
# Batch: [60/79]	Time 3.712 (1.290)	Loss 0.6831 (0.6842)	Accuracy 0.5938 (0.5558)
# Batch: [70/79]	Time 0.096 (1.229)	Loss 0.6908 (0.6844)	Accuracy 0.5469 (0.5566)
# ----------
# Avg validation loss: 0.6872331852912903 	 Accuracy: 0.564
# --------------------
# Epoch 12/20	Time 106.794 sec (138.414 sec)
# --------------------
# Epoch: 13/20
# Batch: [0/79]	Time 7.740 (7.740)	Loss 0.6755 (0.6755)	Accuracy 0.6250 (0.6250)
# Batch: [10/79]	Time 0.167 (1.579)	Loss 0.6867 (0.6820)	Accuracy 0.5781 (0.5724)
# Batch: [20/79]	Time 4.389 (1.504)	Loss 0.6749 (0.6820)	Accuracy 0.5000 (0.5640)
# Batch: [30/79]	Time 0.105 (1.334)	Loss 0.6821 (0.6839)	Accuracy 0.4844 (0.5524)
# Batch: [40/79]	Time 4.356 (1.361)	Loss 0.6792 (0.6828)	Accuracy 0.5625 (0.5560)
# Batch: [50/79]	Time 0.130 (1.292)	Loss 0.6745 (0.6841)	Accuracy 0.5781 (0.5539)
# Batch: [60/79]	Time 3.756 (1.289)	Loss 0.6836 (0.6845)	Accuracy 0.6406 (0.5538)
# Batch: [70/79]	Time 0.235 (1.229)	Loss 0.6832 (0.6847)	Accuracy 0.6250 (0.5544)
# ----------
# Avg validation loss: 0.6881131539344788 	 Accuracy: 0.514
# --------------------
# Epoch 13/20	Time 106.246 sec (136.116 sec)
# --------------------
# Epoch: 14/20
# Batch: [0/79]	Time 7.616 (7.616)	Loss 0.7007 (0.7007)	Accuracy 0.4688 (0.4688)
# Batch: [10/79]	Time 0.156 (1.568)	Loss 0.6888 (0.6829)	Accuracy 0.5156 (0.5369)
# Batch: [20/79]	Time 4.406 (1.488)	Loss 0.6868 (0.6833)	Accuracy 0.5625 (0.5551)
# Batch: [30/79]	Time 0.238 (1.335)	Loss 0.6942 (0.6847)	Accuracy 0.5469 (0.5524)
# Batch: [40/79]	Time 4.220 (1.349)	Loss 0.6664 (0.6845)	Accuracy 0.6719 (0.5530)
# Batch: [50/79]	Time 0.227 (1.284)	Loss 0.7153 (0.6832)	Accuracy 0.4531 (0.5573)
# Batch: [60/79]	Time 4.182 (1.279)	Loss 0.6896 (0.6840)	Accuracy 0.5312 (0.5528)
# Batch: [70/79]	Time 0.073 (1.226)	Loss 0.7115 (0.6841)	Accuracy 0.4219 (0.5515)
# ----------
# Avg validation loss: 0.6855836191177368 	 Accuracy: 0.556
# --------------------
# Epoch 14/20	Time 106.798 sec (134.162 sec)
# --------------------
# Epoch: 15/20
# Batch: [0/79]	Time 7.529 (7.529)	Loss 0.6773 (0.6773)	Accuracy 0.6406 (0.6406)
# Batch: [10/79]	Time 0.137 (1.562)	Loss 0.6710 (0.6806)	Accuracy 0.5312 (0.5852)
# Batch: [20/79]	Time 4.449 (1.485)	Loss 0.7222 (0.6833)	Accuracy 0.3906 (0.5573)
# Batch: [30/79]	Time 0.143 (1.326)	Loss 0.6852 (0.6856)	Accuracy 0.5469 (0.5484)
# Batch: [40/79]	Time 4.343 (1.349)	Loss 0.6808 (0.6852)	Accuracy 0.5938 (0.5526)
# Batch: [50/79]	Time 0.159 (1.281)	Loss 0.6782 (0.6846)	Accuracy 0.6406 (0.5597)
# Batch: [60/79]	Time 4.301 (1.283)	Loss 0.6711 (0.6841)	Accuracy 0.6875 (0.5633)
# Batch: [70/79]	Time 0.114 (1.225)	Loss 0.6993 (0.6838)	Accuracy 0.4844 (0.5649)
# ----------
# Avg validation loss: 0.6833067760467529 	 Accuracy: 0.596
# --------------------
# Epoch 15/20	Time 106.198 sec (132.414 sec)
# --------------------
# Epoch: 16/20
# Batch: [0/79]	Time 7.852 (7.852)	Loss 0.6839 (0.6839)	Accuracy 0.5312 (0.5312)
# Batch: [10/79]	Time 0.139 (1.578)	Loss 0.6590 (0.6794)	Accuracy 0.6094 (0.5724)
# Batch: [20/79]	Time 4.436 (1.492)	Loss 0.6647 (0.6816)	Accuracy 0.6406 (0.5536)
# Batch: [30/79]	Time 0.378 (1.332)	Loss 0.6837 (0.6821)	Accuracy 0.5938 (0.5575)
# Batch: [40/79]	Time 4.231 (1.350)	Loss 0.6768 (0.6817)	Accuracy 0.6094 (0.5629)
# Batch: [50/79]	Time 0.393 (1.283)	Loss 0.7133 (0.6822)	Accuracy 0.4844 (0.5659)
# Batch: [60/79]	Time 3.933 (1.272)	Loss 0.6794 (0.6827)	Accuracy 0.6250 (0.5638)
# Batch: [70/79]	Time 0.295 (1.215)	Loss 0.6773 (0.6829)	Accuracy 0.5781 (0.5632)
# ----------
# Avg validation loss: 0.6848983058929443 	 Accuracy: 0.544
# --------------------
# Epoch 16/20	Time 106.286 sec (130.877 sec)
# --------------------
# Epoch: 17/20
# Batch: [0/79]	Time 7.765 (7.765)	Loss 0.6860 (0.6860)	Accuracy 0.5156 (0.5156)
# Batch: [10/79]	Time 0.132 (1.598)	Loss 0.6795 (0.6819)	Accuracy 0.6094 (0.5824)
# Batch: [20/79]	Time 4.478 (1.524)	Loss 0.6826 (0.6817)	Accuracy 0.5781 (0.5863)
# Batch: [30/79]	Time 0.200 (1.354)	Loss 0.6963 (0.6800)	Accuracy 0.5156 (0.5927)
# Batch: [40/79]	Time 4.318 (1.372)	Loss 0.6809 (0.6808)	Accuracy 0.5625 (0.5812)
# Batch: [50/79]	Time 0.336 (1.302)	Loss 0.6934 (0.6814)	Accuracy 0.4375 (0.5732)
# Batch: [60/79]	Time 4.087 (1.298)	Loss 0.6773 (0.6819)	Accuracy 0.5781 (0.5689)
# Batch: [70/79]	Time 0.200 (1.237)	Loss 0.6842 (0.6819)	Accuracy 0.5781 (0.5713)
# ----------
# Avg validation loss: 0.681976526260376 	 Accuracy: 0.592
# --------------------
# Epoch 17/20	Time 106.774 sec (129.538 sec)
# --------------------
# Epoch: 18/20
# Batch: [0/79]	Time 7.692 (7.692)	Loss 0.6811 (0.6811)	Accuracy 0.5625 (0.5625)
# Batch: [10/79]	Time 0.167 (1.568)	Loss 0.6813 (0.6785)	Accuracy 0.5000 (0.5923)
# Batch: [20/79]	Time 4.497 (1.488)	Loss 0.6842 (0.6797)	Accuracy 0.4688 (0.5707)
# Batch: [30/79]	Time 0.196 (1.332)	Loss 0.6619 (0.6807)	Accuracy 0.7188 (0.5670)
# Batch: [40/79]	Time 4.412 (1.353)	Loss 0.6738 (0.6815)	Accuracy 0.6250 (0.5617)
# Batch: [50/79]	Time 0.114 (1.279)	Loss 0.6588 (0.6804)	Accuracy 0.7031 (0.5726)
# Batch: [60/79]	Time 4.053 (1.277)	Loss 0.6862 (0.6808)	Accuracy 0.6406 (0.5745)
# Batch: [70/79]	Time 0.103 (1.223)	Loss 0.6805 (0.6803)	Accuracy 0.5938 (0.5779)
# ----------
# Avg validation loss: 0.6830336537361145 	 Accuracy: 0.548
# --------------------
# Epoch 18/20	Time 105.377 sec (128.266 sec)
# --------------------
# Epoch: 19/20
# Batch: [0/79]	Time 7.731 (7.731)	Loss 0.6809 (0.6809)	Accuracy 0.5625 (0.5625)
# Batch: [10/79]	Time 0.155 (1.574)	Loss 0.6656 (0.6785)	Accuracy 0.6250 (0.5852)
# Batch: [20/79]	Time 4.492 (1.489)	Loss 0.6789 (0.6797)	Accuracy 0.5469 (0.5878)
# Batch: [30/79]	Time 0.150 (1.321)	Loss 0.6698 (0.6789)	Accuracy 0.6562 (0.5948)
# Batch: [40/79]	Time 4.405 (1.352)	Loss 0.6871 (0.6784)	Accuracy 0.5156 (0.5926)
# Batch: [50/79]	Time 0.201 (1.280)	Loss 0.6847 (0.6781)	Accuracy 0.6094 (0.5980)
# Batch: [60/79]	Time 3.653 (1.279)	Loss 0.6837 (0.6793)	Accuracy 0.5469 (0.5917)
# Batch: [70/79]	Time 0.257 (1.234)	Loss 0.6657 (0.6792)	Accuracy 0.7344 (0.5946)
# ----------
# Avg validation loss: 0.681799949169159 	 Accuracy: 0.564
# --------------------
# Epoch 19/20	Time 104.891 sec (127.098 sec)
# --------------------

# %%
plt.figure(figsize=(10,10))
plt.subplot(221)
plt.title('training classification loss')
plt.plot(train_losses)
plt.subplot(222)
plt.title('training accuracy')
plt.plot(train_accs)
plt.subplot(223)
plt.title('validation loss')
plt.plot(val_losses)
plt.subplot(224)
plt.title('validation accuracy')
plt.plot(val_accs)
# plt.legend()
plt.tight_layout()
